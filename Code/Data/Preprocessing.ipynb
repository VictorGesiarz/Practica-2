# %% [markdown]
# # Preprocessing of the DATABASE

# %%
import pandas as pd
import numpy as np
import random

# %% [markdown]
# - - -

# %% [markdown]
# ## Read CSV

# %%
books = pd.read_csv("./Data/Books.csv")
print(len(books))
# Out:
# 52478

# %% [markdown]
# - - -

# %% [markdown]
# ## Remove Columns

# %%
book = books.iloc[0]
print(book)
# Out:
# bookId                                       2767052-the-hunger-games
# title                                                The Hunger Games
# series                                            The Hunger Games #1
# author                                                Suzanne Collins
# rating                                                           4.33
# description         WINNING MEANS FAME AND FORTUNE.LOSING MEANS CE...
# language                                                      English
# isbn                                                    9780439023481
# genres              ['Young Adult', 'Fiction', 'Dystopia', 'Fantas...
# characters          ['Katniss Everdeen', 'Peeta Mellark', 'Cato (H...
# bookFormat                                                  Hardcover
# edition                                                 First Edition
# pages                                                             374
# publisher                                            Scholastic Press
# publishDate                                                  09/14/08
# firstPublishDate                                                  NaN
# awards              ['Locus Award Nominee for Best Young Adult Boo...
# numRatings                                                    6376780
# ratingsByStars      ['3444695', '1921313', '745221', '171994', '93...
# likedPercent                                                     96.0
# setting             ['District 12, Panem', 'Capitol, Panem', 'Pane...
# coverImg            https://i.gr-assets.com/images/S/compressed.ph...
# bbeScore                                                      2993816
# bbeVotes                                                        30516
# price                                                            5.09
# Name: 0, dtype: object

# %%
books = books.drop(columns=['bookId', 'isbn', 'edition', 'ratingsByStars', 'coverImg', 'bbeVotes', 'bbeScore', 'price', 'characters', 'publisher', 'setting', 'firstPublishDate', 'bookFormat'], axis=1)

# %%
books
# Out:
#                                            title                 series  \
# 0                               The Hunger Games    The Hunger Games #1
# 1      Harry Potter and the Order of the Phoenix        Harry Potter #5
# 2                          To Kill a Mockingbird  To Kill a Mockingbird
# 3                            Pride and Prejudice                    NaN
# 4                                       Twilight   The Twilight Saga #1
# ...                                          ...                    ...
# 52473                                  Fractured             Fateful #2
# 52474                                    Anasazi      Sense of Truth #2
# 52475                                     Marked      Soul Guardians #1
# 52476                                Wayward Son                    NaN
# 52477                        Daughter of Helaman   Stripling Warrior #1
#
#                                                   author  rating  \
# 0                                        Suzanne Collins    4.33
# 1              J.K. Rowling, Mary GrandPré (Illustrator)    4.50
# 2                                             Harper Lee    4.28
# 3              Jane Austen, Anna Quindlen (Introduction)    4.26
# 4                                        Stephenie Meyer    3.60
# ...                                                  ...     ...
# 52473                   Cheri Schmidt (Goodreads Author)    4.00
# 52474                                      Emma Michaels    4.19
# 52475                  Kim Richardson (Goodreads Author)    3.70
# 52476  Tom Pollack (Goodreads Author), John Loftus (G...    3.85
# 52477                    Misty Moncur (Goodreads Author)    4.02
#
#                                              description language  \
# 0      WINNING MEANS FAME AND FORTUNE.LOSING MEANS CE...  English
# 1      There is a door at the end of a silent corrido...  English
# 2      The unforgettable novel of a childhood in a sl...  English
# 3      Alternate cover edition of ISBN 9780679783268S...  English
# 4      About three things I was absolutely positive.\...  English
# ...                                                  ...      ...
# 52473  The Fateful Trilogy continues with Fractured. ...  English
# 52474  'Anasazi', sequel to 'The Thirteenth Chime' by...  English
# 52475  --READERS FAVORITE AWARDS WINNER 2011--Sixteen...  English
# 52476  A POWERFUL TREMOR UNEARTHS AN ANCIENT SECRETBu...  English
# 52477  Fighting in Helaman's army is Keturah's deepes...  English
#
#                                                   genres pages  \
# 0      ['Young Adult', 'Fiction', 'Dystopia', 'Fantas...   374
# 1      ['Fantasy', 'Young Adult', 'Fiction', 'Magic',...   870
# 2      ['Classics', 'Fiction', 'Historical Fiction', ...   324
# 3      ['Classics', 'Fiction', 'Romance', 'Historical...   279
# 4      ['Young Adult', 'Fantasy', 'Romance', 'Vampire...   501
# ...                                                  ...   ...
# 52473  ['Vampires', 'Paranormal', 'Young Adult', 'Rom...     0
# 52474                         ['Mystery', 'Young Adult']   190
# 52475  ['Fantasy', 'Young Adult', 'Paranormal', 'Ange...   280
# 52476  ['Fiction', 'Mystery', 'Historical Fiction', '...   507
# 52477  ['Lds Fiction', 'Historical Fiction', 'Young A...   201
#
#               publishDate                                             awards  \
# 0                09/14/08  ['Locus Award Nominee for Best Young Adult Boo...
# 1                09/28/04  ['Bram Stoker Award for Works for Young Reader...
# 2                05/23/06  ['Pulitzer Prize for Fiction (1961)', 'Audie A...
# 3                10/10/00                                                 []
# 4                09/06/06  ['Georgia Peach Book Award (2007)', 'Buxtehude...
# ...                   ...                                                ...
# 52473       May 28th 2011                                                 []
# 52474     August 5th 2011                                                 []
# 52475     March 18th 2011            ["Readers' Favorite Book Award (2011)"]
# 52476  September 1st 2011                                                 []
# 52477        May 8th 2011                                                 []
#
#        numRatings  likedPercent
# 0         6376780          96.0
# 1         2507623          98.0
# 2         4501075          95.0
# 3         2998241          94.0
# 4         4964519          78.0
# ...           ...           ...
# 52473         871          94.0
# 52474          37          95.0
# 52475        6674          84.0
# 52476         238          90.0
# 52477         246          90.0
#
# [52478 rows x 12 columns]

# %% [markdown]
# - - -
#
# ## Preprocess categories

# %%
""" We have to remove all accents and not valid strings so that the clips language works. """

from unidecode import unidecode

def clean_string(string):
    return unidecode(string)

# %% [markdown]
# Titles  - - - - - - - - - - - - - - - - - - - - - - - - - - - - -

# %%
books['title'] = books['title'].apply(lambda x: clean_string(x))

# %% [markdown]
# Authors - - - - - - - - - - - - - - - - - - - - - - - - - - - - -

# %%
authors = books['author'].unique()
print(authors)
# Out:
# ['Suzanne Collins' 'J.K. Rowling, Mary GrandPré (Illustrator)'
#  'Harper Lee' ... 'Cheri Schmidt (Goodreads Author)'
#  'Tom Pollack (Goodreads Author), John Loftus (Goodreads Author), Jim Alves'
#  'Misty Moncur (Goodreads Author)']

# %%
def modify_authors(author):
    authors = author.split(',')
    author = clean_string(' '.join(authors[0].split()))
    remove_parentesis = author.find('(')
    if remove_parentesis != -1:
        author = author[:remove_parentesis]
    return author

filtered_books_df = books.copy()
filtered_books_df['author'] = filtered_books_df['author'].apply(lambda x: modify_authors(x))

# %%
books = filtered_books_df.copy()

# %% [markdown]
# Languages - - - - - - - - - - - - - - - - - - - - - - - - - - - - -

# %%
languages = books['language'].unique()
print(languages)
# Out:
# ['English' 'French' 'German' 'Persian' 'Arabic' nan 'Spanish'
#  'Multiple languages' 'Portuguese' 'Indonesian' 'Turkish' 'Polish'
#  'Bulgarian' 'Tamil' 'Japanese' 'Romanian' 'Italian'
#  'French, Middle (ca.1400-1600)' 'Norwegian' 'Urdu' 'Dutch' 'Finnish'
#  'Marathi' 'Chinese' 'Swedish' 'Icelandic' 'Malayalam' 'Croatian'
#  'Estonian' 'Greek, Modern (1453-)' 'Russian' 'Kurdish' 'Danish' 'Hindi'
#  'Filipino; Pilipino' 'Serbian' 'Bengali' 'Malay' 'Catalan; Valencian'
#  'Czech' 'Vietnamese' 'Armenian' 'Georgian' 'Kannada' 'Korean' 'Nepali'
#  'Slovak' 'Telugu' 'Hungarian' 'English, Middle (1100-1500)' 'Azerbaijani'
#  'Farsi' 'Lithuanian' 'Ukrainian' 'Bokmål, Norwegian; Norwegian Bokmål'
#  'Iranian (Other)' 'Faroese' 'Basque' 'Macedonian' 'Maltese' 'Gujarati'
#  'Amharic' 'Aromanian; Arumanian; Macedo-Romanian' 'Assamese'
#  'Panjabi; Punjabi' 'Albanian' 'Latvian' 'Bosnian' 'Afrikaans' 'Thai'
#  'Dutch, Middle (ca.1050-1350)' 'Mongolian' 'Tagalog' 'Galician' 'Aleut'
#  'Slovenian' 'Undetermined' 'Greek, Ancient (to 1453)' 'Mayan languages'
#  'Duala' 'Australian languages' 'Norwegian Nynorsk; Nynorsk, Norwegian']

# %%
desired_languages = ['English'] 
books = books[books['language'].isin(desired_languages)]
books = books.drop(columns=['language'])

# %% [markdown]
# Genres - - - - - - - - - - - - - - - - - - - - - - - - - - - - -

# %%
import ast

books['genres'] = books['genres'].apply(ast.literal_eval)

# %%
# Separate the "Classic" Genre as an independentn column.

classics = []
ages = []
for i, row in books.iterrows():
    genre = row['genres']
    if 'Classics' in genre:
        classics.append('classic')
    elif 'Modern Classics' in genre:
        classics.append('modern-classic')
    elif 'Children Classics' in genre:
        classics.append('children-classic')
    else:
        classics.append("no")
        
    age = []
    if 'Kids' in genre or 'Childrens' in genre:
        age.append('kids')
    if 'Teen' in genre:
        age.append('teen')
    if 'Young Adult' in genre:
        age.append('young-adult')
    if 'Adult' in genre:
        age.append('adult')
    ages.append(age)
        
books.insert(books.columns.get_loc("genres") + 1, 'classics', classics)
books.insert(books.columns.get_loc("genres") + 2, 'ages', ages)

# %%
def get_genres(db):
    genres = set()

    for i, row in db.iterrows():
        genre = row['genres']
        
        for j in genre:
            genres.add(j)
            
    return genres

genres = get_genres(books)
print("Genres:", len(genres), genres)
# Out:
# Genres: 966 {'Chick Lit', 'Hard Boiled', 'Western Historical Romance', 'Mary Shelley', 'Contemporary', 'The United States Of America', 'Cyberpunk', 'Ethiopia', 'Journal', 'Philosophy', 'M M M', 'Dragons', 'Food History', 'Georgian', 'Womens', 'Singularity', 'Spanish Literature', 'Brewing', 'German Literature', 'Fae', 'Greece', 'Womens Fiction', 'Civil War', 'Memoir', 'Love Inspired', 'Humanities', 'Travel', 'Writing', 'Computer Science', 'World War II', 'Comix', 'Amateur Sleuth', 'Star Trek Deep Space Nine', 'Irish Literature', 'Algeria', 'Space Opera', 'Art and Photography', 'Arthurian', 'History Of Medicine', 'Ornithology', 'Loveswept', 'Sustainability', 'Viking Romance', 'Oral History', 'Lds Non Fiction', 'Holland', 'Global Warming', 'International Relations', 'Romance', 'Medieval', 'Entrepreneurship', 'Adoption', 'Boarding School', 'Website Design', 'Ethnography', 'Banks', 'Personal Finance', 'Communication', 'Tragedy', 'Planetary Romance', 'Pop Culture', 'Young Adult Historical Fiction', 'Bande Dessinée', 'Animal Fiction', 'Zombies', 'Media Tie In', 'Cults', 'Disease', 'Sudan', 'Soldiers', 'Slash Fiction', 'Paranormal Romance', 'Namibia', 'Paranormal Mystery', 'Field Guides', 'Spain', 'Police', 'Teen', 'Naturopathy', 'Amish', 'Scotland', 'Short Story Collection', 'Sewing', 'Kazakhstan', 'Asia', 'High School', 'Nursery Rhymes', 'Maritime', 'Visual Art', 'Splatterpunk', 'Language', 'Indian Literature', 'Death', 'Western Africa', 'Coming Of Age', 'Colouring Books', 'Theatre', 'Goddess', 'Central Africa', 'Physics', 'American', 'Biblical Fiction', 'Poetry', 'Turkish Literature', 'Moroccan', 'Belgian', 'Research', 'Political Science', 'Anarchism', 'Birds', 'Elizabethan Period', 'American Fiction', 'Education', 'Civil War Eastern Theater', 'Civil War History', 'Unfinished', 'Firefighters', 'Turkish', 'Paranormal', 'Animals', 'Fighters', 'Basketball', 'Post Colonial', 'Architecture', 'Mathematics', 'Urban', 'Puzzles', 'Polyamorous', 'Paranormal Urban Fantasy', 'Geometry', 'Science Nature', 'Role Playing Games', 'Sex Work', 'Figure Skating', 'Maps', 'Sci Fi Fantasy', 'M M Science Fiction', 'Republic Of The Congo', 'Young Adult Science Fiction', 'Anthropology', 'Mixed Martial Arts', 'Diary', 'Fat Acceptance', 'Comics', 'Ecclesiology', 'Health Care', 'Naval Historical Fiction', 'Low Fantasy', 'Food Preservation', 'Ecology', 'Liberia', 'United States', 'Soviet History', 'Algorithms', 'Social Justice', 'Did Not Finish', 'Yeti', 'Gay Fiction', 'Military History', 'Satanism', 'Folklore', 'Germany', 'Church', 'Sierra Leone', 'Illness', 'Dogs', 'Regency', 'Elves', 'Gardening', 'Vaccines', 'Spanish History', 'Realistic Fiction', 'Zambia', 'Adventure', 'Italian Literature', 'Comedy', 'Travelogue', 'Epic Fantasy', 'Presidents', 'Modern', 'Foodie', 'Academia', 'Josei', 'Steampunk', 'Nerd', 'Cult Classics', 'Roman Britain', 'Supernatural Romance', 'Queer', 'Booze', 'Virtual Reality', 'Alternate History', 'Information Science', 'Sequential Art', 'Star Wars', 'Conservation', 'Pilots', 'Unicorns', 'Brazil', 'Motorcycle', 'Deception', 'Nigeria', 'Multicultural Literature', 'Library Science', 'Spanish Civil War', 'Words', 'Stand Up', 'Culinary', 'Sociology', 'Finance', 'Plantagenet', 'Vegan', 'Georgian Romance', 'Nordic Noir', 'Erotic Horror', 'Komik', 'Bulgarian Literature', 'Egyptology', 'Mental Health', 'Indonesian Literature', 'Historical Romance', 'Egypt', 'Nature', 'Chemistry', 'Morocco', 'Danish', 'Benin', 'Gothic', 'Robots', 'High Fantasy', 'M M F', 'Angels', 'Tudor Period', 'Martial Arts', 'Seinen', 'Planets', 'Foster Parents', 'Personal Development', 'Superheroes', 'Fundamentalism', 'Gaming', '17th Century', 'New Adult', 'Harlequin Nocturne', 'France', 'Far Right', 'Folk Tales', 'Drama', 'Art Design', 'Drawing', 'Young Adult Paranormal', 'Anti Racist', 'Classics', 'History and Politics', 'Software', 'Lebanon', 'Crafts', 'Tanzania', 'Music Biography', 'Zen', 'Uganda', 'Psychology', 'Own', 'Hockey', 'Transport', 'Canon', 'Lenin', 'Southern ...

# %%
desired_genres = ['Romance', 'Fantasy', 'Science Fiction', 'Horror']
desired_subgenres = ['Comedy', 'Erotic Romance', 'Paranormal Romance', 'Contemporary Romance', 'Historical Romance',
                     'High Fantasy', 'Urban Fantasy', 'Sword and Sorcery', 'Epic Fantasy', 'Historical Fantasy', 'Magic',
                     'Cyberpunk', 'Hard Science Fiction', 'Post Apocalyptic', 'Space', 'Time Travel', 'Historical Fiction', 'Realistic Fiction',
                     'Paranormal', 'Demons', 'Monsters', 'Zombies', 'Vampires', 'Witchcraft']

# %%
genres = []
subgenres = []
for i, row in books.iterrows():
    genre = row['genres']
    row_genres = []
    row_subgenres = []
    if 'Fiction' in genre:
        for x in genre:
            if x in desired_genres:
                row_genres.append(x)
            if x in desired_subgenres:
                row_subgenres.append(x)
        
    genres.append(row_genres)
    subgenres.append(row_subgenres)
        
books['genres'] = genres
books.insert(books.columns.get_loc("genres") + 1, 'subgenres', subgenres)
books = books[books['genres'].apply(lambda x: x != [])]
books = books[books['subgenres'].apply(lambda x: x != [])]

# %% [markdown]
# Awards - - - - - - - - - - - - - - - - - - - - - - - - - - - - -

# %%
books['awards'] = books['awards'].apply(ast.literal_eval)

# %%
def update_awards(awards_list):
    return len(awards_list)

books['awards'] = books['awards'].apply(update_awards)

# %% [markdown]
# Series -> saga - - - - - - - - - - - - - - - - - - - - - - - - - - - - -

# %%
books['series'] = books['series'].replace(np.nan, 'No')
books.rename(columns={'series': 'saga'}, inplace=True)
books['saga'] = books['saga'].apply(lambda x: clean_string(x))

# %%
num_saga = []
saga = []

saga_books = books.copy()

for i, row in books.iterrows():
    name_saga = row["saga"]
    
    if name_saga == "No":
        saga.append(name_saga)
        num_saga.append("No")
        continue
    
    index = name_saga.find("#")
    new_string = name_saga[:index-1]
    saga.append(new_string)  
    
    if name_saga[index+1:len(name_saga)].isnumeric():
        num_saga.append(int(name_saga[index+1:len(name_saga)])) 
        
    else:  
        num_saga.append("remove")
        
saga_books['saga'] = saga
saga_books.insert(books.columns.get_loc("saga") + 1, "numSaga", num_saga)
saga_books = saga_books[saga_books['numSaga'].apply(lambda x: x != "remove")]

# %%
saga_books[saga_books['saga'] == "The Lord of the Rings"]
# Out:
#                       title                   saga numSaga          author  \
# 548  The Return of the King  The Lord of the Rings       3  J.R.R. Tolkien
# 608          The Two Towers  The Lord of the Rings       2  J.R.R. Tolkien
#
#      rating                                        description     genres  \
# 548    4.53  In the third volume of The Lord of the Rings t...  [Fantasy]
# 608    4.44  The Fellowship was scattered. Some were bracin...  [Fantasy]
#
#                                subgenres classics ages pages publishDate  \
# 548  [High Fantasy, Epic Fantasy, Magic]  classic   []   385    07/12/74
# 608  [High Fantasy, Epic Fantasy, Magic]  classic   []   322    09/05/03
#
#      awards  numRatings  likedPercent
# 548       0      678718          98.0
# 608       0      719647          97.0

# %%
books = saga_books.copy()

# %% [markdown]
# Publish Date - - - - - - - - - - - - - - - - - - - - - - - - - - - - -

# %%
books['publishDate'] = books['publishDate'].replace(np.nan, "00/00/00")

# %%
from dateutil import parser

def extract_year(date_str):
    try:
        date_obj = parser.parse(date_str)
        return date_obj.year
    except ValueError:
        return None

books['publishDate'] = books['publishDate'].apply(extract_year)

# %% [markdown]
# Result - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -

# %%
books = books.dropna()
books.isna().sum()
# Out:
# title           0
# saga            0
# numSaga         0
# author          0
# rating          0
# description     0
# genres          0
# subgenres       0
# classics        0
# ages            0
# pages           0
# publishDate     0
# awards          0
# numRatings      0
# likedPercent    0
# dtype: int64

# %%
books
# Out:
#                                            title                    saga  \
# 0                               The Hunger Games        The Hunger Games
# 1      Harry Potter and the Order of the Phoenix            Harry Potter
# 3                            Pride and Prejudice                      No
# 4                                       Twilight       The Twilight Saga
# 9                             Gone with the Wind                      No
# ...                                          ...                     ...
# 52461                           Sweet Possession         Sweet Addiction
# 52466             Theodosia and the Last Pharaoh  Theodosia Throckmorton
# 52471                                  Elemental          Soul Guardians
# 52475                                     Marked          Soul Guardians
# 52477                        Daughter of Helaman       Stripling Warrior
#
#       numSaga             author  rating  \
# 0           1    Suzanne Collins    4.33
# 1           5       J.K. Rowling    4.50
# 3          No        Jane Austen    4.26
# 4           1    Stephenie Meyer    3.60
# 9          No  Margaret Mitchell    4.30
# ...       ...                ...     ...
# 52461       2        J. Daniels     4.33
# 52466       4     R.L. LaFevers     4.26
# 52471       2    Kim Richardson     4.07
# 52475       1    Kim Richardson     3.70
# 52477       1      Misty Moncur     4.02
#
#                                              description  \
# 0      WINNING MEANS FAME AND FORTUNE.LOSING MEANS CE...
# 1      There is a door at the end of a silent corrido...
# 3      Alternate cover edition of ISBN 9780679783268S...
# 4      About three things I was absolutely positive.\...
# 9      Scarlett O'Hara, the beautiful, spoiled daught...
# ...                                                  ...
# 52461  There is an alternate cover edition for this A...
# 52466  In this fourth book in the series, Theodosia s...
# 52471  When seventeen-year-old Kara Nightingale is su...
# 52475  --READERS FAVORITE AWARDS WINNER 2011--Sixteen...
# 52477  Fighting in Helaman's army is Keturah's deepes...
#
#                                     genres  \
# 0      [Fantasy, Science Fiction, Romance]
# 1                                [Fantasy]
# 3                                [Romance]
# 4                       [Fantasy, Romance]
# 9                                [Romance]
# ...                                    ...
# 52461                            [Romance]
# 52466                            [Fantasy]
# 52471  [Fantasy, Romance, Science Fiction]
# 52475                   [Fantasy, Romance]
# 52477                   [Fantasy, Romance]
#
#                                                subgenres classics  \
# 0                                     [Post Apocalyptic]       no
# 1                                                [Magic]  classic
# 3               [Historical Fiction, Historical Romance]  classic
# 4      [Vampires, Paranormal, Paranormal Romance, Urb...       no
# 9               [Historical Fiction, Historical Romance]  classic
# ...                                                  ...      ...
# 52461                             [Contemporary Romance]       no
# 52466                               [Historical Fiction]       no
# 52471           [Paranormal, Demons, Paranormal Romance]       no
# 52475  [Paranormal, Demons, Paranormal Romance, Urban...       no
# 52477                               [Historical Fiction]       no
#
#                       ages pages  publishDate  awards  numRatings  \
# 0      [teen, young-adult]   374       2008.0      41     6376780
# 1      [kids, young-adult]   870       2004.0       9     2507623
# 3                  [adult]   279       2000.0       0     2998241
# 4      [teen, young-adult]   501       2006.0      25     4964519
# 9                       []  1037       1999.0       2     1074620
# ...                    ...   ...          ...     ...         ...
# 52461              [adult]   248       2014.0       0       10663
# 52466  [kids, young-adult]   400       2011.0       0        1958
# 52471        [young-adult]   151       2011.0       0        1947
# 52475        [young-adult]   280       2011.0       1        6674
# 52477  [teen, young-adult]   201       2011.0       0         246
#
#        likedPercent
# 0              96.0
# 1              98.0
# 3              94.0
# 4              78.0
# 9              94.0
# ...             ...
# 52461          97.0
# 52466          97.0
# 52471          94.0
# 52475          84.0
# 52477          90.0
#
# [12401 rows x 15 columns]

# %% [markdown]
# - - -

# %% [markdown]
# ## Generate Data

# %%
"""
(defclass Book
    (multislot genres)
    (slot author)
    (slot orientated-age)
    (slot period)
    (slot film)
    (slot narrator)
    (slot saga)
    (slot n-volumes)      ESTA NO SE
    (slot saga-finished)  ESTA TAMPOCO
    (slot book-length)
    (slot punctuation)
    (slot classic)
    (slot antiquity-of-book)
    (slot recently-published)
    (slot bestseller)
    (slot comedy)
    (slot drama)
    (slot happiness)
    (slot predictable)
    (slot violence)
    (slot conventional)
)
"""
# Out:
# '\n(defclass Book\n    (multislot genres)\n    (slot author)\n    (slot orientated-age)\n    (slot period)\n    (slot film)\n    (slot narrator)\n    (slot saga)\n    (slot n-volumes)      ESTA NO SE\n    (slot saga-finished)  ESTA TAMPOCO\n    (slot book-length)\n    (slot punctuation)\n    (slot classic)\n    (slot antiquity-of-book)\n    (slot recently-published)\n    (slot bestseller)\n    (slot comedy)\n    (slot drama)\n    (slot happiness)\n    (slot predictable)\n    (slot violence)\n    (slot conventional)\n)\n'

# %%
saga_finished = []
period = []
film = []
narrator = []
hapiness = []
drama = []
comedy = []
predictable = []
violence = []
conventional = [] 

random.seed(42)

sagas_done = {}

for i, row in books.iterrows():
    saga = row['saga']
    if saga == "No":
        saga_finished.append("No")
    else:
        if saga not in sagas_done:
            choice = random.choice(['Yes', 'No'])
            saga_finished.append(choice)
            sagas_done[saga] = choice
        else:
            saga_finished.append(sagas_done[saga])
    period.append(random.choice(['past', 'present', 'future']))
    film.append(random.choice(['Yes', 'No']))
    narrator.append(random.choices(['first-person', 'second-person', 'third-person', 'omniscent'], weights=[0.25, 0.05, 0.5, 0.2], k=1)[0])
    hapiness.append(random.randint(0, 10))
    drama.append(random.randint(0, 10))
    comedy.append(random.randint(0, 10))
    predictable.append(random.randint(0, 10))
    violence.append(random.randint(0, 10))
    conventional.append(random.randint(0, 10))


new_books = books.copy()
new_books.insert(new_books.columns.get_loc("numSaga") + 1, "sagaFinished", saga_finished)
new_books['period'] = period
new_books['film'] = film
new_books['narrator'] = narrator
new_books['hapiness'] = hapiness
new_books['drama'] = drama
new_books['comedy'] = comedy
new_books['predictable'] = predictable
new_books['violence'] = violence
new_books['conventional'] = conventional

# %%
new_books
# Out:
#                                            title                    saga  \
# 0                               The Hunger Games        The Hunger Games
# 1      Harry Potter and the Order of the Phoenix            Harry Potter
# 3                            Pride and Prejudice                      No
# 4                                       Twilight       The Twilight Saga
# 9                             Gone with the Wind                      No
# ...                                          ...                     ...
# 52461                           Sweet Possession         Sweet Addiction
# 52466             Theodosia and the Last Pharaoh  Theodosia Throckmorton
# 52471                                  Elemental          Soul Guardians
# 52475                                     Marked          Soul Guardians
# 52477                        Daughter of Helaman       Stripling Warrior
#
#       numSaga sagaFinished             author  rating  \
# 0           1          Yes    Suzanne Collins    4.33
# 1           5           No       J.K. Rowling    4.50
# 3          No           No        Jane Austen    4.26
# 4           1           No    Stephenie Meyer    3.60
# 9          No           No  Margaret Mitchell    4.30
# ...       ...          ...                ...     ...
# 52461       2          Yes        J. Daniels     4.33
# 52466       4           No     R.L. LaFevers     4.26
# 52471       2          Yes    Kim Richardson     4.07
# 52475       1          Yes    Kim Richardson     3.70
# 52477       1           No      Misty Moncur     4.02
#
#                                              description  \
# 0      WINNING MEANS FAME AND FORTUNE.LOSING MEANS CE...
# 1      There is a door at the end of a silent corrido...
# 3      Alternate cover edition of ISBN 9780679783268S...
# 4      About three things I was absolutely positive.\...
# 9      Scarlett O'Hara, the beautiful, spoiled daught...
# ...                                                  ...
# 52461  There is an alternate cover edition for this A...
# 52466  In this fourth book in the series, Theodosia s...
# 52471  When seventeen-year-old Kara Nightingale is su...
# 52475  --READERS FAVORITE AWARDS WINNER 2011--Sixteen...
# 52477  Fighting in Helaman's army is Keturah's deepes...
#
#                                     genres  \
# 0      [Fantasy, Science Fiction, Romance]
# 1                                [Fantasy]
# 3                                [Romance]
# 4                       [Fantasy, Romance]
# 9                                [Romance]
# ...                                    ...
# 52461                            [Romance]
# 52466                            [Fantasy]
# 52471  [Fantasy, Romance, Science Fiction]
# 52475                   [Fantasy, Romance]
# 52477                   [Fantasy, Romance]
#
#                                                subgenres classics  ...  \
# 0                                     [Post Apocalyptic]       no  ...
# 1                                                [Magic]  classic  ...
# 3               [Historical Fiction, Historical Romance]  classic  ...
# 4      [Vampires, Paranormal, Paranormal Romance, Urb...       no  ...
# 9               [Historical Fiction, Historical Romance]  classic  ...
# ...                                                  ...      ...  ...
# 52461                             [Contemporary Romance]       no  ...
# 52466                               [Historical Fiction]       no  ...
# 52471           [Paranormal, Demons, Paranormal Romance]       no  ...
# 52475  [Paranormal, Demons, Paranormal Romance, Urban...       no  ...
# 52477                               [Historical Fiction]       no  ...
#
#       likedPercent   period  film      narrator  hapiness  drama comedy  \
# 0             96.0     past    No  first-person         2      1     10
# 1             98.0     past   Yes  first-person         3      8      9
# 3             94.0   future    No  first-person         9      4      0
# 4             78.0     past   Yes     omniscent         5      1      1
# 9             94.0  present    No     omniscent         7      8      1
# ...            ...      ...   ...           ...       ...    ...    ...
# 52461         97.0   future   Yes  third-person         0      9      8
# 52466         97.0  present    No  third-person         7      1      9
# 52471         94.0  present   Yes  third-person         3      7      0
# 52475         84.0     past   Yes  third-person         5      3      7
# 52477         90.0     past    No     omniscent         6      1      6
#
#       predictable violence  conventional
# 0               8        1             9
# 1               0        8             3
# 3               2        6             5
# 4               6        1             5
# 9               6        1             8
# ...           ...      ...           ...
# 52461           7        7             6
# 52466           4        7             1
# 52471           0        9             1
# 52475           7        5             4
# 52477          10        3             2
#
# [12401 rows x 25 columns]

# %% [markdown]
# - - -

# %% [markdown]
# ## Save results

# %%
books.to_csv('./Data/Books_preprocessed.csv', index=False)
new_books.to_csv('./Data/Books_preprocessed_generated_data.csv', index=False)

# %% [markdown]
# - - -
#
# # Create Authors Data Base

# %%
import statistics

authors = []
books_authors = []
genres_authors = []
subgenres_authors = []
classic_authors = []
narrator_authors = []

for i, row in new_books.iterrows():    
    author = row["author"]
    
    if author in authors:
        continue
    
    authors.append(author)
    
    books_author = []
    genres_author = []
    subgenres_author = []
    classic_author = []
    narrator_author = []
    
    for j, row2 in new_books[new_books['author'] == author].iterrows():
        
        books_author.append(row2['title'])
        
        for i in row2['genres']:
            if i not in genres_author:
                genres_author.append(i)
        
        for i in row2['subgenres']:
            if i not in subgenres_author:
                subgenres_author.append(i)
        
        classic_author.append(row2['classics'])
        
        narrator_author.append(row2['narrator'])
    
    books_authors.append(books_author)
    genres_authors.append(genres_author)
    subgenres_authors.append(subgenres_author)
    classic_authors.append(statistics.mode(classic_author))
    narrator_authors.append(statistics.mode(narrator_author))

# %%
data = {
    'author': authors,
    'books': books_authors,
    'genres': genres_authors,
    'subgenres': subgenres_authors,
    'classic': classic_authors,
    'narrator': narrator_authors
}

authors_db = pd.DataFrame(data)
authors_db
# Out:
#                  author                                              books  \
# 0       Suzanne Collins  [The Hunger Games, Catching Fire, Mockingjay, ...
# 1          J.K. Rowling  [Harry Potter and the Order of the Phoenix, Ha...
# 2           Jane Austen  [Pride and Prejudice, The Complete Novels, Man...
# 3       Stephenie Meyer  [Twilight, Midnight Sun [2008 Draft], The Host...
# 4     Margaret Mitchell                               [Gone with the Wind]
# ...                 ...                                                ...
# 4858         Paul Melko       [The Walls of the Universe, Broken Universe]
# 4859       Gideon Defoe     [The Pirates! In an Adventure with Scientists]
# 4860        Brian Lynch                  [Angel: After the Fall, Volume 1]
# 4861    Kim Richardson                                 [Elemental, Marked]
# 4862      Misty Moncur                               [Daughter of Helaman]
#
#                                    genres  \
# 0     [Fantasy, Science Fiction, Romance]
# 1                               [Fantasy]
# 2                               [Romance]
# 3     [Fantasy, Romance, Science Fiction]
# 4                               [Romance]
# ...                                   ...
# 4858           [Science Fiction, Fantasy]
# 4859                            [Fantasy]
# 4860                    [Fantasy, Horror]
# 4861  [Fantasy, Romance, Science Fiction]
# 4862                   [Fantasy, Romance]
#
#                                               subgenres  classic      narrator
# 0                                    [Post Apocalyptic]       no  first-person
# 1                           [Magic, Historical Fiction]  classic     omniscent
# 2              [Historical Fiction, Historical Romance]  classic  third-person
# 3     [Vampires, Paranormal, Paranormal Romance, Urb...       no  third-person
# 4              [Historical Fiction, Historical Romance]  classic     omniscent
# ...                                                 ...      ...           ...
# 4858                                      [Time Travel]       no     omniscent
# 4859                       [Historical Fiction, Comedy]       no     omniscent
# 4860              [Vampires, Urban Fantasy, Paranormal]       no  third-person
# 4861  [Paranormal, Demons, Paranormal Romance, Urban...       no  third-person
# 4862                               [Historical Fiction]       no     omniscent
#
# [4863 rows x 6 columns]

# %%
authors_db.to_csv('./Data/Authors.csv', index=False)

# %% [markdown]
# - - -
#
# # Create sagas and genres database

# %%
sagas = []
book_names = []
number_books = []
saga_finished = []
for i, row in new_books.iterrows():
    saga = row['saga']
    if saga in sagas or saga == "No": continue
    
    names = []
    for j, row2 in new_books[new_books['saga'] == saga].iterrows():
        names.append(row2['title'])
    number = len(names)    
    finished = row['sagaFinished']

    sagas.append(saga)
    book_names.append(names)
    number_books.append(number)
    saga_finished.append(finished)

# %%
data = {
    'saga': sagas,
    'books': book_names,
    'number': number_books,
    'finished': saga_finished
}

sagas_df = pd.DataFrame(data)

# %%
sagas_df
# Out:
#                                       saga  \
# 0                         The Hunger Games
# 1                             Harry Potter
# 2                        The Twilight Saga
# 3     The Hitchhiker's Guide to the Galaxy
# 4                                Divergent
# ...                                    ...
# 4283                          The Pirates!
# 4284         Nathaniel Fludd, Beastologist
# 4285                 Angel: After the Fall
# 4286                        Soul Guardians
# 4287                     Stripling Warrior
#
#                                                   books  number finished
# 0         [The Hunger Games, Catching Fire, Mockingjay]       3      Yes
# 1     [Harry Potter and the Order of the Phoenix, Ha...       8       No
# 2     [Twilight, Eclipse, Breaking Dawn, New Moon, M...       5       No
# 3     [The Hitchhiker's Guide to the Galaxy, The Res...       5      Yes
# 4                     [Divergent, Insurgent, Allegiant]       3      Yes
# ...                                                 ...     ...      ...
# 4283     [The Pirates! In an Adventure with Scientists]       1      Yes
# 4284                              [The Basilisk's Lair]       1      Yes
# 4285                  [Angel: After the Fall, Volume 1]       1       No
# 4286                                [Elemental, Marked]       2      Yes
# 4287                              [Daughter of Helaman]       1       No
#
# [4288 rows x 4 columns]

# %%
sagas_df.to_csv("./Data/Sagas.csv", index=False)
