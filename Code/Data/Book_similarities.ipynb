# %% [markdown]
# # Find book similarities with cosine similarity

# %% [markdown]
# - - -

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np
import pandas as pd
import re
import string
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer

# %%
books = pd.read_csv('./Data/Books_preprocessed.csv')
books_descriptions = books['description']

# %%
suma = 0
for i in books['genres']:
    if 'Fiction' in i:
        suma += 1
print(suma, len(books))
# Out:
# 2741 13152

# %%
for i in range(len(books)):
    print(f'{books["title"][i]}: {books["genres"][i]}')
# Out:
# The Hunger Games: ['Fantasy', 'Science Fiction', 'Romance']
# Harry Potter and the Order of the Phoenix: ['Fantasy']
# Pride and Prejudice: ['Romance']
# Twilight: ['Fantasy', 'Romance']
# J.R.R. Tolkien 4-Book Boxed Set: The Hobbit and The Lord of the Rings: ['Fantasy']
# Gone with the Wind: ['Romance']
# The Fault in Our Stars: ['Romance']
# The Hitchhiker's Guide to the Galaxy: ['Science Fiction', 'Fantasy']
# Wuthering Heights: ['Romance']
# Memoirs of a Geisha: ['Romance']
# Jane Eyre: ['Romance']
# Les Misérables: ['Romance']
# Divergent: ['Fantasy', 'Science Fiction', 'Romance']
# The Perks of Being a Wallflower: ['Romance']
# The Great Gatsby: ['Romance']
# City of Bones: ['Fantasy', 'Romance']
# Harry Potter and the Sorcerer's Stone: ['Fantasy']
# The Time Traveler's Wife: ['Romance', 'Fantasy', 'Science Fiction']
# Dracula: ['Horror', 'Fantasy']
# One Hundred Years of Solitude: ['Fantasy']
# The Princess Bride: ['Fantasy', 'Romance']
# The Lightning Thief: ['Fantasy']
# The Secret Garden: ['Fantasy']
# A Wrinkle in Time: ['Fantasy', 'Science Fiction']
# A Game of Thrones: ['Fantasy']
# Where the Wild Things Are: ['Fantasy']
# The Odyssey: ['Fantasy']
# Water for Elephants: ['Romance']
# Slaughterhouse-Five: ['Science Fiction', 'Fantasy']
# The Pillars of the Earth: ['Fantasy']
# The Stand: ['Horror', 'Fantasy', 'Science Fiction']
# Little Women: ['Romance']
# Harry Potter and the Deathly Hallows: ['Fantasy']
# Anna Karenina: ['Romance']
# Outlander: ['Romance', 'Fantasy']
# Matilda: ['Fantasy']
# Rebecca: ['Romance']
# The Road: ['Science Fiction', 'Horror']
# Vampire Academy: ['Fantasy', 'Romance']
# Harry Potter and the Prisoner of Azkaban: ['Fantasy']
# The Notebook: ['Romance']
# Interview with the Vampire: ['Horror', 'Fantasy']
# Harry Potter and the Goblet of Fire: ['Fantasy']
# Clockwork Angel: ['Fantasy', 'Romance']
# Harry Potter and the Half-Blood Prince: ['Fantasy']
# The Master and Margarita: ['Fantasy']
# The Name of the Wind: ['Fantasy']
# The Shining: ['Horror', 'Fantasy']
# Eragon: ['Fantasy']
# Looking for Alaska: ['Romance']
# The Shadow of the Wind: ['Fantasy']
# Harry Potter and the Chamber of Secrets: ['Fantasy']
# Hush, Hush: ['Fantasy', 'Romance']
# American Gods: ['Fantasy', 'Science Fiction']
# The Count of Monte Cristo: ['Romance']
# Perfume: The Story of a Murderer: ['Horror']
# The Lion, the Witch and the Wardrobe: ['Fantasy']
# It: ['Horror', 'Fantasy']
# The Last Olympian: ['Fantasy']
# The Hobbit, or There and Back Again: ['Fantasy']
# Love in the Time of Cholera: ['Romance']
# Shadow Kiss: ['Fantasy', 'Romance']
# Insurgent: ['Fantasy', 'Science Fiction', 'Romance']
# The Thorn Birds: ['Romance']
# A Walk to Remember: ['Romance']
# The Ultimate Hitchhiker's Guide to the Galaxy: ['Science Fiction', 'Fantasy']
# Atonement: ['Romance']
# The Importance of Being Earnest: ['Romance']
# The Wonderful Wizard of Oz: ['Fantasy']
# Frostbite: ['Fantasy', 'Romance']
# Good Omens: The Nice and Accurate Prophecies of Agnes Nutter, Witch: ['Fantasy', 'Science Fiction']
# Blood Promise: ['Fantasy', 'Romance']
# Tess of the D'Urbervilles: ['Romance']
# The Battle of the Labyrinth: ['Fantasy']
# Clockwork Princess: ['Fantasy', 'Romance']
# The Mists of Avalon: ['Fantasy', 'Romance']
# The Titan's Curse: ['Fantasy']
# The Sea of Monsters: ['Fantasy']
# Bridge to Terabithia: ['Fantasy']
# The Maze Runner: ['Science Fiction', 'Fantasy']
# Treasure Island: ['Fantasy']
# Fifty Shades of Grey: ['Romance']
# The Clan of the Cave Bear: ['Fantasy', 'Romance']
# A Storm of Swords: ['Fantasy']
# A Farewell to Arms: ['Romance']
# Wicked: The Life and Times of the Wicked Witch of the West: ['Fantasy']
# His Dark Materials: ['Fantasy', 'Science Fiction']
# The Other Boleyn Girl: ['Romance']
# Last Sacrifice: ['Fantasy', 'Romance']
# The Night Circus: ['Fantasy', 'Romance']
# Fallen: ['Fantasy', 'Romance']
# The Silmarillion: ['Fantasy']
# Catching Fire: ['Fantasy', 'Science Fiction', 'Romance']
# The Lost Hero: ['Fantasy']
# Throne of Glass: ['Fantasy', 'Romance']
# Spirit Bound: ['Fantasy', 'Romance']
# Clockwork Prince: ['Fantasy', 'Romance']
# The Iliad/The Odyssey: ['Fantasy']
# Girl with a Pearl Earring: ['Romance']
# Shiver: ['Fantasy', 'Romance']
# Uglies: ['Science Fiction', 'Fantasy', 'Romance']
# City of Fallen Angels: ['Fantasy', 'Romance']
# The Phantom of the Opera: ['Horror', 'Romance', 'Fantasy']
# Ella Enchanted: ['Fantasy', 'Romance']
# The Green Mile: ['Horror', 'Fantasy']
# A Clash of Kings: ['Fantasy']
# Marked: ['Fantasy', 'Romance']
# The Guernsey Literary and Potato Peel Pie Society: ['Romance']
# The House of the Spirits: ['Fantasy']
# Howl's Moving Castle: ['Fantasy', 'Romance']
# Midnight Sun [2008 Draft]: ['Fantasy', 'Romance']
# Delirium: ['Romance', 'Science Fiction', 'Fantasy']
# Beautiful Disaster: ['Romance']
# Flow Down Like Silver: Hypatia of Alexandria: ['Romance']
# Paper Towns: ['Romance']
# The Vampire Lestat: ['Horror', 'Fantasy']
# The Once and Future King: ['Fantasy']
# Neverwhere: ['Fantasy', 'Science Fiction', 'Horror']
# Inkheart: ['Fantasy']
# Lamb: The Gospel According to Biff, Christ's Childhood Pal: ['Fantasy']
# The Historian: ['Fantasy', 'Horror']
# Graceling: ['Fantasy', 'Romance']
# The Thirteenth Tale: ['Fantasy']
# Foundation: ['Science Fiction', 'Fantasy']
# The Time Machine: ['Science Fiction', 'Fantasy']
# City of Lost Souls: ['Fantasy', 'Romance']
# The Wise Man's Fear: ['Fantasy']
# Fangirl: ['Romance']
# The Son of Neptune: ['Fantasy']
# Dead Until Dark: ['Fantasy', 'Romance', 'Horror']
# Fifty Shades Darker: ['Romance']
# Ready Player One: ['Science Fiction', 'Fantasy']
# Middlemarch: ['Romance']
# The Monster at the End of this Book: ['Fantasy']
# A Court of Mist and Fury: ['Fantasy', 'Romance']
# Bridget Jones's Diary: ['Romance']
# Mockingjay: ['Fantasy', 'Science Fiction', 'Romance']
# The Magician's Nephew: ['Fantasy']
# Stardust: ['Fantasy', 'Romance']
# The Gunslinger: ['Fantasy', 'Horror', 'Science Fiction']
# Do Androids Dream of Electric Sheep?: ['Science Fiction', 'Fantasy']
# Allegiant: ['Science Fiction', 'Fantasy', 'Romance']
# Eleanor & Park: ['Romance']
# The Lord of the Rings: ['Fantasy']
# Me Before You: ['Romance']
# The Mark of Athena: ['Fantasy', 'Romance']
# The Way of Kings: ['Fantasy']
# If I Stay: ['Romance']
# Legend: ['Science Fiction', 'Romance', 'Fantasy']
# The Witches: ['Fantasy']
# The Graveyard Book: ['Fantasy', 'Horror']
# The Complete Novels: ['Romance']
# Fifty Shades Freed: ['Romance']
# Cold Mountain: ['Romance']
# Tuck Everlasting: ['Fantasy', 'Romance']
# The Final Empire: ['Fantasy']
# Beautiful Creatures: ['Fantasy', 'Romance']
# Eldest: ['Fantasy']
# Dark Lover: ['Romance', 'Fantasy']
# The Eye of the World: ['Fantasy']
# Mansfield Park: ['Romance']
# Brisingr: ['Fantasy']
# Stargirl: ['Romance']
# Dear John: ['Romance']
# Midnight's Children: ['Fantasy']
# Obsidian: ['Fantasy', 'Romance', 'Science Fiction']
# 'Salem's Lot: ['Horror', 'Fantasy']
# The Martian Chronicles: ['Science Fiction', 'Fantasy']
# Crescendo: ['Fantasy', 'Romance']
# The English Patient: ['Romance']
# Cloud Atlas: ['Science Fiction', 'Fantasy']
# The Martian: ['Science Fiction']
# The Last Song: ['Romance']
# Shatter Me: ['Fantasy', 'Romance', 'Science Fiction']
# The Amber Spyglass: ['Fantasy', 'Science Fiction']
# Doctor Zhivago: ['Romance']
# The Hunchback of Notre-Dame: ['Romance']
# Like Water for Chocolate: ['Romance', 'Fantasy']
# Dragonfly in Amber: ['Romance', 'Fantasy']
# Breakfast of Champions: ['Science Fiction']
# Six of Crows: ['Fantasy', 'Romance']
# Harry Potter Series Box Set: ['Fantasy']
# Daughter of Smoke & Bone: ['Fantasy', 'Romance']
# City of Heavenly Fire: ['Fantasy', 'Romance']
# Evermore: ['Fantasy', 'Romance']
# The Subtle Knife: ['Fantasy', 'Science Fiction']
# 11/22/63: ['Science Fiction', 'Fantasy', 'Horror']
# Anna and the French Kiss: ['Romance']
# A Feast for Crows: ['Fantasy']
# The Angel Experiment: ['Fantasy', 'Science Fiction']
# Miss Peregrine's Home for Peculiar Children: ['Fantasy', 'Horror']
# Matched: ['Romance', 'Science Fiction', 'Fantasy']
# The Scarlet Pimpernel: ['Romance']
# Hopeless: ['Romance']
# Jonathan Strange & Mr Norrell: ['Fantasy']
# High Fidelity: ['Romance']
# Blood Meridian, or the Evening Redness in the West: ['Horror']
# Artemis Fowl: ['Fantasy', 'Science Fiction']
# The Tales of Beedle the Bard: ['Fantasy']
# The Reader: ['Romance']
# The House of Hades: ['Fantasy', 'Romance']
# Redeeming Love: ['Romance']
# The Age of Innocence: ['Romance']
# The Host: ['Science Fiction', 'Fantasy', 'Romance']
# Neuromancer: ['Science Fiction', 'Fantasy']
# Betrayed: ['Fantasy', 'Romance']
# Northanger Abbey: ['Romance']
# Lover Awakened: ['Romance', 'Fantasy']
# A Court of Thorns and Roses: ['Fantasy', 'Romance']
# Untamed: ['Fantasy', 'Romance']
# A Dance with Dragons: ['Fantasy']
# Crown of Midnight: ['Fantasy', 'Romance']
# The Twilight Collection: ['Fantasy', 'Romance']
# Carrie: ['Horror', 'Fantasy']
# Snow Falling on Cedars: ['Romance']
# Voyager: ['Romance', 'Fantasy']
# Heir of Fire: ['Fantasy', 'Romance']
# Chosen: ['Fantasy', 'Romance']
# A Room with a View: ['Romance']
# The Exorcist: ['Horror', 'Fantasy']
# Coraline: ['Fantasy', 'Horror']
# The 5th Wave: ['Science Fiction', 'Fantasy', 'Romance']
# The Iron King: ['Fantasy', 'Romance']
# Aristotle and Dante Discover the Secrets of the Universe: ['Romance']
# Torment: ['Fantasy', 'Romance']
# Bloodlines: ['Fantasy', 'Romance']
# Vanity Fair: ['Romance']
# Wizard's First Rule: ['Fantasy', 'Romance']
# North and South: ['Romance']
# Pet Sematary: ['Horror', 'Fantasy']
# Snow Crash: ['Science Fiction', 'Fantasy']
# World War Z: An Oral History of the Zombie War: ['Horror', 'Science Fiction', 'Fantasy']
# A Great and Terrible Beauty: ['Fantasy', 'Romance']
# Bared to You: ['Romance']
# The Witching Hour: ['Horror', 'Fantasy']
# The Summoning: ['Fantasy', 'Romance']
# Johnny Got His Gun: ['Horror']
# Chocolat: ['Romance', 'Fantasy']
# Halfway to the Grave: ['Romance', 'Fantasy']
# Perfect Chemistry: ['Romance']
# Red Queen: ['Fantasy', 'Romance', 'Science Fiction']
# City of Glass: ['Fantasy', 'Romance']
# The Mortal Instruments Boxed Set: City of Bones; City of Ashes; City of Glass: ['Fantasy', 'Romance']
# The Woman in White: ['Horror']
# Just Listen: ['Romance']
# 2001: A Space Odyssey: ['Science Fiction', 'Fantasy']
# The Truth About Forever: ['Romance']
# A Discovery of Witches: ['Fantasy', 'Romance']
# Much Ado About Nothing: ['Romance']
# Acheron: ['Romance', 'Fantasy']
# Lady Chatterley's Lover: ['Romance']
# Silence: ['Fantasy', 'Romance']
# The Unbecoming of Mara Dyer: ['Fantasy', 'Romance', 'Horror']
# The Return of the King: ['Fantasy']
# All the Bright Places: ['Romance']
# Far From the Madding Crowd: ['Romance']
# I Am Number Four: ['Fantasy', 'Science Fiction', 'Romance']
# Angelfall: ['Fantasy', 'Romance']
# Dead to the World: ['Fantasy', 'Romance']
# Persuasion: ['Romance']
# The Bronze Horseman: ['Romance']
# Sabriel: ['Fantasy']
# The Goose Girl: ['Fantasy', 'Romance']
# I Capture the Castle: ['Romance']
# Ignite Me: ['Fantasy', 'Romance', 'Science Fiction']
# The Darkest Minds: ['Fantasy', 'Science Fiction', 'Romance']
# Drums of Autumn: ['Romance', 'Fantasy']
# Wicked Lovely: ['Fantasy', 'Romance']
# P.S. I Love You: ['Romance']
# Queen of Shadows: ['Fantasy', 'Romance']
# Hunted: ['Fantasy', 'Romance']
# World Without End: ['Romance', 'Fantasy']
# A Christmas Carol: ['Fantasy']
# The Last Unicorn: ['Fantasy']
# Slammed: ['Romance']
# Hyperion: ['Science Fiction', 'Fantasy', 'Horror']
# The Raven Boys: ['Fantasy', 'Romance']
# Cyrano de Bergerac: ['Romance']
# Speaker for the Dead: ['Science Fiction', 'Fantasy']
# The Red Pyramid: ['Fantasy']
# We Were Liars: ['Romance']
# Anne of Avonlea: ['Romance']
# A Monster Calls: ['Fantasy', 'Horror']
# Poison Study: ['Fantasy', 'Romance']
# The Two Towers: ['Fantasy']
# The Queen of the Damned: ['Horror', 'Fantasy']
# The Eyre Affair: ['Fantasy', 'Science Fiction']
# Inheritance: ['Fantasy']
# Before I Fall: ['Romance', 'Fantasy']
# The Talisman: ['Horror', 'Fantasy', 'Science Fiction']
# Where She Went: ['Romance']
# The Knife of Never Letting Go: ['Science Fiction', 'Fantasy']
# Shadowfever: ['Fantasy', 'Romance']
# Gone: ['Science Fiction', 'Fantasy', 'Romance']
# The Blind Assassin: ['Science Fiction']
# The Scorch Trials: ['Science Fiction', 'Fantasy']
# Darkfever: ['Fantasy', 'Romance']
# The History of Love: ['Romance']
# Pretties: ['Science Fiction', 'Fantasy', 'Romance']
# Words of Radiance: ['Fantasy']
# Possession: ['Romance']
# Gravity's Rainbow: ['Science Fiction']
# I Am Legend and Other Stories: ['Horror', 'Science Fiction', 'Fantasy']
# Alanna: The First Adventure: ['Fantasy']
# One for the Money: ['Romance']
# A Wizard of Earthsea: ['Fantasy', 'Science Fiction']
# The Song of Achilles: ['Fantasy', 'Romance']
# Lover Unbound: ['Romance', 'Fantasy']
# The Haunting of Hill House: ['Horror']
# Assassin's Apprentice: ['Fantasy']
# I'll Give You the Sun: ['Romance']
# Oryx and Crake: ['Science Fiction', 'Fantasy']
# Tempted: ['Fantasy', 'Romance']
# A Breath of Snow and Ashes: ['Romance', 'Fantasy']
# Night Watch: ['Fantasy', 'Science Fiction']
# The Lies of Locke Lamora: ['Fantasy']
# Jitterbug Perfume: ['Fantasy']
# Corelli's Mandolin: ['Romance']
# I'd Tell You I Love You, But Then I'd Have to Kill You: ['Romance']
# The Fiery Cross: ['Romance', 'Fantasy']
# The Sisterhood of the Traveling Pants: ['Romance']
# Message in a Bottle: ['Romance']
# Crooked Kingdom: ['Fantasy', 'Romance']
# City of Ashes: ['Fantasy', 'Romance']
# Glass Houses: ['Fantasy', 'Romance']
# Confessions of a Shopaholic: ['Romance']
# Lover Revealed: ['Romance', 'Fantasy']
# Odd Thomas: ['Horror', 'Fantasy']
# The Edge of Never: ['Romance']
# Club Dead: ['Fantasy', 'Romance']
# Ivanhoe: ['Romance']
# Carry On: ['Fantasy', 'Romance']
# The Nightingale: ['Romance']
# Ender's Shadow: ['Science Fiction', 'Fantasy']
# Unravel Me: ['Fantasy', 'Romance', 'Science Fiction']
# Emma: ['Romance']
# Lover Avenged: ['Romance', 'Fantasy']
# The Shell Seekers: ['Romance']
# The Witch of Blackbird Pond: ['Romance']
# Living Dead in Dallas: ['Fantasy', 'Romance']
# A Canticle for Leibowitz: ['Science Fiction', 'Fantasy']
# Linger: ['Fantasy', 'Romance']
# Cryptonomicon: ['Science Fiction', 'Fantasy']
# The Portrait of a Lady: ['Romance']
# Red Rising: ['Science Fiction', 'Fantasy']
# Empire of Storms: ['Fantasy', 'Romance']
# To All the Boys I've Loved Before: ['Romance']
# The Death Cure: ['Science Fiction', 'Fantasy']
# Howards End: ['Romance']
# It's Kind of a Funny Story: ['Romance']
# Fire: ['Fantasy', 'Romance']
# The Color of Magic: ['Fantasy', 'Science Fiction']
# The Hero of Ages: ['Fantasy']
# The Moon Is a Harsh Mistress: ['Science Fiction', 'Fantasy']
# Mary Poppins: ['Fantasy']
# Finale: ['Fantasy', 'Romance']
# The Awakening: ['Fantasy', 'Romance']
# An Abundance of Katherines: ['Romance']
# The Invention of Hugo Cabret: ['Fantasy']
# The Ocean at the End of the Lane: ['Fantasy', 'Horror']
# Small Gods: ['Fantasy', 'Science Fiction']
# The Passage: ['Horror', 'Science Fiction', 'Fantasy']
# The Reckoning: ['Fantasy', 'Romance']
# Starship Troopers: ['Science Fiction', 'Fantasy']
# Ethan Frome: ['Romance']
# The Restaurant at the End of the Universe: ['Science Fiction', 'Fantasy']
# The Gargoyle: ['Fantasy', 'Romance']
# Walking Disaster: ['Romance']
# Gabriel's Inferno: ['Romance']
# Dreamfever: ['Fantasy', 'Romance']
# Around the World in Eighty Days: ['Science Fiction', 'Fantasy']
# Daughter of the Forest: ['Fantasy', 'Romance']
# The Forgotten Garden: ['Romance']
# Reflected in You: ['Romance']
# Specials: ['Science Fiction', 'Fantasy', 'Romance']
# Mort: ['Fantasy', 'Science Fiction']
# The Golden Lily: ['Fantasy', 'Romance']
# One Foot in the Grave: ['Romance', 'Fantasy']
# The Blood of Olympus: ['Fantasy', 'Romance']
# Lover Mine: ['Romance', 'Fantasy']
# Burned: ['Fantasy', 'Romance']
# Guilty Pleasures: ['Fantasy', 'Romance', 'Horror']
# The City of Ember: ['Fantasy', 'Science Fiction']
# Dead as a Doornail: ['Fantasy', 'Romance']
# Simon vs. the Homo Sapiens Agenda: ['Romance']
# Christy: ['Romance']
# The Lucky One: ['Romance']
# The Amulet of Samarkand: ['Fantasy']
# Crank: ['Romance']
# House of Leaves: ['Horror', 'Fantasy']
# Shadow and Bone: ['Fantasy', 'Romance']
# Orlando: ['Fantasy']
# A Connecticut Yankee in King Arthur's Court: ['Fantasy', 'Science Fiction']
# Beauty: A Retelling of the Story of Beauty and the Beast: ['Fantasy', 'Romance']
# Where the Heart Is: ['Romance']
# Night World, No. 1: ['Fantasy', 'Romance']
# Will Grayson, Will Grayson: ['Romance']
# On the Beach: ['Science Fiction']
# Thoughtless: ['Romance']
# The Wedding: ['Romance']
# Fablehaven: ['Fantasy']
# Easy: ['Romance']
# The Pact: ['Romance']
# The Awakening / The Struggle: ['Fantasy', 'Romance']
# Onyx: ['Romance', 'Fantasy', 'Science Fiction']
# Fantasy Lover: ['Romance', 'Fantasy']
# This Lullaby: ['Romance']
# Ugly Love: ['Romance']
# Passion: ['Fantasy', 'Romance']
# A Court of Wings and Ruin: ['Fantasy', 'Romance']
# Bitten: ['Fantasy', 'Romance']
# From Dead to Worse: ['Fantasy', 'Romance']
# Wizard and Glass: ['Fantasy', 'Horror', 'Science Fiction']
# Wings: ['Fantasy', 'Romance']
# All Together Dead: ['Fantasy', 'Romance']
# These Is My Words: The Diary of Sarah Agnes Prine, 1881-1901, Arizona Territories: ['Romance']
# Dead and Gone: ['Fantasy', 'Romance']
# Every Day: ['Romance', 'Fantasy', 'Science Fiction']
# Tiger's Curse: ['Fantasy', 'Romance']
# Safe Haven: ['Romance']
# The Iliad: ['Fantasy']
# The Ruins of Gorlan: ['Fantasy']
# Unearthly: ['Fantasy', 'Romance']
# The Well of Ascension: ['Fantasy']
# The Guardian: ['Romance']
# Along for the Ride: ['Romance']
# Dead Witch Walking: ['Fantasy', 'Romance']
# Beastly: ['Fantasy', 'Romance']
# The Far Pavilions: ['Romance']
# At Grave's End: ['Romance', 'Fantasy']
# The Man in the High Castle: ['Science Fiction', 'Fantasy']
# A Bend in the Road: ['Romance']
# Blue Bloods: ['Fantasy', 'Romance']
# The Assassin's Blade: ['Fantasy', 'Romance']
# Suzanne's Diary for Nicholas: ['Romance']
# The Taming of the Shrew: ['Romance']
# The Devil Wears Prada: ['Romance']
# An Ember in the Ashes: ['Fantasy', 'Romance']
# Anansi Boys: ['Fantasy']
# Lover Enshrined: ['Romance', 'Fantasy']
# Forbidden: ['Romance']
# The Iron Queen: ['Fantasy', 'Romance']
# Across the Universe: ['Science Fiction', 'Romance', 'Fantasy']
# Point of Retreat: ['Romance']
# Birdsong: A Novel of Love and War: ['Romance']
# Hogfather: ['Fantasy']
# Let the Right One In: ['Horror', 'Fantasy']
# Nightshade: ['Fantasy', 'Romance']
# Storm Front: ['Fantasy']
# Lock and Key: ['Romance']
# The Short Second Life of Bree Tanner: ['Fantasy', 'Romance']
# Evernight: ['Fantasy', 'Romance']
# Between Shades of Gray: ['Romance']
# Magician: ['Fantasy', 'Science Fiction']
# Dirk Gently's Holistic Detective Agency: ['Science Fiction', 'Fantasy']
# Fingersmith: ['Romance']
# The Past: ['Science Fiction', 'Fantasy']
# On Dublin Street: ['Romance']
# Cry Wolf: ['Fantasy', 'Romance']
# Swan Song: ['Horror', 'Fantasy', 'Science Fiction']
# Memnoch the Devil: ['Horror', 'Fantasy']
# The Iron Daughter: ['Fantasy', 'Romance']
# The Valley of Horses: ['Fantasy', 'Romance']
# School's Out—Forever: ['Fantasy', 'Science Fiction', 'Romance']
# Saving the World and Other Extreme Sports: ['Fantasy', 'Science Fiction', 'Romance']
# Rules of Attraction: ['Romance']
# Percy Jackson and the Olympians: ['Fantasy']
# A Darker Shade of Magic: ['Fantasy']
# Everything, Everything: ['Romance']
# Timeline: ['Science Fiction', 'Fantasy']
# Practical Magic: ['Fantasy', 'Romance']
# Blue Moon: ['Fantasy', 'Romance']
# Life, the Universe and Everything: ['Science Fiction', 'Fantasy']
# Bloodfever: ['Fantasy', 'Romance']
# Awakened: ['Fantasy', 'Romance']
# A Scanner Darkly: ['Science Fiction']
# The Way of Shadows: ['Fantasy']
# Archer's Voice: ['Romance']
# A Dirty Job: ['Fantasy', 'Horror']
# The Forty Rules of Love: ['Romance']
# Switched: ['Fantasy', 'Romance']
# A Town Like Alice: ['Romance']
# Kushiel's Dart: ['Fantasy', 'Romance']
# Inkspell: ['Fantasy']
# The Turn of the Screw: ['Horror']
# Lady Midnight: ['Fantasy', 'Romance']
# Forever: ['Fantasy', 'Romance']
# Starcrossed: ['Fantasy', 'Romance']
# Mother Night: ['Science Fiction']
# Destined for an Early Grave: ['Romance', 'Fantasy']
# The Rescue: ['Romance']
# The Tale of Genji: ['Romance']
# Nights in Rodanthe: ['Romance']
# Hearts in Atlantis: ['Horror', 'Fantasy']
# Fallen Too Far: ['Romance']
# The Day of the Triffids: ['Science Fiction', 'Horror', 'Fantasy']
# The Dragon Reborn: ['Fantasy']
# The Evolution of Mara Dyer: ['Fantasy', 'Romance', 'Horror']
# The Blade Itself: ['Fantasy']
# Needful Things: ['Horror', 'Fantasy']
# The Throne of Fire: ['Fantasy']
# On the Jellicoe Road: ['Romance']
# Going Postal: ['Fantasy', 'Science Fiction']
# The Choice: ['Romance']
# The Red and the Black: ['Romance']
# Pretty Little Liars: ['Romance']
# Under the Never Sky: ['Romance', 'Fantasy', 'Science Fiction']
# The Dead Zone: ['Horror', 'Fantasy', 'Science Fiction']
# The Complete Anne of Green Gables Boxed Set: ['Romance']
# Love, Rosie: ['Romance']
# Inkdeath: ['Fantasy']
# The Alchemyst: ['Fantasy']
# Halo: ['Fantasy', 'Romance']
# The Silver Linings Playbook: ['Romance']
# Sweet Evil: ['Fantasy', 'Romance']
# Fifty Shades Trilogy: ['Romance']
# Eclipse: ['Fantasy', 'Romance']
# Breaking Dawn: ['Fantasy', 'Romance']
# The Angel's Game: ['Fantasy']
# Garden Spells: ['Fantasy', 'Romance']
# The Immortal Rules: ['Fantasy', 'Romance']
# Anne of the Island: ['Romance']
# Losing Hope: ['Romance']
# Villette: ['Romance']
# Magic Bites: ['Fantasy', 'Romance']
# Wait for You: ['Romance']
# Rant: ['Science Fiction', 'Horror']
# The Princess Diaries: ['Romance']
# The Blue Castle: ['Romance']
# The French Lieutenant's Woman: ['Romance']
# The Tenant of Wildfell Hall: ['Romance']
# Max: ['Fantasy', 'Science Fiction', 'Romance']
# Beautiful Darkness: ['Fantasy', 'Romance']
# Stolen: A Letter to My Captor: ['Romance']
# Quo Vadis: ['Romance']
# Guards! Guards!: ['Fantasy']
# The Present: ['Science Fiction', 'Fantasy']
# Something Borrowed: ['Romance']
# Elantris: ['Fantasy', 'Romance', 'Science Fiction']
# Extras: ['Science Fiction', 'Fantasy', 'Romance']
# Perdido Street Station: ['Fantasy', 'Science Fiction', 'Horror']
# The Blue Sword: ['Fantasy', 'Romance']
# The Sky Is Everywhere: ['Romance']
# The Diamond Age: Or, A Young Lady's Illustrated Primer: ['Science Fiction', 'Fantasy']
# Rapture: ['Fantasy', 'Romance']
# Iron Kissed: ['Fantasy', 'Romance']
# Illuminae: ['Science Fiction', 'Romance', 'Fantasy']
# An Echo in the Bone: ['Romance', 'Fantasy']
# Tiger's Voyage: ['Fantasy', 'Romance']
# It Ends with Us: ['Romance']
# Ink Exchange: ['Fantasy', 'Romance']
# Fantastic Beasts and Where to Find Them: ['Fantasy']
# The Waste Lands: ['Fantasy', 'Horror', 'Science Fiction']
# The Thief Lord: ['Fantasy']
# The Serpent's Shadow: ['Fantasy']
# The Fury / Dark Reunion: ['Fantasy', 'Romance']
# New Moon: ['Fantasy', 'Romance']
# The Dream Thieves: ['Fantasy', 'Romance']
# River God: ['Fantasy', 'Romance']
# Pawn of Prophecy: ['Fantasy', 'Science Fiction']
# Burned: ['Romance']
# The Great Hunt: ['Fantasy']
# Pushing the Limits: ['Romance']
# The Warded Man: ['Fantasy']
# The Dead Girls' Dance: ['Fantasy', 'Romance']
# Days of Blood & Starlight: ['Fantasy', 'Romance']
# Impulse: ['Romance']
# Gabriel's Rapture: ['Romance']
# Old Man's War: ['Science Fiction', 'Fantasy']
# Vicious: ['Fantasy', 'Science Fiction']
# The Crystal Cave: ['Fantasy']
# The Summer I Turned Pretty: ['Romance']
# The Scorpio Races: ['Fantasy', 'Romance']
# The Cruel Prince: ['Fantasy', 'Romance']
# The Forever War: ['Science Fiction']
# The Painted Bird: ['Horror']
# Life As We Knew It: ['Science Fiction', 'Fantasy']
# The Children of Húrin: ['Fantasy']
# Can You Keep a Secret?: ['Romance']
# Hollow City: ['Fantasy', 'Horror']
# Kissed by an Angel/The Power of Love/Soulmates: ['Romance', 'Fantasy']
# Where the Crawdads Sing: ['Romance']
# The Sword of Shannara: ['Fantasy']
# The Shadow Rising: ['Fantasy']
# A Storm of Swords: Blood and Gold: ['Fantasy']
# A Voice in the Wind: ['Romance']
# The Iron Knight: ['Fantasy', 'Romance']
# Vampire Academy Collection: ['Fantasy', 'Romance']
# Reaper Man: ['Fantasy', 'Science Fiction']
# Rendezvous with Rama: ['Science Fiction']
# Entwined with You: ['Romance']
# The Opportunist: ['Romance']
# Skulduggery Pleasant: ['Fantasy']
# A Suitable Boy: ['Romance']
# Eragon, Eldest & Brisingr: ['Fantasy']
# Crossed: ['Romance', 'Science Fiction', 'Fantasy']
# Flipped: ['Romance']
# Preludes & Nocturnes: ['Fantasy', 'Horror']
# The False Prince: ['Fantasy']
# Les Liaisons dangereuses: ['Romance']
# Tomorrow, When the War Began: ['Science Fiction']
# Wallbanger: ['Romance']
# Shadow of Night: ['Fantasy', 'Romance']
# Quidditch Through the Ages: ['Fantasy']
# Boy's Life: ['Horror', 'Fantasy']
# Turtles All the Way Down: ['Romance']
# Blood Bound: ['Fantasy', 'Romance']
# Hometown Girl at Heart: ['Romance']
# The Last Wish: ['Fantasy']
# Harry Potter and the Cursed Child: Parts One and Two: ['Fantasy']
# Masquerade: ['Fantasy', 'Romance']
# The High Lord: ['Fantasy', 'Romance']
# Die for Me: ['Fantasy', 'Romance']
# Bone Crossed: ['Fantasy', 'Romance']
# Royal Assassin: ['Fantasy']
# The Gathering Storm: ['Fantasy']
# The Final Warning: ['Fantasy', 'Science Fiction', 'Romance']
# Lola and the Boy Next Door: ['Romance']
# The Great Book of Amber: ['Fantasy', 'Science Fiction']
# Fang: ['Fantasy', 'Science Fiction', 'Romance']
# Lover Unleashed: ['Romance', 'Fantasy']
# Daughter of Fortune: ['Romance']
# Keeper of the Lost Cities: ['Fantasy']
# Glass Sword: ['Fantasy', 'Romance', 'Science Fiction']
# Weaveworld: ['Fantasy', 'Horror', 'Science Fiction']
# The Magicians' Guild: ['Fantasy', 'Romance']
# The Light Between Oceans: ['Romance']
# Angels' Blood: ['Romance', 'Fantasy']
# The Sunne in Splendour: ['Romance']
# Master of the Game: ['Romance']
# The Wee Free Men: ['Fantasy']
# North and South: ['Romance']
# On the Island: ['Romance']
# As You Like It: ['Romance']
# Doomsday Book: ['Science Fiction', 'Fantasy']
# The Kill Order: ['Science Fiction', 'Fantasy']
# Lord of Misrule: ['Fantasy', 'Romance']
# The Language of Flowers: ['Romance']
# Midnight Alley: ['Fantasy', 'Romance']
# Torn: ['Fantasy', 'Romance']
# Kingdom of Ash: ['Fantasy', 'Romance']
# The Wishing Spell: ['Fantasy']
# The Demon King: ['Fantasy', 'Romance']
# The Eight: ['Fantasy', 'Romance']
# Caraval: ['Fantasy', 'Romance']
# Tigana: ['Fantasy']
# Stargazer: ['Fantasy', 'Romance']
# I Am Legend: ['Horror', 'Science Fiction', 'Fantasy']
# Circe: ['Fantasy']
# Magic Strikes: ['Fantasy', 'Romance']
# The Darkest Night: ['Romance', 'Fantasy']
# Dragonflight: ['Fantasy', 'Science Fiction', 'Romance']
# Feast of Fools: ['Fantasy', 'Romance']
# Katherine: ['Romance']
# The Power of Six: ['Fantasy', 'Science Fiction', 'Romance']
# Animal Dreams: ['Romance']
# Dead in the Family: ['Fantasy', 'Romance']
# Soulless: ['Fantasy', 'Romance']
# This Side of Paradise: ['Romance']
# The DUFF: Designated Ugly Fat Friend: ['Romance']
# The Demigod Files: ['Fantasy']
# Before I Die: ['Romance']
# Requiem: ['Romance', 'Science Fiction', 'Fantasy']
# Lirael: ['Fantasy']
# Carpe Corpus: ['Fantasy', 'Romance']
# This Man: ['Romance']
# Kindred: ['Science Fiction', 'Fantasy']
# Wither: ['Fantasy', 'Science Fiction']
# Ascend: ['Fantasy', 'Romance']
# The Black Jewels Trilogy: Daughter of the Blood, Heir to the Shadows, Queen of the Darkness: ['Fantasy', 'Romance']
# Never Fade: ['Fantasy', 'Science Fiction', 'Romance']
# Beautiful Bastard: ['Romance']
# World After: ['Fantasy', 'Romance']
# Identical: ['Romance']
# Abhorsen: ['Fantasy']
# Silver Borne: ['Fantasy', 'Romance']
# Station Eleven: ['Science Fiction', 'Fantasy']
# Rebel Angels: ['Fantasy', 'Romance']
# The Forest of Hands and Teeth: ['Horror', 'Fantasy', 'Romance', 'Science Fiction']
# The Year of the Flood: ['Science Fiction', 'Fantasy']
# Reason to Breathe: ['Romance']
# Kiss of Midnight: ['Romance', 'Fantasy']
# Ringworld: ['Science Fiction', 'Fantasy']
# Tatiana and Alexander: ['Romance']
# Uprooted: ['Fantasy', 'Romance']
# The Physician: ['Romance']
# The King of Attolia: ['Fantasy', 'Romance']
# The Young Elites: ['Fantasy', 'Romance', 'Science Fiction']
# Book of a Thousand Days: ['Fantasy', 'Romance']
# Shadowland: ['Fantasy', 'Romance']
# The Magicians: ['Fantasy']
# Ptolemy's Gate: ['Fantasy']
# Just One Day: ['Romance']
# Some Girls Bite: ['Fantasy', 'Romance']
# Wool Omnibus: ['Science Fiction', 'Fantasy']
# After Forever Ends: ['Romance', 'Fantasy']
# Eva Luna: ['Romance']
# Fragile Eternity: ['Fantasy', 'Romance']
# Lisey's Story: ['Horror', 'Fantasy', 'Romance']
# My Life Next Door: ['Romance']
# Dark Flame: ['Fantasy', 'Romance']
# The Diviners: ['Fantasy', 'Horror']
# Nightfall: ['Fantasy', 'Romance']
# Thud!: ['Fantasy', 'Science Fiction']
# The Light Fantastic: ['Fantasy', 'Science Fiction']
# A Storm of Swords: Steel and Snow: ['Fantasy']
# Chain Reaction: ['Romance']
# The Golem's Eye: ['Fantasy']
# The End of Eternity: ['Science Fiction', 'Fantasy']
# The Vampire Armand: ['Horror', 'Fantasy']
# Ghost Story: ['Horror', 'Fantasy']
# Dance with the Devil: ['Romance', 'Fantasy']
# Galápagos: ['Science Fiction', 'Fantasy']
# The Kiss of Deception: ['Fantasy', 'Romance']
# The Guardian of Secrets and Her Deathly Pact: ['Romance']
# The Sword of Summer: ['Fantasy']
# The Harry Potter Collection 1-4: ['Fantasy']
# Blood Red Road: ['Fantasy', 'Romance', 'Science Fiction']
# Splintered: ['Fantasy', 'Romance']
# The Seven Husbands of Evelyn Hugo: ['Romance']
# Leviathan: ['Fantasy', 'Science Fiction']
# The Winner's Curse: ['Fantasy', 'Romance']
# Xenocide: ['Science Fiction', 'Fantasy']
# The Earthsea Trilogy: ['Fantasy', 'Science Fiction']
# The Wrath and the Dawn: ['Fantasy', 'Romance']
# After: ['Romance']
# Faith of the Fallen: ['Fantasy', 'Romance']
# Finnikin of the Rock: ['Fantasy', 'Romance']
# Twilight: ['Fantasy', 'Romance']
# Eon: Dragoneye Reborn: ['Fantasy']
# Wives and Daughters: ['Romance']
# The Rise of Nine: ['Fantasy', 'Science Fiction', 'Romance']
# Doctor Sleep: ['Horror', 'Fantasy']
# The Testing: ['Science Fiction', 'Romance', 'Fantasy']
# The Return of the Native: ['Romance']
# To Say Nothing of the Dog: ['Science Fiction', 'Fantasy', 'Romance']
# The House at Riverton: ['Romance']
# Dreamland: ['Romance']
# The Forbidden Game: ['Fantasy', 'Romance', 'Horror']
# The Thief: ['Fantasy']
# Warbreaker: ['Fantasy', 'Romance']
# Salt to the Sea: ['Romance']
# This Girl: ['Romance']
# Nevermore: ['Fantasy', 'Romance', 'Horror']
# Amy & Roger's Epic Detour: ['Romance']
# Rise of the Evening Star: ['Fantasy']
# Night Watch: ['Fantasy', 'Horror', 'Science Fiction']
# The Fall of Hyperion: ['Science Fiction', 'Fantasy', 'Horror']
# Ship of Magic: ['Fantasy']
# Little Dorrit: ['Romance']
# Slave to Sensation: ['Romance', 'Fantasy', 'Science Fiction']
# Daddy-Long-Legs: ['Romance']
# The Sight: ['Fantasy']
# Beautiful Chaos: ['Fantasy', 'Romance']
# The Sweet Far Thing: ['Fantasy', 'Romance']
# The Coincidence of Callie & Kayden: ['Romance']
# The Long Dark Tea-Time of the Soul: ['Fantasy', 'Science Fiction']
# Someone Like You: ['Romance']
# Oathbringer: ['Fantasy']
# Lord of Chaos: ['Fantasy']
# A Song of Ice and Fire: ['Fantasy', 'Science Fiction']
# Stone of Tears: ['Fantasy', 'Romance']
# Gates of Fire: ['Fantasy']
# The Dragonbone Chair: ['Fantasy']
# Son of the Shadows: ['Fantasy', 'Romance']
# The Orb of Truth: ['Fantasy']
# Bag of Bones: ['Horror', 'Fantasy']
# Wild Magic: ['Fantasy']
# So Long, and Thanks for All the Fish: ['Science Fiction', 'Fantasy']
# Grave Mercy: ['Fantasy', 'Romance']
# The Raven King: ['Fantasy', 'Romance']
# Beyond the Shadows: ['Fantasy']
# Avalon High: ['Fantasy', 'Romance']
# Since You've Been Gone: ['Romance']
# Tangled: ['Romance']
# Making Faces: ['Romance']
# The Sword in the Stone: ['Fantasy']
# P.S. I Still Love You: ['Romance']
# Heist Society: ['Romance']
# Equal Rites: ['Fantasy', 'Science Fiction']
# Shadow's Edge: ['Fantasy']
# Enna Burning: ['Fantasy', 'Romance']
# Free Four: Tobias Tells the Divergent Knife-Throwing Scene: ['Science Fiction', 'Fantasy', 'Romance']
# The Tattooist of Auschwitz: ['Romance']
# Baby: ['Science Fiction', 'Horror', 'Fantasy']
# The Constant Princess: ['Romance']
# Shadowland: ['Fantasy', 'Romance']
# Fade Out: ['Fantasy', 'Romance']
# These Happy Golden Years: ['Romance']
# Night Play: ['Romance', 'Fantasy']
# The Novice: ['Fantasy', 'Romance']
# The Tea Rose: ['Romance']
# Raintree County: ['Romance']
# Alas, Babylon: ['Science Fiction']
# Soul Music: ['Fantasy']
# The Mummy: ['Horror', 'Fantasy', 'Romance']
# Gaudy Night: ['Romance']
# Sunshine: ['Fantasy', 'Horror', 'Romance']
# Dream Caster: ['Fantasy', 'Science Fiction']
# The Naming: ['Fantasy']
# Bitterblue: ['Fantasy', 'Romance']
# Spells: ['Fantasy', 'Romance']
# First Drop of Crimson: ['Romance', 'Fantasy']
# Leaving Paradise: ['Romance']
# The Great Alone: ['Romance']
# Seraphina: ['Fantasy', 'Romance']
# Monstrous Regiment: ['Fantasy']
# The Wicked King: ['Fantasy', 'Romance']
# Quicksilver: ['Science Fiction', 'Fantasy']
# Circus of the Damned: ['Fantasy', 'Horror', 'Romance']
# Wyrd Sisters: ['Fantasy', 'Science Fiction']
# Maybe Someday: ['Romance']
# Five Feet Apart: ['Romance']
# Willow: ['Romance']
# Magic Study: ['Fantasy', 'Romance']
# A Knight in Shining Armor: ['Romance', 'Fantasy']
# The Mammoth Hunters: ['Fantasy', 'Romance']
# At First Sight: ['Romance']
# Dark Visions: ['Fantasy', 'Romance']
# A Living Nightmare: ['Fantasy', 'Horror']
# Mateguas Island: A Novel of Horror and Suspense: ['Horror', 'Fantasy']
# The Body Finder: ['Fantasy', 'Romance']
# Blood & Spirits: ['Fantasy', 'Horror']
# The Book of Three: ['Fantasy']
# Love on the Line: ['Romance']
# Blue Moon: ['Fantasy', 'Romance', 'Horror']
# Strange the Dreamer: ['Fantasy', 'Romance']
# NOS4A2: ['Horror', 'Fantasy']
# Good in Bed: ['Romance']
# The Eternity Code: ['Fantasy', 'Science Fiction']
# Wake: ['Romance', 'Fantasy']
# What Dreams May Come: ['Fantasy', 'Romance', 'Horror', 'Science Fiction']
# Second Foundation: ['Science Fiction', 'Fantasy']
# Alice in Zombieland: ['Fantasy', 'Romance', 'Horror']
# Attachments: ['Romance']
# First Grave on the Right: ['Fantasy', 'Romance']
# La Dame aux Camélias: ['Romance']
# Trickster's Choice: ['Fantasy', 'Romance']
# Tiger's Quest: ['Fantasy', 'Romance']
# Shadow Souls: ['Fantasy', 'Romance', 'Horror']
# This Side of the Grave: ['Romance', 'Fantasy']
# Anna Dressed in Blood: ['Horror', 'Fantasy', 'Romance']
# The Fifth Elephant: ['Fantasy']
# A Million Suns: ['Science Fiction', 'Romance', 'Fantasy']
# A Northern Light: ['Romance']
# The Hobbit: Graphic Novel: ['Fantasy']
# Anathem: ['Science Fiction', 'Fantasy']
# A Conjuring of Light: ['Fantasy', 'Romance']
# The Van Alen Legacy: ['Fantasy', 'Romance']
# I've Got Your Number: ['Romance']
# The Sun Is Also a Star: ['Romance']
# Witches Abroad: ['Fantasy']
# Lightning: ['Horror', 'Science Fiction', 'Fantasy']
# Angel: ['Fantasy', 'Science Fiction', 'Romance']
# This Man Confessed: ['Romance']
# Resonance: ['Fantasy', 'Romance', 'Science Fiction']
# True Believer: ['Romance']
# Blue Lily, Lily Blue: ['Fantasy', 'Romance']
# The Burning Bridge: ['Fantasy']
# Angelfire: ['Fantasy', 'Romance']
# Fire Study: ['Fantasy', 'Romance']
# Across the Nightingale Floor: ['Fantasy', 'Romance']
# Heartless: ['Fantasy', 'Romance']
# Lover at Last: ['Romance', 'Fantasy']
# Time and Again: ['Science Fiction', 'Fantasy', 'Romance']
# Towers of Midnight: ['Fantasy']
# Revelations: ['Fantasy', 'Romance']
# Circle of Five: ['Fantasy', 'Science Fiction']
# The Gentleman's Guide to Vice and Virtue: ['Romance', 'Fantasy']
# The Fifth Season: ['Fantasy', 'Science Fiction']
# Every Which Way But Dead: ['Fantasy', 'Romance']
# The Game of Kings: ['Fantasy', 'Romance']
# The Stars My Destination: ['Science Fiction', 'Fantasy']
# Horns: ['Horror', 'Fantasy']
# A Memory of Light: ['Fantasy']
# Obsidian Butterfly: ['Fantasy', 'Romance', 'Horror']
# The Tale of the Body Thief: ['Horror', 'Fantasy']
# Never Too Far: ['Romance']
# Lies: ['Science Fiction', 'Fantasy', 'Horror']
# Replay: ['Science Fiction', 'Fantasy', 'Romance']
# Starters: ['Science Fiction', 'Fantasy', 'Romance']
# The Bone Season: ['Fantasy', 'Science Fiction', 'Romance']
# Duma Key: ['Horror', 'Fantasy']
# The Shelters of Stone: ['Fantasy', 'Romance']
# The Crimson Petal and the White: ['Romance']
# Dreams of Gods and Monsters: ['Fantasy', 'Romance']
# Wolves of the Calla: ['Fantasy', 'Horror', 'Science Fiction']
# Trickster's Queen: ['Fantasy', 'Romance']
# The Player of Games: ['Science Fiction', 'Fantasy']
# Written in My Own Heart's Blood: ['Romance', 'Fantasy', 'Science Fiction']
# The Fires of Heaven: ['Fantasy']
# Lucifer's Hammer: ['Science Fiction']
# Legend: ['Fantasy']
# Nation: ['Fantasy']
# The Forsyte Saga: ['Romance']
# Night Pleasures: ['Romance', 'Fantasy']
# The Birth of Venus: ['Romance']
# From Hell: ['Horror']
# The History of Tom Jones, a Foundling: ['Romance']
# The Summer Garden: ['Romance']
# The Good, the Bad, and the Undead: ['Fantasy', 'Romance']
# Roadside Picnic: ['Science Fiction', 'Fantasy']
# The Best of Me: ['Romance']
# Secrets of the Dragon Sanctuary: ['Fantasy']
# A Gathering of Shadows: ['Fantasy', 'Romance']
# Washington Square: ['Romance']
# The Longest Ride: ['Romance']
# Love, Stargirl: ['Romance']
# The Dark Elf Trilogy Collector's Edition: ['Fantasy']
# Dragons of Autumn Twilight: ['Fantasy']
# Wildwood Dancing: ['Fantasy', 'Romance']
# The Statistical Probability of Love at First Sight: ['Romance']
# The Mysterious Benedict Society and the Perilous Journey: ['Fantasy', 'Science Fiction']
# Memories of Ice: ['Fantasy']
# Twenties Girl: ['Romance']
# Grip of the Shadow Plague: ['Fantasy']
# Life After Life: ['Fantasy']
# The Black Prism: ['Fantasy']
# Blackwood Farm: ['Horror', 'Fantasy']
# Bet Me: ['Romance']
# Whitney, My Love: ['Romance']
# Magyk: ['Fantasy']
# The Secret Keeper: ['Romance']
# Tithe: ['Fantasy', 'Romance']
# The Immortals of Meluha: ['Fantasy']
# Siege and Storm: ['Fantasy', 'Romance']
# When You Reach Me: ['Science Fiction', 'Fantasy']
# Rosemary's Baby: ['Horror', 'Fantasy']
# Fairest: ['Fantasy', 'Romance']
# Peter and the Starcatchers: ['Fantasy']
# Silver Shadows: ['Fantasy', 'Romance']
# Blood Song: ['Fantasy']
# The Passion: ['Fantasy', 'Romance']
# An Echo in the Darkness: ['Romance']
# Fear: ['Science Fiction', 'Fantasy', 'Horror', 'Romance']
# John Dies at the End: ['Horror', 'Fantasy', 'Science Fiction']
# The Name of This Book Is Secret: ['Fantasy']
# The Plains of Passage: ['Fantasy', 'Romance']
# The Hidden Oracle: ['Fantasy']
# Written in Red: ['Fantasy', 'Romance']
# November 9: ['Romance']
# Dorothy Must Die: ['Fantasy']
# Feet of Clay: ['Fantasy']
# Tower of Dawn: ['Fantasy', 'Romance']
# The Lions of Al-Rassan: ['Fantasy', 'Romance']
# The Curse of Chalion: ['Fantasy', 'Romance', 'Science Fiction']
# Glass: ['Romance']
# Steelheart: ['Fantasy', 'Science Fiction']
# Angel: ['Fantasy', 'Romance']
# The Baron in the Trees: ['Fantasy']
# Golden Son: ['Science Fiction', 'Fantasy']
# Falling Kingdoms: ['Fantasy', 'Romance']
# Ship of Destiny: ['Fantasy']
# Thief of Time: ['Fantasy', 'Science Fiction']
# Children of Blood and Bone: ['Fantasy', 'Romance']
# Furies of Calderon: ['Fantasy']
# Dune Messiah: ['Science Fiction', 'Fantasy']
# Elsewhere: ['Fantasy', 'Romance']
# The Hero and the Crown: ['Fantasy', 'Romance']
# The Goddess Test: ['Fantasy', 'Romance']
# The Lost Colony: ['Fantasy', 'Science Fiction']
# Bird Box: ['Horror', 'Science Fiction']
# Mostly Harmless: ['Science Fiction', 'Fantasy']
# Everblaze: ['Fantasy']
# Daisy Jones & The Six: ['Romance']
# Exile: ['Fantasy']
# The Time Keeper: ['Fantasy', 'Science Fiction']
# The Alloy of Law: ['Fantasy', 'Science Fiction']
# Lover Reborn: ['Romance', 'Fantasy']
# Archangel's Kiss: ['Romance', 'Fantasy']
# The Dark Is Rising Sequence: ['Fantasy']
# Through the Ever Night: ['Romance', 'Fantasy', 'Science Fiction']
# Nevernight: ['Fantasy', 'Romance']
# Feed: ['Horror', 'Science Fiction', 'Fantasy']
# The Bear and the Nightingale: ['Fantasy']
# Hunger: ['Science Fiction', 'Fantasy', 'Horror', 'Romance']
# Embrace: ['Fantasy', 'Romance']
# Found: ['Science Fiction', 'Fantasy']
# First Test: ['Fantasy']
# Undead and Unwed: ['Romance', 'Fantasy']
# Rule: ['Romance']
# Parable of the Sower: ['Science Fiction', 'Fantasy']
# The Winter King: ['Fantasy']
# Thirst No. 1: The Last Vampire, Black Blood, and Red Dice: ['Fantasy', 'Romance']
# Green Rider: ['Fantasy', 'Romance']
# Temple of the Winds: ['Fantasy', 'Romance']
# Captive Prince: ['Fantasy', 'Romance']
# Beneath This Man: ['Romance']
# Rooftops of Tehran: ['Romance']
# Blood and Chocolate: ['Fantasy', 'Romance']
# The Bane Chronicles: ['Fantasy', 'Romance']
# Eighth Grade Bites: ['Fantasy', 'Horror']
# Heart-Shaped Box: ['Horror', 'Fantasy']
# Love Unscripted: ['Romance']
# One Grave at a Time: ['Romance', 'Fantasy']
# King's Cage: ['Fantasy', 'Romance', 'Science Fiction']
# My Soul to Take: ['Fantasy', 'Romance']
# The Strange and Beautiful Sorrows of Ava Lavender: ['Fantasy', 'Romance']
# The Arctic Incident: ['Fantasy', 'Science Fiction']
# Dead Beat: ['Fantasy']
# Spellbound in His Arms: ['Romance']
# Library of Souls: ['Fantasy', 'Horror']
# Plague: ['Science Fiction', 'Fantasy', 'Horror', 'Romance']
# Midnight: ['Fantasy', 'Romance']
# Lost Horizon: ['Fantasy', 'Science Fiction']
# Destroy Me: ['Fantasy', 'Romance', 'Science Fiction']
# The Bone People: ['Fantasy']
# Virals: ['Science Fiction', 'Fantasy']
# Prince of Thorns: ['Fantasy', 'Science Fiction']
# Let it Snow: ['Romance']
# The Beautiful and Damned: ['Romance']
# River Secrets: ['Fantasy', 'Romance']
# The Soldier's Wife: ['Romance']
# Neverseen: ['Fantasy']
# Infinity: ['Fantasy', 'Romance']
# Isla and the Happily Ever After: ['Romance']
# Taking Chances: ['Romance']
# The Winter Sea: ['Romance', 'Fantasy']
# Playing for Keeps: ['Romance']
# Kings Rising: ['Fantasy', 'Romance']
# The Killing Dance: ['Fantasy', 'Romance', 'Horror']
# Storm Born: ['Fantasy', 'Romance']
# 13 Little Blue Envelopes: ['Romance']
# Firestarter: ['Horror', 'Science Fiction', 'Fantasy']
# Enclave: ['Science Fiction', 'Fantasy', 'Romance', 'Horror']
# Everlost: ['Fantasy', 'Science Fiction']
# The Infinite Sea: ['Science Fiction', 'Fantasy', 'Romance']
# The Truth: ['Fantasy']
# Hotel on the Corner of Bitter and Sweet: ['Romance']
# The Book of Occult: ['Horror', 'Fantasy']
# The Call to Serve: ['Romance']
# Hourglass: ['Fantasy', 'Romance']
# Clockwork Angel; Clockwork Prince; Clockwork Princess: ['Fantasy', 'Romance']
# The Archived: ['Fantasy', 'Romance', 'Horror']
# Partials: ['Science Fiction', 'Fantasy', 'Romance']
# Pride and Prejudice and Zombies: ['Horror', 'Fantasy', 'Romance']
# Midnight Awakening: ['Romance', 'Fantasy']
# Thief: ['Romance']
# The Meat Market: ['Science Fiction']
# Harry Potter Collection: ['Fantasy']
# End of Days: ['Fantasy', 'Romance']
# The Book of Life: ['Fantasy', 'Romance']
# On Chesil Beach: ['Romance']
# The Hollow: ['Fantasy', 'Romance']
# The Exiled Queen: ['Fantasy', 'Romance']
# Dreamless: ['Fantasy', 'Romance']
# Le Morte d'Arthur: King Arthur and the Legends of the Round Table: ['Fantasy']
# Metro 2033: ['Science Fiction', 'Horror', 'Fantasy']
# If You Could See Me Now: ['Romance', 'Fantasy']
# The Mysterious Benedict Society and the Prisoner's Dilemma: ['Fantasy', 'Science Fiction']
# The Foundation Trilogy: ['Science Fiction', 'Fantasy']
# The Absolute Sandman, Volume One: ['Fantasy', 'Horror']
# Keys to the Demon Prison: ['Fantasy']
# The Girl With All the Gifts: ['Horror', 'Science Fiction', 'Fantasy']
# Going Too Far: ['Romance']
# Homeland: ['Fantasy']
# Sundays at Tiffany's: ['Romance', 'Fantasy']
# Never Never: ['Romance', 'Fantasy']
# Froi of the Exiles: ['Fantasy', 'Romance']
# Confessions of an Ugly Stepsister: ['Fantasy']
# Kiss of Crimson: ['Romance', 'Fantasy']
# His Majesty's Dragon: ['Fantasy']
# The Nanny Diaries: ['Romance']
# Einstein's Dreams: ['Science Fiction', 'Fantasy']
# Skinny Legs and All: ['Fantasy']
# Fool's Errand: ['Fantasy']
# Light: ['Science Fiction', 'Fantasy', 'Horror', 'Romance']
# Blood And Gold: ['Horror', 'Fantasy']
# Night Embrace: ['Romance', 'Fantasy']
# Dragon Slippers: ['Fantasy', 'Romance']
# The Two Princesses of Bamarre: ['Fantasy', 'Romance']
# The Snow Child: ['Fantasy']
# The V Girl: A Coming Of Age Story: ['Romance', 'Science Fiction']
# Circle of Friends: ['Romance']
# Night School: ['Fantasy', 'Romance']
# Best Served Cold: ['Fantasy']
# Radiant Shadows: ['Fantasy', 'Romance']
# Aztec: ['Fantasy']
# Illusions: ['Fantasy', 'Romance']
# The Amazing Maurice and His Educated Rodents: ['Fantasy']
# The Enchantress Returns: ['Fantasy']
# Entwined: ['Fantasy', 'Romance']
# Heir to the Empire: ['Science Fiction', 'Fantasy']
# Magic's Pawn: ['Fantasy', 'Romance']
# Summer Knight: ['Fantasy']
# The Slow Regard of Silent Things: ['Fantasy']
# Foundation and Empire: ['Science Fiction', 'Fantasy']
# Theft of Swords: ['Fantasy']
# Moving Pictures: ['Fantasy', 'Science Fiction']
# Fallen Crest High: ['Romance']
# Arrows of the Queen: ['Fantasy', 'Romance']
# Maurice: ['Romance']
# Going Bovine: ['Fantasy']
# Eona: The Last Dragoneye: ['Fantasy', 'Romance']
# Of Love and Other Demons: ['Romance']
# My Name Is Memory: ['Romance', 'Fantasy']
# Tiger's Destiny: ['Fantasy', 'Romance']
# Nevermore: ['Fantasy', 'Science Fiction', 'Romance']
# Eternal Kiss of Darkness: ['Romance', 'Fantasy']
# The Laughing Corpse: ['Fantasy', 'Horror', 'Romance']
# A Swiftly Tilting Planet: ['Fantasy', 'Science Fiction']
# The Storyteller: ['Romance', 'Fantasy']
# The Warrior's Apprentice: ['Science Fiction', 'Fantasy']
# Time's Arrow: ['Fantasy']
# Gabriel's Redemption: ['Romance']
# These Broken Stars: ['Science Fiction', 'Romance', 'Fantasy']
# The Sugar Queen: ['Romance', 'Fantasy']
# A Fistful of Charms: ['Fantasy', 'Romance']
# Remember Me?: ['Romance']
# Carpe Jugulum: ['Fantasy']
# Abarat: ['Fantasy', 'Horror']
# The Chrysalids: ['Science Fiction', 'Fantasy']
# The Dark Is Rising: ['Fantasy']
# Finding Cinderella: ['Romance']
# The Golem and the Jinni: ['Fantasy']
# Red Seas Under Red Skies: ['Fantasy']
# Beautiful Redemption: ['Fantasy', 'Romance']
# The City & the City: ['Fantasy', 'Science Fiction']
# Emily of New Moon: ['Romance']
# The Lover: ['Romance']
# The Child Thief: ['Fantasy', 'Horror']
# Little, Big: ['Fantasy', 'Science Fiction']
# Wolf Brother: ['Fantasy']
# The Winner's Crime: ['Fantasy', 'Romance']
# Ruin and Rising: ['Fantasy', 'Romance']
# The Sorceress: ['Fantasy']
# Children of the Mind: ['Science Fiction', 'Fantasy']
# The One and Only Ivan: ['Fantasy']
# The Woman in Black: ['Horror']
# Men at Arms: ['Fantasy']
# The Strain: ['Horror', 'Fantasy', 'Science Fiction']
# Grey: ['Romance']
# Wool: ['Science Fiction', 'Fantasy']
# I Have Never: ['Romance']
# Maskerade: ['Fantasy']
# Emperor Mage: ['Fantasy']
# The Merchant of Death: ['Fantasy', 'Science Fiction']
# The School for Good and Evil: ['Fantasy', 'Romance']
# Narcissus in Chains: ['Fantasy', 'Romance', 'Horror']
# Last Argument of Kings: ['Fantasy']
# The Queen of Nothing: ['Fantasy', 'Romance']
# Stray: ['Fantasy', 'Romance']
# Sex in the Title: A Comedy about Dating, Sex, and Romance in NYC (Back When Phones Weren't So Smart): ['Romance']
# Revenge of the Witch: ['Fantasy', 'Horror']
# Fool Moon: ['Fantasy']
# Touch of Power: ['Fantasy', 'Romance']
# Once Burned: ['Romance', 'Fantasy']
# Time Enough for Love: ['Science Fiction', 'Fantasy']
# The Retribution of Mara Dyer: ['Fantasy', 'Romance', 'Horror']
# The Ancestor: ['Science Fiction']
# Bloody Bones: ['Fantasy', 'Romance', 'Horror']
# No Rest for the Wicked: ['Romance', 'Fantasy']
# Ten Tiny Breaths: ['Romance']
# Half Bad: ['Fantasy']
# Flat-Out Love: ['Romance']
# A Court of Frost and Starlight: ['Fantasy', 'Romance']
# We'll Always Have Summer: ['Romance']
# On a Pale Horse: ['Fantasy', 'Science Fiction']
# Burnt Offerings: ['Fantasy', 'Romance', 'Horror']
# Dash & Lily's Book of Dares: ['Romance']
# The Dragonriders of Pern: ['Fantasy', 'Science Fiction']
# Kiss of Death: ['Fantasy', 'Romance']
# The Paris Wife: ['Romance']
# Jessica's Guide to Dating on the Dark Side: ['Romance', 'Fantasy']
# The Distance Between Us: ['Romance']
# The Gods Themselves: ['Science Fiction', 'Fantasy']
# Into the Wilderness: ['Romance']
# Boy Meets Boy: ['Romance']
# The Black Dagger Brotherhood: An Insider's Guide: ['Romance', 'Fantasy']
# The Distant Hours: ['Romance']
# Knife of Dreams: ['Fantasy']
# Forever Amber: ['Romance']
# Lord of Shadows: ['Fantasy', 'Romance']
# Harry Potter and the Methods of Rationality: ['Fantasy', 'Science Fiction']
# Lioness Rampant: ['Fantasy', 'Romance']
# The Island: ['Romance']
# Her Fearful Symmetry: ['Fantasy']
# Altered Carbon: ['Science Fiction', 'Fantasy']
# Lord Foul's Bane: ['Fantasy', 'Science Fiction']
# The Declaration: ['Science Fiction', 'Romance', 'Fantasy']
# Fatherland: ['Science Fiction']
# Stalking Jack the Ripper: ['Horror', 'Romance']
# Devil May Cry: ['Romance', 'Fantasy']
# Ghost Town: ['Fantasy', 'Romance']
# Tipping the Velvet: ['Romance']
# Squire: ['Fantasy']
# Changes: ['Fantasy']
# Bel-Ami: ['Romance']
# Wintersmith: ['Fantasy']
# Blood in the Skies: ['Fantasy', 'Science Fiction']
# The Mote in God's Eye: ['Science Fiction', 'Fantasy']
# North of Beautiful: ['Romance']
# The Drowned World: ['Science Fiction', 'Fantasy']
# The Rise of Mallory: ['Fantasy', 'Science Fiction']
# The Chronicle of Sapta Sindhu: ['Romance']
# The Woman Who Rides Like a Man: ['Fantasy', 'Romance']
# The Walking Dead, Vol. 1: Days Gone Bye: ['Horror', 'Fantasy']
# Lodestar: ['Fantasy']
# My Blood Approves: ['Fantasy', 'Romance']
# Y: The Last Man, Vol. 1: Unmanned: ['Science Fiction', 'Fantasy']
# Kiss an Angel: ['Romance']
# ...
# 1636: The Saxon Uprising: ['Science Fiction', 'Fantasy']
# Hellboy, Vol. 4: The Right Hand of Doom: ['Horror', 'Fantasy']
# Gift of Fire: ['Romance', 'Fantasy']
# Shadow's Fall: ['Fantasy', 'Romance']
# An English Bride in Scotland: ['Romance']
# Everblue: ['Fantasy', 'Romance']
# Night Moves : Dream Man/After the Night: ['Romance']
# 2061: Odyssey Three: ['Science Fiction', 'Fantasy']
# The Hellion: ['Romance']
# Come to Me Recklessly: ['Romance']
# The Door in the Hedge: ['Fantasy', 'Romance']
# My Little Phony: ['Romance']
# Emissary: ['Fantasy']
# Stranger in My Arms: ['Romance']
# A Twist of Fates: ['Fantasy']
# Swords Against Wizardry: ['Fantasy', 'Science Fiction']
# The Golden Barbarian: ['Romance']
# A Door in the Woods: ['Fantasy', 'Science Fiction']
# Sugar Creek: ['Romance']
# Black Blood: ['Horror', 'Fantasy', 'Romance']
# Tar Beach: ['Fantasy']
# The Huntress: ['Romance', 'Fantasy']
# Last Human: ['Science Fiction', 'Fantasy']
# Transition: ['Science Fiction', 'Fantasy']
# Hellboy: Odd Jobs: ['Horror', 'Fantasy']
# Uncharted: ['Romance']
# The Door in the Wall: ['Fantasy']
# Gift of Gold: ['Romance', 'Fantasy']
# Of Shadow Born: ['Fantasy', 'Romance']
# The Wrong Billionaire's Bed: ['Romance']
# Undertow: ['Romance']
# Frey: ['Fantasy', 'Romance']
# My Immortal Highlander: ['Romance', 'Fantasy']
# The Melody of Secrets: ['Romance']
# Sweetbriar: ['Romance']
# Spindle's End: ['Fantasy', 'Romance']
# A Tale of Two Pretties: ['Romance']
# Three: ['Romance', 'Science Fiction', 'Fantasy']
# The Redemption: ['Romance']
# Restless Waters: ['Romance']
# All Just Glass: ['Fantasy', 'Horror', 'Romance']
# A Day of Glory: ['Fantasy', 'Romance']
# Dear Mr. Knightley: ['Romance']
# Swords in the Mist: ['Fantasy', 'Science Fiction']
# Neveryóna: ['Fantasy', 'Science Fiction']
# Relentless: ['Fantasy', 'Science Fiction']
# Hellboy, Vol. 9: The Wild Hunt: ['Horror', 'Fantasy']
# Gunmetal Magic: ['Fantasy', 'Romance']
# Sabrina: ['Romance']
# Shadowflame: ['Fantasy', 'Romance']
# Running Wild: ['Romance']
# Voyage: ['Science Fiction']
# Sweet Hush: ['Romance']
# Black Butler, Vol. 4: ['Fantasy', 'Horror']
# A Bond of Blood: ['Fantasy', 'Romance']
# Immortality, Inc.: ['Science Fiction', 'Fantasy']
# Shelter for Koren: ['Romance']
# Men in Kilts: ['Romance']
# The Silver Rose: ['Romance', 'Fantasy']
# Love and Summer: ['Romance']
# Hellboy, Vol. 7: The Troll Witch and Others: ['Horror', 'Fantasy']
# The Red Hot Cajun: ['Romance']
# Cassidy: ['Romance']
# Promises After Dark: ['Romance']
# Biggest Flirts: ['Romance']
# Malafrena: ['Fantasy', 'Science Fiction']
# Collide: ['Romance', 'Fantasy', 'Science Fiction']
# The White Tree: ['Fantasy']
# The Worst Witch Strikes Again: ['Fantasy']
# Warrior's Moon: ['Romance', 'Fantasy']
# The Truth About Verity Sparks: ['Fantasy']
# The Revolution of Ivy: ['Romance', 'Science Fiction', 'Fantasy']
# Anchor in the Storm: ['Romance']
# Prince of Dreams: ['Romance']
# A Shade of Doubt: ['Fantasy', 'Romance']
# Must Love Otters: ['Romance']
# Year of the Unicorn: ['Fantasy', 'Science Fiction', 'Romance']
# The Crossbones: ['Horror']
# Hellboy: Weird Tales, Vol. 2: ['Horror', 'Fantasy']
# Tall, Dark, and Cajun: ['Romance']
# Stardust of Yesterday: ['Romance', 'Fantasy']
# Secrets After Dark: ['Romance']
# All the Queen's Men: ['Romance']
# Rise of the Lycans: ['Fantasy', 'Horror', 'Romance']
# PartnerShip: ['Science Fiction', 'Fantasy']
# Somewhere I'll Find You: ['Romance']
# Whiskey Prince: ['Romance']
# A Shade of Novak: ['Fantasy', 'Romance']
# Dark Moon of Avalon: ['Fantasy', 'Romance']
# White Light: ['Science Fiction', 'Fantasy']
# Ghost in the Machine: ['Horror']
# The Dark Queen: ['Fantasy', 'Romance']
# Personal Demons: ['Fantasy', 'Romance']
# Hellboy, Vol. 10: The Crooked Man and Others: ['Horror', 'Fantasy']
# Caradoc of the North Wind: ['Fantasy', 'Romance']
# Understand the Unknown: ['Fantasy', 'Science Fiction']
# Taboo: ['Fantasy', 'Romance']
# The Cajun Cowboy: ['Romance']
# Aelita: ['Science Fiction', 'Fantasy']
# The Worst Witch Saves the Day: ['Fantasy']
# The Eye of the World: The Graphic Novel, Volume One: ['Fantasy', 'Science Fiction']
# The Druid's Tune: ['Fantasy']
# Andromeda Klein: ['Fantasy']
# The Hacker and the Ants: ['Science Fiction']
# Once Burned: ['Science Fiction']
# The Venetian Mask: ['Romance']
# Almost Alice: ['Romance']
# The Wild Rose of Kilgannon: ['Romance']
# M.Y.T.H. Inc. Link: ['Fantasy', 'Science Fiction']
# The Iron Hunt: ['Fantasy', 'Romance']
# The Wishing Game: ['Horror']
# Heroes at Risk: ['Fantasy', 'Romance', 'Science Fiction']
# Traitor: ['Science Fiction', 'Fantasy']
# Her Good Name: ['Romance']
# Merion of the Stones: ['Fantasy', 'Romance']
# Picture Maker: ['Fantasy']
# A Virtuous Woman: ['Romance']
# The State We're In: ['Romance']
# The Worst Witch All at Sea: ['Fantasy']
# The Technician: ['Science Fiction', 'Horror']
# Generation Warriors: ['Science Fiction', 'Fantasy']
# Withering-By-Sea: ['Fantasy']
# The Ice Dragon: ['Fantasy']
# Spaceland: ['Science Fiction']
# Prime Directive: ['Science Fiction', 'Fantasy']
# The Feast of Roses: ['Romance']
# Achingly Alice: ['Romance']
# Kilgannon: ['Romance']
# Darkness Calls: ['Fantasy', 'Romance']
# Hellfire: ['Horror']
# Monster: ['Horror', 'Fantasy', 'Science Fiction']
# A Wreath of Snow: ['Romance']
# Dream Weaver: ['Fantasy', 'Science Fiction']
# The Swing in the Summerhouse: ['Fantasy']
# Passage on the Titanic: ['Romance']
# Swimming Pool Sunday: ['Romance']
# Neptune Crossing: ['Science Fiction', 'Fantasy']
# Surrender to the Will of the Night: ['Fantasy']
# Victoria Victorious: The Story of Queen Victoria: ['Romance']
# In the Arms of Mr. Darcy: ['Romance']
# A Wallflower Christmas: ['Romance']
# A Shadow of Light: ['Fantasy', 'Romance']
# Master of Space and Time: ['Science Fiction', 'Fantasy']
# The Return: ['Science Fiction']
# Wild Irish Rose: ['Romance']
# Shining Through: ['Romance']
# Family Album: ['Romance']
# Golden: A Retelling of Rapunzel: ['Fantasy', 'Romance']
# Her Officer and Gentleman: ['Romance']
# Castle: ['Fantasy', 'Science Fiction']
# Wormwood: A Collection of Short Stories: ['Horror', 'Fantasy']
# A Wild Light: ['Fantasy', 'Romance']
# Lost Souls: ['Romance']
# Chain Letter: ['Horror', 'Fantasy']
# Resenting the Hero: ['Fantasy', 'Romance']
# When the Wind Blows: ['Horror', 'Fantasy']
# The Diamond in the Window: ['Fantasy']
# The Lost Twin: ['Fantasy']
# Within These Walls: ['Horror']
# Empire of Light: ['Science Fiction', 'Fantasy']
# The City Who Fought: ['Science Fiction', 'Fantasy']
# Lord of the Silent Kingdom: ['Fantasy']
# The Trouble with Mr. Darcy: ['Romance']
# Christmas Eve at Friday Harbor: ['Romance']
# The Blessing: ['Romance']
# Deluge: ['Fantasy', 'Romance']
# Dark Mirror: ['Science Fiction', 'Fantasy']
# In Her Sights: ['Romance']
# l8r, g8r: ['Romance']
# Beauty Sleep: A Retelling of Sleeping Beauty: ['Fantasy', 'Romance']
# Page by Paige: ['Romance']
# Timeless: ['Fantasy', 'Romance']
# Gentleman of Her Dreams: ['Romance']
# The Key: ['Romance']
# Hooking Up: ['Romance']
# Side Effects May Vary: ['Romance']
# Power Lines: ['Science Fiction', 'Fantasy', 'Romance']
# The Tyranny of the Night: ['Fantasy']
# My Dearest Mr. Darcy: ['Romance']
# Fata Morgana: ['Fantasy']
# A Castle of Sand: ['Romance', 'Fantasy']
# Into the Whirlwind: ['Romance']
# A Night Like This: ['Romance']
# The Stars Are Fire: ['Romance']
# The Legend of Drizzt Boxed Set, Books 11-13: ['Fantasy']
# Heartless: ['Fantasy', 'Romance']
# Spin State: ['Science Fiction', 'Fantasy']
# Blue Fire: ['Fantasy', 'Romance']
# Beauty: ['Fantasy']
# Power Play: ['Science Fiction', 'Fantasy', 'Romance']
# She is the Darkness: ['Fantasy']
# Arena: ['Fantasy', 'Science Fiction']
# Storm of the Century: ['Horror', 'Fantasy']
# An Inconvenient Beauty: ['Romance']
# The Rock Star's Daughter: ['Romance']
# A Total Waste of Makeup: ['Romance']
# The Heritage of Hastur: ['Fantasy', 'Science Fiction']
# The Thousand Orcs: ['Fantasy']
# The Sword: ['Romance', 'Fantasy']
# Steelhands: ['Fantasy', 'Romance', 'Science Fiction']
# The Book of Blood and Shadow: ['Fantasy']
# The Shifter: ['Fantasy', 'Romance']
# In the Garden of Iden: ['Science Fiction', 'Fantasy', 'Romance']
# Fated: ['Fantasy']
# Himself: ['Fantasy']
# Penhallow: ['Romance']
# A Clash of Storms: ['Fantasy']
# An Uncommon Courtship: ['Romance']
# Software: ['Science Fiction', 'Fantasy']
# The Sum of All Kisses: ['Romance']
# My Diary from the Edge of the World: ['Fantasy']
# Shadow Bride: ['Romance']
# Myth-Nomers and Im-Pervections: ['Fantasy', 'Science Fiction']
# The Last Dragonlord: ['Fantasy', 'Romance']
# Shadow Magic: ['Fantasy']
# Hot Pursuit: ['Romance']
# Good Night, Mr. Holmes: ['Romance']
# Blood Drive: ['Fantasy', 'Romance']
# Dangerous Deception: ['Fantasy', 'Romance']
# Paradox: ['Science Fiction']
# An Elegant Façade: ['Romance']
# Jane Austen: The Complete Collection: ['Romance']
# Jakke: ['Science Fiction', 'Romance', 'Fantasy']
# The Inn at Lake Devine: ['Romance']
# Gallant Bride: ['Romance']
# Shambling Towards Hiroshima: ['Science Fiction', 'Fantasy']
# Whiplash: ['Romance']
# Inside the Illusion: ['Fantasy', 'Science Fiction']
# Dancing With Werewolves: ['Fantasy', 'Romance']
# The Watcher: ['Fantasy']
# When You Were Here: ['Romance']
# In the Time of Dragon Moon: ['Fantasy', 'Romance']
# Perfect Opposite: ['Romance']
# The Golden Transcendence: ['Science Fiction', 'Fantasy']
# Night Magic: ['Romance']
# A Lady of Esteem: ['Romance']
# The Aylesford Skull: ['Fantasy', 'Science Fiction']
# The Girl with the Make-Believe Husband: ['Romance']
# Lord John and the Hellfire Club: ['Fantasy']
# Vanishing Act: Mystery at the U.S. Open: ['Romance']
# The Captive Wife: ['Romance']
# Yankee Bride/Rebel Bride: ['Romance']
# The Search: ['Romance']
# Dispatch: ['Horror', 'Fantasy']
# The Dance of Time: ['Science Fiction', 'Fantasy']
# Prince of Hazel and Oak: ['Fantasy']
# Battle Lines: ['Fantasy', 'Horror', 'Science Fiction']
# Whisper Falls: ['Romance']
# Legacy: ['Fantasy']
# Crush Control: ['Romance']
# Going Home: ['Romance']
# Withering Hope: ['Romance']
# Folly's Bride: ['Romance']
# This Is the Way the World Ends: ['Science Fiction', 'Fantasy']
# The Fallon Blood: ['Fantasy']
# The Resort: ['Horror', 'Fantasy']
# Fortune's Stroke: ['Science Fiction', 'Fantasy']
# The Illuminator: ['Romance']
# By His Desire: ['Romance']
# Chosen: ['Fantasy', 'Romance']
# Ringworld's Children: ['Science Fiction', 'Fantasy']
# Hogwarts: An Incomplete and Unreliable Guide: ['Fantasy']
# Brain Wave: ['Science Fiction', 'Fantasy']
# For the Hope of a Crow: ['Romance', 'Fantasy']
# Exit Strategy: ['Science Fiction']
# Fables, Vol. 4: March of the Wooden Soldiers: ['Fantasy']
# From This Moment On: ['Romance', 'Fantasy']
# House of Illusions: ['Romance']
# Retribution: ['Fantasy']
# Doctor Who: Apollo 23: ['Science Fiction', 'Fantasy']
# 3001: The Final Odyssey: ['Science Fiction', 'Fantasy']
# The Ringworld Throne: ['Science Fiction', 'Fantasy']
# The Providence of Fire: ['Fantasy']
# Phule's Company: ['Science Fiction', 'Fantasy']
# Mr. Cavendish, I Presume: ['Romance']
# Looking for Jake: ['Fantasy', 'Horror', 'Science Fiction']
# Cocky Roomie: ['Romance']
# The Rosemary Tree: ['Romance']
# Vixen 03: ['Science Fiction']
# Ju-on Volume 1: ['Horror']
# A Blessing on the Moon: ['Fantasy']
# Another Chance to Dream: ['Romance', 'Fantasy']
# Treasure Box: ['Fantasy', 'Horror', 'Science Fiction']
# It Sleeps in Me: ['Romance', 'Fantasy']
# The Twelfth Transforming: ['Romance']
# Fudoki: ['Fantasy']
# Crossroads: ['Fantasy', 'Romance']
# Pamela: ['Romance']
# Minx: ['Romance']
# The Amaranth Enchantment: ['Fantasy', 'Romance']
# Only Begotten Daughter: ['Fantasy', 'Science Fiction']
# A Dance Through Time: ['Romance', 'Fantasy']
# The Book of Joby: ['Fantasy']
# Haunted: ['Fantasy', 'Romance']
# Dark Secrets: ['Romance', 'Fantasy']
# T2: Infiltrator: ['Science Fiction', 'Horror']
# From the Dust Returned: ['Fantasy', 'Horror', 'Science Fiction']
# True Confessions: ['Romance']
# The Nonesuch: ['Romance']
# Adam: ['Romance']
# A Sweet Disorder: ['Romance']
# Angel Star: ['Fantasy', 'Romance']
# Jinian Footseer: ['Fantasy', 'Science Fiction']
# The Witch of Cologne: ['Romance', 'Fantasy']
# Nobody's Angel: ['Romance']
# The Neddiad: How Neddie Took the Train, Went to Hollywood, and Saved Civilization: ['Fantasy']
# Blood Bond: ['Fantasy', 'Romance']
# Tempting the Highlander: ['Romance']
# The Female Quixote: ['Romance']
# Black Butler, Vol. 16: ['Fantasy']
# I'm In No Mood For Love: ['Romance']
# Peaches: ['Romance']
# Desiring the Highlander: ['Romance']
# The Adventures of the Stainless Steel Rat: ['Science Fiction', 'Fantasy']
# Hild: ['Fantasy']
# The Trouble With Valentine's Day: ['Romance']
# Edge of Darkness: ['Romance']
# Idol: ['Romance']
# Lovesick: ['Fantasy', 'Romance', 'Horror']
# Stranger: ['Romance']
# Hellboy: Weird Tales, Vol. 1: ['Horror', 'Fantasy']
# Joe: ['Fantasy', 'Horror']
# Seducing the Highlander: ['Romance']
# ReAwakened: ['Romance', 'Fantasy']
# Cake: ['Romance']
# Sunborn: ['Science Fiction', 'Fantasy']
# The Hallowed Hunt: ['Fantasy', 'Romance', 'Science Fiction']
# Truly Madly Yours: ['Romance']
# A Name Unknown: ['Romance']
# Wings: ['Fantasy', 'Science Fiction']
# The Chestnut Tree: ['Romance']
# Courting Magic: ['Fantasy', 'Romance']
# Zombie Lover: ['Fantasy', 'Science Fiction', 'Romance']
# ReVamped: ['Romance', 'Fantasy']
# Sweet Addiction: ['Romance']
# Short Stories from Hogwarts of Heroism, Hardship and Dangerous Hobbies: ['Fantasy']
# Swords and Ice Magic: ['Fantasy', 'Science Fiction']
# Alien Warrior: ['Science Fiction', 'Romance']
# Kilmeny of the Orchard: ['Romance']
# Little Bitty Lies: ['Romance']
# Crimson Rising: ['Science Fiction', 'Fantasy']
# The Last Forever: ['Romance']
# Archangel's Shadows: ['Romance', 'Fantasy']
# The Romance of the Forest: ['Romance']
# Xanth: The Quest for Magic: ['Fantasy', 'Science Fiction']
# Burn: ['Romance']
# Thendara House: ['Fantasy', 'Science Fiction', 'Romance']
# The Whispering Skull: ['Fantasy', 'Horror']
# Short Stories from Hogwarts of Power, Politics and Pesky Poltergeists: ['Fantasy']
# A Lady Unrivaled: ['Romance']
# Wetware: ['Science Fiction']
# Phaze Doubt: ['Fantasy', 'Science Fiction']
# Wild Blood: ['Fantasy']
# Arena Mode: ['Science Fiction', 'Fantasy']
# Courtney Crumrin and the Night Things: ['Fantasy', 'Horror']
# Tangled Up In You: ['Romance']
# The Unquiet Grave: ['Horror']
# The Quiet Gentleman: ['Romance']
# The Reluctant Duchess: ['Romance']
# Manituana: ['Romance']
# A Case of Conscience: ['Science Fiction', 'Fantasy']
# The Girl of Fire and Thorns Complete Collection: ['Fantasy', 'Romance']
# Unicorn Point: ['Fantasy', 'Science Fiction']
# HOT Pursuit: ['Romance']
# Midnight's Choice: ['Fantasy']
# Captain Vorpatril's Alliance: ['Science Fiction', 'Romance', 'Fantasy']
# The Toll-Gate: ['Romance']
# A Change in Altitude: ['Romance']
# Way Down Deep: ['Fantasy']
# The Boyfriend School: ['Romance']
# The Winter Witch: ['Fantasy', 'Romance']
# Geis of the Gargoyle: ['Fantasy', 'Science Fiction']
# Bad Boys Ahoy!: ['Romance']
# Celestra: Books 1-3: ['Fantasy']
# Nothing But Trouble: ['Romance']
# Savannah: ['Romance']
# My Life as a White Trash Zombie: ['Fantasy', 'Horror', 'Romance']
# A Robin McKinley Collection: Spindle's End, The Hero and the Crown and The Blue Sword (Folktales #1-3): ['Fantasy']
# Artistic License: ['Romance']
# Sharks & Boys: ['Romance', 'Horror']
# The Hopkins Manuscript: ['Science Fiction']
# Lighthouse: ['Romance']
# The Gap Into Madness: Chaos and Order: ['Science Fiction', 'Fantasy']
# The Vanishing Pumpkin: ['Fantasy']
# The Walls of the Universe: ['Science Fiction', 'Fantasy']
# Robot Adept: ['Fantasy', 'Science Fiction']
# The Firework-Maker's Daughter: ['Fantasy']
# See Jane Score: ['Romance']
# The Beloved Invader: ['Romance']
# The Pirates! In an Adventure with Scientists: ['Fantasy']
# Pilgrim's Inn: ['Romance']
# Trouble: ['Romance']
# Broken Universe: ['Science Fiction']
# Harpy Thyme: ['Fantasy', 'Science Fiction']
# Fiendish: ['Fantasy', 'Horror', 'Romance']
# The Basilisk’s Lair: ['Fantasy']
# The Burning Page: ['Fantasy']
# Nothing To Fear: ['Romance']
# The Gap Into Power: A Dark and Hungry God Arises: ['Science Fiction', 'Fantasy']
# Angel: After the Fall, Volume 1: ['Fantasy', 'Horror']
# Vacuum Flowers: ['Science Fiction']
# Question Quest: ['Fantasy', 'Science Fiction']
# Sweet Possession: ['Romance']
# Arafel's Saga: ['Fantasy', 'Science Fiction']
# Theodosia and the Last Pharaoh: ['Fantasy']
# Elemental: ['Fantasy', 'Romance', 'Science Fiction']
# Marked: ['Fantasy', 'Romance']
# Daughter of Helaman: ['Fantasy', 'Romance']

# %% [markdown]
# - - -

# %%
stop_words = set(stopwords.words("english"))
lemmatizer = WordNetLemmatizer()


# Define functions for text preprocessing
def preprocess_text(text):
    
    # Lower and remove numbers and punctuation
    text = text.lower()
    text = re.sub(r'[^\w\s]', '', text)
    text = re.sub(r'\d', '', text)
    text = ' '.join(text.split())
    
    # Remove stopwords
    words = text.split()
    filtered_words = [word for word in words if word not in stop_words]
    
    # Lemmatize
    lemmatized_words = [lemmatizer.lemmatize(word) for word in filtered_words]
    
    return ' '.join(lemmatized_words)


# Apply preprocessing, stop word removal, and lemmatization to each description
preprocessed_descriptions = [preprocess_text(desc) for desc in books_descriptions]

# %%
# Vectorize preprocessed book descriptions using TF-IDF
tfidf_vectorizer = TfidfVectorizer()
tfidf_matrix = tfidf_vectorizer.fit_transform(preprocessed_descriptions)

# %%
# Calculate cosine similarity between descriptions
cosine_similarities = cosine_similarity(tfidf_matrix, tfidf_matrix)

# Print the similarity matrix
print(cosine_similarities)
# Out:
# [[1.         0.         0.00828443 ... 0.00843651 0.0028751  0.02716902]
#  [0.         1.         0.         ... 0.00228359 0.01374134 0.00395555]
#  [0.00828443 0.         1.         ... 0.         0.         0.01831067]
#  ...
#  [0.00843651 0.00228359 0.         ... 1.         0.44265752 0.        ]
#  [0.0028751  0.01374134 0.         ... 0.44265752 1.         0.        ]
#  [0.02716902 0.00395555 0.01831067 ... 0.         0.         1.        ]]

# %%
similar_books_indices = cosine_similarities.argsort()[1][::-1]
print(similar_books_indices)
# Out:
# [   1   51   39 ... 6069 6067    0]

# %%
for idx in similar_books_indices:
    print(f"Similarity: {cosine_similarities[1][idx]}, Book: {books['title'][idx]}, Saga: {books['series'][idx]}")
# Out:
# Similarity: 0.9999999999999999, Book: Harry Potter and the Order of the Phoenix, Saga: Harry Potter #5
# Similarity: 0.25375004205720875, Book: Harry Potter and the Chamber of Secrets, Saga: Harry Potter #2
# Similarity: 0.23934086544813232, Book: Harry Potter and the Prisoner of Azkaban, Saga: Harry Potter #3
# Similarity: 0.18971769595368115, Book: Harry Potter Schoolbooks Box Set: Two Classic Books from the Library of Hogwarts School of Witchcraft and Wizardry, Saga: Hogwarts Library
# Similarity: 0.17918572289491363, Book: Harry Potter and the Goblet of Fire, Saga: Harry Potter #4
# Similarity: 0.17556408560699652, Book: Harry Potter and the Sorcerer's Stone, Saga: Harry Potter #1
# Similarity: 0.14977091491764954, Book: Hogwarts: An Incomplete and Unreliable Guide, Saga: Pottermore Presents #3
# Similarity: 0.14432880745876467, Book: Fantastic Beasts and Where to Find Them, Saga: Hogwarts Library
# Similarity: 0.14335834779468395, Book: Harry Potter and the Half-Blood Prince, Saga: Harry Potter #6
# Similarity: 0.13594504831351217, Book: Harry Potter Collection, Saga: Harry Potter #1-6
# Similarity: 0.1330939943843809, Book: The Harry Potter Collection 1-4, Saga: Harry Potter #1-4
# Similarity: 0.12899809954350225, Book: Fantastic Beasts - The Crimes of Grindelwald: The Original Screenplay, Saga: Fantastic Beasts: The Original Screenplay #2
# Similarity: 0.12897385274685086, Book: Harry Potter Boxed Set, Books 1-5 (Harry Potter, #1-5), Saga: No
# Similarity: 0.1273113354229758, Book: The First Fifteen Lives of Harry August, Saga: No
# Similarity: 0.1270367307244216, Book: Quidditch Through the Ages, Saga: Hogwarts Library
# Similarity: 0.12458446881469089, Book: James Potter and the Morrigan Web, Saga: James Potter #4
# Similarity: 0.11371105700493528, Book: Harry Potter: A Pop-Up Book: Based on the Film Phenomenon, Saga: No
# Similarity: 0.11238494466740498, Book: The Harry Potter trilogy, Saga: Harry Potter #1-3
# Similarity: 0.10885334273488376, Book: Harry Potter and the Cursed Child: Parts One and Two, Saga: Harry Potter #8
# Similarity: 0.10625922022127471, Book: James Potter and the Hall of Elders' Crossing, Saga: James Potter #1
# Similarity: 0.10210550238288252, Book: Short Stories from Hogwarts of Power, Politics and Pesky Poltergeists, Saga: Pottermore Presents #2
# Similarity: 0.08971605409681019, Book: Harry Potter and the Methods of Rationality, Saga: Harry Potter and the Methods of Rationality
# Similarity: 0.08801167404217543, Book: Small Favor, Saga: The Dresden Files #10
# Similarity: 0.0877610624878519, Book: The Leopard Prince, Saga: Princes #2
# Similarity: 0.08746669082835754, Book: Harry Potter Series Box Set, Saga: Harry Potter #1-7
# Similarity: 0.08641973408658961, Book: The Magical Worlds Of Harry Potter: A Treasury Of Myths, Legends And Fascinating Facts, Saga: No
# Similarity: 0.08593645945069722, Book: Flyaway, Saga: No
# Similarity: 0.08554445266623384, Book: The Hogwarts Library, Saga: Hogwarts Library
# Similarity: 0.08450129349132623, Book: Harry Potter: A History of Magic, Saga: Harry Potter: A History of Magic Exhibition
# Similarity: 0.08195327630397972, Book: As You Desire, Saga: Braxton #1
# Similarity: 0.08188097354581207, Book: Death Masks, Saga: The Dresden Files #5
# Similarity: 0.0788073783155532, Book: Dead Beat, Saga: The Dresden Files #7
# Similarity: 0.07825841535530773, Book: Proven Guilty, Saga: The Dresden Files #8
# Similarity: 0.07770200650117079, Book: Ghost Story, Saga: The Dresden Files #13
# Similarity: 0.0773410947665919, Book: Summer Knight, Saga: The Dresden Files #4
# Similarity: 0.07732687721922529, Book: James Potter and the Curse of the Gatekeeper, Saga: James Potter #2
# Similarity: 0.07642131131663434, Book: Courting Miss Lancaster, Saga: The Lancaster Family #2
# Similarity: 0.0757315937974621, Book: The Heaven Tree Trilogy, Saga: Heaven Tree #1-3
# Similarity: 0.07561784120160571, Book: James Potter and the Vault of Destinies, Saga: James Potter #3
# Similarity: 0.07442475827917787, Book: Blood Rites, Saga: The Dresden Files #6
# Similarity: 0.07286726019723305, Book: The Bottoms, Saga: No
# Similarity: 0.07033662001145446, Book: Rhythm, Chord & Malykhin, Saga: No
# Similarity: 0.06956691452832517, Book: The Thirteenth, Saga: Vampire Huntress #12
# Similarity: 0.06845134474121907, Book: Necroscope, Saga: Necroscope #1
# Similarity: 0.06741246059651664, Book: Master of Space and Time, Saga: No
# Similarity: 0.06664432388151365, Book: Peace Talks, Saga: The Dresden Files #16
# Similarity: 0.06547643798629502, Book: White Night, Saga: The Dresden Files #9
# Similarity: 0.0653464132951003, Book: Fool Moon, Saga: The Dresden Files #2
# Similarity: 0.0652698611488953, Book: The Corridor, Saga: The Corridor #1
# Similarity: 0.06519892991234569, Book: The Heaven Tree, Saga: Heaven Tree #1
# Similarity: 0.06486156999207514, Book: No Highway, Saga: No
# Similarity: 0.06486070192866085, Book: You Don't Know Jack, Saga: Sexy in NYC #2
# Similarity: 0.06460139891621003, Book: The Mind Games, Saga: Mind Readers #3
# Similarity: 0.06454734998298535, Book: The Lost Scrolls, Saga: Tennis Shoes #6
# Similarity: 0.06436076875060065, Book: Welcome to the Jungle, Saga: The Dresden Files Graphic Novels #0.5
# Similarity: 0.06417443857681421, Book: The Third Door, Saga: The Three Doors Trilogy #3
# Similarity: 0.06360014871386102, Book: Singularity, Saga: No
# Similarity: 0.06291784948589427, Book: Turn, Saga: Turn!verse #1
# Similarity: 0.062228688547494734, Book: Dairy Queen, Saga: Dairy Queen #1
# Similarity: 0.06207937856138354, Book: Harry Potter and the Deathly Hallows, Saga: Harry Potter #7
# Similarity: 0.06109576317253182, Book: The Last Dark, Saga: The Last Chronicles of Thomas Covenant #4
# Similarity: 0.060981110137625257, Book: His Captive Lady, Saga: Devil Riders #2
# Similarity: 0.06082913430796891, Book: The Splendour Falls, Saga: No
# Similarity: 0.060778999174238096, Book: Sweet Nothing, Saga: No
# Similarity: 0.06047892251640882, Book: Haunted, Saga: David Ash #1
# Similarity: 0.060441914150663904, Book: Working for Bigfoot, Saga: The Dresden Files #11.8
# Similarity: 0.05956153757784406, Book: Tempt Me at Twilight, Saga: The Hathaways #3
# Similarity: 0.05946422006515715, Book: Sweetest Taboo, Saga: Sweetest Taboo #1
# Similarity: 0.05934001087147027, Book: Island of Dragons, Saga: Unwanteds #7
# Similarity: 0.05862726792949038, Book: Sweep: Volume 3, Saga: Wicca #7-9
# Similarity: 0.058555703866636735, Book: The Midnight Palace, Saga: Niebla #2
# Similarity: 0.05799331027110577, Book: 11/22/63, Saga: No
# Similarity: 0.057695499620315914, Book: Bullet, Saga: Anita Blake, Vampire Hunter #19
# Similarity: 0.05760186434244021, Book: The Girl in the Clockwork Collar, Saga: Steampunk Chronicles #2
# Similarity: 0.05726709955074103, Book: Nightmares!, Saga: Nightmares! #1
# Similarity: 0.05714845642394888, Book: The Turn of the Screw, Saga: No
# Similarity: 0.05708669019578886, Book: The End, Saga: The Enemy #7
# Similarity: 0.056925952854702914, Book: Short Stories from Hogwarts of Heroism, Hardship and Dangerous Hobbies, Saga: Pottermore Presents #1
# Similarity: 0.05686817483280153, Book: Untamed, Saga: House of Night #4
# Similarity: 0.05673188842245184, Book: The Right Hand of Evil, Saga: No
# Similarity: 0.056588167872999674, Book: Hopeless Magic, Saga: Star-Crossed #2
# Similarity: 0.05614921329914032, Book: Changes, Saga: The Dresden Files #12
# Similarity: 0.05613599723637128, Book: A Dark Dividing, Saga: No
# Similarity: 0.05570094676476353, Book: Feast of Souls, Saga: The Magister Trilogy #1
# Similarity: 0.05539045604352726, Book: Restoration of Faith, Saga: The Dresden Files #0.1
# Similarity: 0.05511715950084016, Book: Canary, Saga: No
# Similarity: 0.05486541119130985, Book: The Spanish Bride, Saga: No
# Similarity: 0.05446657676612871, Book: Wake, Saga: Watersong #1
# Similarity: 0.05434665211967904, Book: Indulge, Saga: Warm Delicacy #2
# Similarity: 0.05421960652587579, Book: Nightfall, Saga: No
# Similarity: 0.05359037306551637, Book: When Lightning Strikes, Saga: No
# Similarity: 0.05354813013826522, Book: The Door to December, Saga: No
# Similarity: 0.05351638965980687, Book: Fallout: Equestria, Saga: Fallout: Equestria
# Similarity: 0.053004611811317555, Book: In The Afterlight, Saga: The Darkest Minds #3
# Similarity: 0.05278280038380245, Book: Pretty Girl-13, Saga: No
# Similarity: 0.0524047375153082, Book: Vignette, Saga: The Dresden Files #5.5
# Similarity: 0.052281764442183735, Book: Secret Lives, Saga: Darke Academy #1
# Similarity: 0.05216817395225908, Book: Torn, Saga: Trylle #2
# Similarity: 0.05211417988918525, Book: Earth Afire, Saga: The First Formic War #2
# Similarity: 0.05201260328077972, Book: Unsouled, Saga: Cradle #1
# Similarity: 0.051908982939382384, Book: The Concubine, Saga: No
# Similarity: 0.05186072545311144, Book: Acceleration, Saga: No
# Similarity: 0.05119573558435087, Book: Harry Potter: The Prequel, Saga: Harry Potter #0.5
# Similarity: 0.05108407526082215, Book: Necroscope III: The Source, Saga: Necroscope #3
# Similarity: 0.050975860638016374, Book: The Summer of Skinny Dipping, Saga: Summer #1
# Similarity: 0.050697289978970654, Book: Finding Cinderella, Saga: Hopeless #2.5
# Similarity: 0.050683130133663254, Book: Good Girls, Saga: No
# Similarity: 0.05063870304516464, Book: The Little Lady Agency, Saga: The Little Lady Agency #1
# Similarity: 0.05048649402451282, Book: The Arabian Nights: Tales of 1001 Nights, Volume 1 of 3, Saga: No
# Similarity: 0.05040368930390836, Book: Island of Legends, Saga: Unwanteds #4
# Similarity: 0.050238649058812146, Book: A Place Called Winter, Saga: No
# Similarity: 0.050079550218625715, Book: Underworld: Evolution, Saga: Underworld #3
# Similarity: 0.04973907211457432, Book: Storm Front, Saga: The Dresden Files #1
# Similarity: 0.04926654970679635, Book: Talisman Of El, Saga: Arcadia Saga #1
# Similarity: 0.0492189506236358, Book: The Rocker That Holds Her, Saga: The Rocker #5
# Similarity: 0.0492189506236358, Book: The Rocker That Holds Her, Saga: The Rocker #5
# Similarity: 0.049204442201947494, Book: The Siren Song, Saga: The Cronus Chronicles #2
# Similarity: 0.04918380946363265, Book: Negima! Magister Negi Magi, Vol. 2, Saga: Negima! Magister Negi Magi #2
# Similarity: 0.04917781122754587, Book: Johnny Got His Gun, Saga: No
# Similarity: 0.04916634781301561, Book: The Back Door of Midnight, Saga: Dark Secrets #5
# Similarity: 0.049098559929766764, Book: Lodestar, Saga: Keeper of the Lost Cities #5
# Similarity: 0.049092294678535375, Book: Phaze Doubt, Saga: Apprentice Adept #7
# Similarity: 0.04909024839109496, Book: Of Love and Evil, Saga: The Songs of the Seraphim #2
# Similarity: 0.04905222817052037, Book: Dark Wolf, Saga: Dark #22
# Similarity: 0.04903724146254188, Book: If Only It Were True, Saga: Et si c'était vrai #1
# Similarity: 0.048822316497699, Book: Ransom, Saga: No
# Similarity: 0.048799342736195, Book: The Archived, Saga: The Archived #1
# Similarity: 0.048690304100067514, Book: The Age of Miracles, Saga: No
# Similarity: 0.04867211787302351, Book: Born of Defiance, Saga: The League: Nemesis Rising #7
# Similarity: 0.04858218060454706, Book: The Dead-Tossed Waves, Saga: The Forest of Hands and Teeth #2
# Similarity: 0.048335491472818126, Book: Taste of Darkness, Saga: Healer #3
# Similarity: 0.04818655954948982, Book: The Pleasure Master, Saga: No
# Similarity: 0.04798959317658068, Book: Awakening, Saga: A New World #5
# Similarity: 0.047857902290735346, Book: The Killing Dance, Saga: Anita Blake, Vampire Hunter #6
# Similarity: 0.04775672865650629, Book: A Certain Slant of Light, Saga: Light #1
# Similarity: 0.047526382771854975, Book: Grave Peril, Saga: The Dresden Files #3
# Similarity: 0.04750952658585457, Book: Bitten, Saga: Dangerous Girls #1-2
# Similarity: 0.0474554259428186, Book: Cold Days, Saga: The Dresden Files #14
# Similarity: 0.047425284822623315, Book: Bones of the Moon, Saga: Answered Prayers #1
# Similarity: 0.04739056361398655, Book: Life Expectancy, Saga: No
# Similarity: 0.047124985950703274, Book: Fantastic Beasts and Where to Find Them: The Original Screenplay, Saga: Fantastic Beasts: The Original Screenplay #1
# Similarity: 0.04707319743609796, Book: Geography Club, Saga: Russel Middlebrook #1
# Similarity: 0.04697979305044153, Book: Oblivion, Saga: Lux #1.5
# Similarity: 0.04696159016526316, Book: Same Difference, Saga: No
# Similarity: 0.0469580260581311, Book: Oblivion, Saga: Lux #1.5, 2.5, 3.5
# Similarity: 0.046876599497171316, Book: Presence, Saga: Presence #1
# Similarity: 0.0467614749627159, Book: The Dreamer, Saga: Dreamland #1
# Similarity: 0.04646996476667353, Book: The Dream Merchant, Saga: No
# Similarity: 0.04643463241056578, Book: Cheat the Grave, Saga: Signs of the Zodiac #5
# Similarity: 0.04591392348334084, Book: Fortune's Pawn, Saga: Paradox #1
# Similarity: 0.045854054963235205, Book: Indian Hill, Saga: Indian Hill #1
# Similarity: 0.045839468579350555, Book: Vows, Saga: No
# Similarity: 0.04564725592072292, Book: From Willa, With Love, Saga: Wedding Planner's Daughter #6
# Similarity: 0.045638467263727084, Book: The Age of Odin, Saga: Pantheon #3
# Similarity: 0.04536225147515615, Book: Malice, Saga: The Faithful and the Fallen #1
# Similarity: 0.04533520525163991, Book: A Cottage by the Sea, Saga: No
# Similarity: 0.045313585528739875, Book: The Drowned Cities, Saga: Ship Breaker #2
# Similarity: 0.04529604926989052, Book: House of Secrets, Saga: House of Secrets #1
# Similarity: 0.0449739305534175, Book: Emily Windsnap and the Land of the Midnight Sun, Saga: Emily Windsnap #5
# Similarity: 0.044945901560897936, Book: Gates of Paradise, Saga: Blue Bloods #7
# Similarity: 0.04489634641133311, Book: Texas Pride, Saga: No
# Similarity: 0.04483742582129962, Book: Two Summers, Saga: No
# Similarity: 0.04481793078062371, Book: Lady of Milkweed Manor, Saga: No
# Similarity: 0.04469457023899857, Book: Skin Game, Saga: The Dresden Files #15
# Similarity: 0.04467121560406319, Book: Sleep, Pale Sister, Saga: No
# Similarity: 0.04466187527173866, Book: The Gemini Effect, Saga: No
# Similarity: 0.04465218084929342, Book: Independent Study, Saga: The Testing #2
# Similarity: 0.044588509290317886, Book: The Extraordinary Secrets of April, May, & June, Saga: No
# Similarity: 0.04428213597832849, Book: And Then He Kissed Her, Saga: Girl Bachelors #1
# Similarity: 0.044188791438194173, Book: The Golden Key, Saga: Golden Key #1
# Similarity: 0.04411872233561349, Book: The Midnight Mayor, Saga: Matthew Swift #2
# Similarity: 0.044111498892932706, Book: The Forbidden Game, Saga: The Forbidden Game #1-3
# Similarity: 0.04403173674796624, Book: What Happens in London, Saga: Bevelstoke #2
# Similarity: 0.043988644859226204, Book: Matilda, Saga: No
# Similarity: 0.04391116606942369, Book: A Fire Upon the Deep, Saga: Zones of Thought #1
# Similarity: 0.04382282037710733, Book: Friends With Boys, Saga: No
# Similarity: 0.043721942115924714, Book: Wasteland, Saga: Wasteland #1
# Similarity: 0.04372145165101564, Book: Frostbite, Saga: The Dragonian #3
# Similarity: 0.043672015028635346, Book: Lord of the Dead, Saga: No
# Similarity: 0.043603209373263174, Book: Wait, Saga: Bleeding Stars #4
# Similarity: 0.04357666424332544, Book: The Archmage Unbound, Saga: Mageborn #3
# Similarity: 0.0435681928322315, Book: Fury of the Phoenix, Saga: Kingdom of Xia (Phoenix) #2
# Similarity: 0.04353853496782841, Book: Things Grak Hates, Saga: No
# Similarity: 0.04349855428105297, Book: Shadow Me, Saga: Shatter Me #4.5
# Similarity: 0.043490946289739506, Book: The Loners, Saga: Quarantine #1
# Similarity: 0.04340947108841714, Book: The Fires of Merlin, Saga: Merlin #3
# Similarity: 0.04331288380429926, Book: Turn Coat, Saga: The Dresden Files #11
# Similarity: 0.043119845910164156, Book: Blindsight, Saga: Firefall #1
# Similarity: 0.04293548881023774, Book: Kiss of Crimson, Saga: Midnight Breed #2
# Similarity: 0.04292890665895125, Book: Academ's Fury, Saga: Codex Alera #2
# Similarity: 0.042898343104570205, Book: Nobody, Saga: No
# Similarity: 0.04284874456093622, Book: Legacy of Kings, Saga: The Magister Trilogy #3
# Similarity: 0.04275696838390395, Book: The Price of Valour, Saga: The Shadow Campaigns #3
# Similarity: 0.042749134997457125, Book: Elites of Eden, Saga: Children of Eden #2
# Similarity: 0.04253325474032767, Book: The Golden Transcendence, Saga: The Golden Oecumene #3
# Similarity: 0.04250947254379541, Book: It Happened at the Fair, Saga: It Happened at the Fair #1
# Similarity: 0.04248543827250797, Book: The Way I Used to Be, Saga: No
# Similarity: 0.042437873352047954, Book: The Royal Ranger: A New Beginning, Saga: Ranger's Apprentice: The Royal Ranger #1
# Similarity: 0.04227990035473395, Book: The Left Hand of God, Saga: The Left Hand of God #1
# Similarity: 0.04225443285766766, Book: Eerie, Saga: No
# Similarity: 0.04223399859059234, Book: Insomnia, Saga: The Night Walkers #1
# Similarity: 0.042223867009431815, Book: Blood Prophecy, Saga: Drake Chronicles #6
# Similarity: 0.04221672758075515, Book: Three Wishes, Saga: No
# Similarity: 0.042184951987785005, Book: The Sign, Saga: No
# Similarity: 0.042112856399254585, Book: Any Which Wall, Saga: No
# Similarity: 0.04204412178490189, Book: Fire by Night, Saga: Refiner's Fire #2
# Similarity: 0.04204142762245641, Book: Joe, Saga: Joe #1
# Similarity: 0.04203581809769584, Book: Betrothed, Saga: Betrothed #1
# Similarity: 0.0420026671649122, Book: Aberrant, Saga: Aberrant #1
# Similarity: 0.0418733500167754, Book: Courting Magic, Saga: Kat, Incorrigible #4
# Similarity: 0.04182068640157835, Book: Assassin's Creed: Renaissance, Saga: Assassin's Creed #1
# Similarity: 0.04177003034547058, Book: The King's Buccaneer, Saga: Krondor's Sons #2
# Similarity: 0.041714794230391435, Book: Tunnel in the Sky (Heinlein's Juveniles, #9), Saga: No
# Similarity: 0.04156512503251336, Book: Remembering the Titanic, Saga: Titanic #2
# Similarity: 0.041546042468410274, Book: Discount Armageddon, Saga: InCryptid #1
# Similarity: 0.041475694256274453, Book: Shadow of Night, Saga: All Souls Trilogy #2
# Similarity: 0.04146440831517423, Book: Overruled, Saga: The Legal Briefs #1
# Similarity: 0.041464381380364776, Book: Lord of the Fading Lands, Saga: Tairen Soul #1
# Similarity: 0.041446029403717936, Book: The Court of the Air, Saga: Jackelian #1
# Similarity: 0.041431532337925396, Book: The Book of Blood and Shadow, Saga: No
# Similarity: 0.04142883939607705, Book: Crown of Crystal Flame, Saga: Tairen Soul #5
# Similarity: 0.04137819264386457, Book: Infatuate, Saga: Gilded Wings #2
# Similarity: 0.04136275317061147, Book: Angelfire, Saga: Angelfire #1
# Similarity: 0.04132583369528525, Book: Betrayed, Saga: The Vampire Journals #3
# Similarity: 0.04127328498976035, Book: Much Ado About Magic, Saga: Enchanted, Inc. #5
# Similarity: 0.040922721717722724, Book: Naked Empire, Saga: Sword of Truth #8
# Similarity: 0.040918875352802864, Book: Dreaming Anastasia, Saga: Dreaming Anastasia #1
# Similarity: 0.04091513199887042, Book: Endless Magic, Saga: Star-Crossed #4
# Similarity: 0.04090781592447447, Book: The Bunker Diary, Saga: No
# Similarity: 0.04087081855479297, Book: The Enchantress Returns, Saga: The Land of Stories #2
# Similarity: 0.040707359670133156, Book: Just Friends, Saga: Friends #1
# Similarity: 0.0406685339631804, Book: The Slow Regard of Silent Things, Saga: The Kingkiller Chronicle #2.5
# Similarity: 0.040547297170678356, Book: Where Dreams Descend, Saga: Kingdom of Cards #1
# Similarity: 0.040529041922683674, Book: Don't Look Back, Saga: No
# Similarity: 0.040446340296443645, Book: A Charming Magic, Saga: Magical Cures Mystery #5
# Similarity: 0.04038146259823248, Book: Blackout, Saga: Newsflesh #3
# Similarity: 0.040336784326198374, Book: Red Prophet, Saga: Tales of Alvin Maker #2
# Similarity: 0.04027828645519443, Book: Lies & Omens, Saga: Shadows Inquiries #4
# Similarity: 0.04013004539311093, Book: Fear Nothing, Saga: Moonlight Bay #1
# Similarity: 0.04008485083674525, Book: Obsidian, Saga: Lux #1
# Similarity: 0.040075174265941114, Book: Most of All You, Saga: No
# Similarity: 0.040005983428402184, Book: Song for the Basilisk, Saga: No
# Similarity: 0.03993982315005614, Book: The Friend Zone, Saga: The Friend Zone #1
# Similarity: 0.03988354042815369, Book: The Resistance, Saga: The Declaration #2
# Similarity: 0.0398440934675003, Book: Tower of Thunder, Saga: Tennis Shoes #9
# Similarity: 0.03981465655958537, Book: Whisper Falls, Saga: Destiny #3
# Similarity: 0.03972070680075263, Book: The Bone Labyrinth, Saga: Sigma Force #11
# Similarity: 0.039646645292277946, Book: Love Bites, Saga: Argeneau #2
# Similarity: 0.03959136405038857, Book: Lullaby, Saga: Watersong #2
# Similarity: 0.03958679928480034, Book: The Unloved, Saga: No
# Similarity: 0.03953409206804492, Book: Breaking Nova, Saga: Nova #1
# Similarity: 0.03952675912421216, Book: The Unsuspecting Mage, Saga: The Morcyth Saga #1
# Similarity: 0.039493347415015874, Book: Deeper, Saga: No
# Similarity: 0.03942685635998087, Book: The Emperor of Evening Stars, Saga: The Bargainer #2.5
# Similarity: 0.03940308148009577, Book: Demon Road, Saga: Demon Road #1
# Similarity: 0.0393456793622574, Book: Hellfire, Saga: No
# Similarity: 0.0393451194199803, Book: Race to the Sun, Saga: No
# Similarity: 0.03934435144807212, Book: Book of Shadows, Saga: Wicca #1
# Similarity: 0.0393227735459519, Book: A Stir of Echoes, Saga: No
# Similarity: 0.03930741671174112, Book: Tales of Terror from the Black Ship, Saga: Tales of Terror #2
# Similarity: 0.039284771867080376, Book: Breadcrumbs, Saga: No
# Similarity: 0.03922856370157749, Book: The Sword of Truth, Boxed Set III: The Pillars of Creation, Naked Empire, Chainfire, Saga: Sword of Truth #7-9
# Similarity: 0.039196109233323374, Book: Angelic, Saga: Otherworld Stories #9.3
# Similarity: 0.03906519585694913, Book: The Magicians Trilogy Boxed Set, Saga: The Magicians #1-3
# Similarity: 0.03902889896055667, Book: The Taming of the Tights, Saga: The Misadventures of Tallulah Casey #3
# Similarity: 0.03892365740868949, Book: Page by Paige, Saga: No
# Similarity: 0.03886644760302099, Book: The Gorgon's Gaze, Saga: The Companions Quartet #2
# Similarity: 0.03871754659371655, Book: Trials of Death, Saga: Cirque du Freak #5
# Similarity: 0.0387015410849372, Book: The Assassin and the Desert, Saga: Throne of Glass #0.3
# Similarity: 0.038651306269303146, Book: The Everafter War, Saga: The Sisters Grimm #7
# Similarity: 0.038598692752457774, Book: Princess Ben, Saga: No
# Similarity: 0.03846147601052813, Book: Boundless, Saga: Unearthly #3
# Similarity: 0.03845950870047169, Book: Stars, Saga: Wendy Darling #1
# Similarity: 0.038450010347713684, Book: Tris's Book, Saga: Circle of Magic #2
# Similarity: 0.03838532687449504, Book: Dayworld, Saga: Dayworld #1
# Similarity: 0.03838417670854823, Book: The Purge of Babylon, Saga: Purge of Babylon #1
# Similarity: 0.03835107641897208, Book: Pillow Talk, Saga: No
# Similarity: 0.03834206466430962, Book: The Peace War, Saga: Across Realtime #1
# Similarity: 0.03828798089385822, Book: Shadow Bound, Saga: Shadow #1
# Similarity: 0.038240680478866, Book: The Tyranny of the Night, Saga: Instrumentalities of the Night #1
# Similarity: 0.03818240456331794, Book: Drizzle, Saga: No
# Similarity: 0.03812732064841804, Book: Level 7, Saga: No
# Similarity: 0.0381017555679042, Book: True Colors, Saga: Star Wars: Republic Commando #3
# Similarity: 0.03805551186881991, Book: The Ruins of Ambrai, Saga: Exiles #1
# Similarity: 0.0380414015825233, Book: Damaged, Saga: Damaged #1
# Similarity: 0.03803490918209748, Book: Shades of Midnight, Saga: Midnight Breed #7
# Similarity: 0.038001862103035786, Book: Goddess Interrupted, Saga: Goddess Test #2
# Similarity: 0.03796551029879208, Book: How to Stop Time, Saga: No
# Similarity: 0.03795510405139297, Book: OCD Love Story, Saga: No
# Similarity: 0.03784682096984767, Book: The Secret of Ella and Micha, Saga: The Secret #1
# Similarity: 0.0378429485922297, Book: John Dies at the End, Saga: John Dies at the End #1
# Similarity: 0.03782257689289383, Book: Finding the Fox, Saga: The Shapeshifter #1
# Similarity: 0.03782166828545314, Book: The Song of David, Saga: The Law of Moses #2
# Similarity: 0.037745212478143456, Book: RoomHate, Saga: No
# Similarity: 0.03774071443251773, Book: Don't Breathe a Word, Saga: No
# Similarity: 0.0377159610519085, Book: Deadline, Saga: No
# Similarity: 0.037676433818539246, Book: Children of Eden, Saga: Children of Eden #1
# Similarity: 0.03762242030611884, Book: Shadow and Bone, Saga: The Shadow and Bone Trilogy #1
# Similarity: 0.03759315423424901, Book: Side Jobs, Saga: The Dresden Files #12.5
# Similarity: 0.0375534321045659, Book: Spirit Bound, Saga: Vampire Academy #5
# Similarity: 0.037551473819678036, Book: Night World, No. 1, Saga: Night World #1-3
# Similarity: 0.03750298128998972, Book: Mists of the Serengeti, Saga: No
# Similarity: 0.03749581933968577, Book: Caressed by Ice, Saga: Psy-Changeling #3
# Similarity: 0.0374664258375663, Book: That Wedding, Saga: That Boy #2
# Similarity: 0.037394654273988026, Book: The Unbecoming of Mara Dyer, Saga: Mara Dyer #1
# Similarity: 0.037370897714680655, Book: Stay the Night, Saga: Darkyn #7
# Similarity: 0.037345804605142426, Book: Double Play, Saga: Pacific Heat #1
# Similarity: 0.03732293432529457, Book: A Mad, Wicked Folly, Saga: No
# Similarity: 0.03731793661570157, Book: Checkmate, Saga: Neighbor from Hell #3
# Similarity: 0.03728277716620766, Book: The Pillars of Creation, Saga: Sword of Truth #7
# Similarity: 0.037257101726725944, Book: Beautiful Creatures: The Manga, Saga: No
# Similarity: 0.03723043823240088, Book: Born in Flames, Saga: Born in Flames Trilogy #1
# Similarity: 0.03722337707416241, Book: Tiamat's Wrath, Saga: The Expanse #8
# Similarity: 0.037169635147433724, Book: The Lost Art of Keeping Secrets, Saga: No
# Similarity: 0.03711649094507529, Book: Animal Dreams, Saga: No
# Similarity: 0.03710232123125483, Book: Fray, Saga: No
# Similarity: 0.037054525512347766, Book: The Well of Ascension, Saga: Mistborn #2
# Similarity: 0.03704653192527525, Book: For the Fallen, Saga: Zombie Fallout #7
# Similarity: 0.0370299235615573, Book: The Blood, Saga: Morpheus Road #3
# Similarity: 0.0370219139740885, Book: The Witch Hunter, Saga: The Witch Hunter Saga #1
# Similarity: 0.037016869884142045, Book: The Mage, Saga: Foxcraft #3
# Similarity: 0.03701644741369597, Book: Stealing Bradford, Saga: Carter House Girls #2
# Similarity: 0.037005331730143774, Book: The Book of Everything, Saga: No
# Similarity: 0.03700041264640958, Book: Fan Art, Saga: No
# Similarity: 0.03697649794242058, Book: The Broken Council, Saga: The Guardian Chronicles #1
# Similarity: 0.03695895362829357, Book: Mixed Bags, Saga: Carter House Girls #1
# Similarity: 0.036948278616450114, Book: Since Drew, Saga: No
# Similarity: 0.036917632328516144, Book: Family Album, Saga: No
# Similarity: 0.03686396519640348, Book: Unmade, Saga: The Lynburn Legacy #3
# Similarity: 0.03685263348853978, Book: Two By Twilight, Saga: Wings in the Night #9 & 6
# Similarity: 0.03684130261276633, Book: Above the Veil, Saga: The Seventh Tower #4
# Similarity: 0.03681189222167036, Book: Sterling, Saga: Mageri #1
# Similarity: 0.036805991991836824, Book: The Named, Saga: Guardians of Time #1
# Similarity: 0.036748546638130784, Book: Burned, Saga: House of Night #7
# Similarity: 0.036724186665728804, Book: Double Share, Saga: Golden Age of the Solar Clipper #4
# Similarity: 0.03670814261482431, Book: Empire of Storms, Saga: Throne of Glass #5
# Similarity: 0.036699330535589894, Book: On the Other Side, Saga: No
# Similarity: 0.03668309093569689, Book: InterWorld, Saga: InterWorld #1
# Similarity: 0.03659259759401666, Book: Twilight Watch, Saga: Дозоры #3
# Similarity: 0.036558067249582084, Book: The Mysteries of Udolpho, Saga: No
# Similarity: 0.03654679076584778, Book: Edge of Dawn, Saga: Midnight Breed #11
# Similarity: 0.036485903210568736, Book: House of Leaves, Saga: No
# Similarity: 0.03642542605014166, Book: Mystique, Saga: No
# Similarity: 0.036395097397453766, Book: Dawnthief, Saga: Chronicles of the Raven #1
# Similarity: 0.03635222389017534, Book: The Revenge of the Dwarves, Saga: Die Zwerge #3
# Similarity: 0.03634559022533242, Book: Radiance, Saga: Wraith Kings #1
# Similarity: 0.03634053083636455, Book: The Gore: Book Six of the Oz Chronicles, Saga: The Oz Chronicles #6
# Similarity: 0.03631175910014385, Book: Be Not Afraid, Saga: No
# Similarity: 0.03630435647192699, Book: Tehanu, Saga: Earthsea Cycle #4
# Similarity: 0.03626944766684154, Book: First Drop of Crimson, Saga: Night Huntress World #1
# Similarity: 0.03622967873949509, Book: Perfect Fifths, Saga: Jessica Darling #5
# Similarity: 0.036222931214379125, Book: Snow Angel, Saga: No
# Similarity: 0.03622085406961491, Book: The Magicians, Saga: The Magicians #1
# Similarity: 0.03616120500231137, Book: The Stonor Eagles, Saga: No
# Similarity: 0.03610467415675278, Book: Generation Dead, Saga: Generation Dead #1
# Similarity: 0.036073541659113396, Book: Panic, Saga: Panic #1
# Similarity: 0.03606572497529544, Book: Wild About You, Saga: Love at Stake #13
# Similarity: 0.03604455401617725, Book: Beachcombers, Saga: No
# Similarity: 0.03602199431571848, Book: Shameless, Saga: Shameless #1
# Similarity: 0.036003378760917255, Book: Black Obsidian, Saga: Obsidian #1
# Similarity: 0.03598822631143184, Book: Swallowing Darkness, Saga: Merry Gentry #7
# Similarity: 0.03597517930097208, Book: Airel: The Awakening, Saga: The Airel Saga
# Similarity: 0.03592091843504075, Book: Sunshine, Saga: No
# Similarity: 0.03587201762880631, Book: Archer's Voice, Saga: No
# Similarity: 0.035820790763477106, Book: The Sea of Trolls, Saga: Sea of Trolls #1
# Similarity: 0.03576807874226929, Book: The Fall of Candy Corn, Saga: Sweet Seasons #2
# Similarity: 0.03574627604395833, Book: So Much Closer, Saga: No
# Similarity: 0.035738753950173716, Book: Un Lun Dun, Saga: No
# Similarity: 0.03573144347068834, Book: Kingdoms and Conquerors, Saga: Tennis Shoes #10
# Similarity: 0.035693866120484426, Book: The Secret of Platform 13, Saga: No
# Similarity: 0.03567809540773753, Book: Crossing the Line, Saga: Pushing the Limits #1.1
# Similarity: 0.03567656172989279, Book: Our Lady of Darkness, Saga: No
# Similarity: 0.03565582584342739, Book: Flunked, Saga: Fairy Tale Reform School #1
# Similarity: 0.03564173559516546, Book: One Foot in the Grave, Saga: Night Huntress #2
# Similarity: 0.035622097652168304, Book: Dark Kiss, Saga: Nightwatchers #1
# Similarity: 0.03559851846970007, Book: The Third Caliph, Saga: Rogue Angel #40
# Similarity: 0.035588823454878744, Book: Shut Out, Saga: Hamilton High #2
# Similarity: 0.03554983533884437, Book: House of Echoes, Saga: No
# Similarity: 0.03552622713410006, Book: The Switch, Saga: No
# Similarity: 0.0355051242788198, Book: Ghosts of Rosewood Asylum, Saga: No
# Similarity: 0.03549706241769802, Book: The Branches of Time, Saga: The Branches of Time #1
# Similarity: 0.03549086597280292, Book: Nathaniel, Saga: No
# Similarity: 0.035438014392443484, Book: Bloodline, Saga: Sigma Force #8
# Similarity: 0.03541564674943343, Book: Unremembered, Saga: Unremembered #1
# Similarity: 0.03540738989666701, Book: Suddenly You, Saga: No
# Similarity: 0.03530899167781064, Book: The Lunatic Cafe, Saga: Anita Blake, Vampire Hunter #4
# Similarity: 0.03530222049918194, Book: A Dance with Dragons: Dreams and Dust, Saga: A Song of Ice and Fire (1-in-2) #9
# Similarity: 0.03521285199711416, Book: The Lantern Bearers, Saga: The Dolphin Ring Cycle #4
# Similarity: 0.035193846089437486, Book: Against the Wall, Saga: Against the Wall #1
# Similarity: 0.03514033879402398, Book: The Last Days, Saga: Peeps #2
# Similarity: 0.035122874660765704, Book: The Restorer's Journey, Saga: The Sword of Lyric #3
# Similarity: 0.03511136264919073, Book: Almost Alice, Saga: Alice #20
# Similarity: 0.03507744749364836, Book: A Kiss of Shadows, Saga: Merry Gentry #1
# Similarity: 0.0350704096476826, Book: Exile's Song, Saga: Darkover - Publication Order #32
# Similarity: 0.035048787435072296, Book: The Princesses of Iowa, Saga: No
# Similarity: 0.03501275195125746, Book: Kiss of Death, Saga: The Morganville Vampires #8
# Similarity: 0.034994772239606675, Book: The Vanishing Girl, Saga: The Vanishing Girl #1
# Similarity: 0.03493307120054339, Book: The Hunted, Saga: The Enemy #6
# Similarity: 0.03492829030790053, Book: The Fiend and the Forge, Saga: The Tapestry #3
# Similarity: 0.034924134493089155, Book: Sunblind, Saga: No
# Similarity: 0.034904404886679494, Book: Villa Incognito, Saga: No
# Similarity: 0.034889060961454735, Book: The Moth Diaries, Saga: No
# Similarity: 0.034873361048941065, Book: The Destiny of Violet & Luke, Saga: The Coincidence #3
# Similarity: 0.03483812122958093, Book: Somber Island, Saga: No
# Similarity: 0.034834082660150416, Book: The Dresden Files Collection 1-6, Saga: The Dresden Files #1-6
# Similarity: 0.03479390781555222, Book: Muse of Nightmares, Saga: Strange the Dreamer #2
# Similarity: 0.034787204044995745, Book: The Story of Me, Saga: Carnage #2
# Similarity: 0.03468888738156119, Book: Dear Bridget, I Want You, Saga: A Series of Standalone Novels #5
# Similarity: 0.03463437148911602, Book: Obsessed, Saga: Obsessed #1
# Similarity: 0.03460920745385475, Book: Ghost Hunter, Saga: Chronicles of Ancient Darkness #6
# Similarity: 0.0345886673472274, Book: Lost & Found, Saga: Lost & Found #1
# Similarity: 0.034582393094640534, Book: Wool, Saga: Wool #1
# Similarity: 0.03456226808927936, Book: The Scorch Trials, Saga: The Maze Runner #2
# Similarity: 0.034552324753340954, Book: Hunted, Saga: House of Night #5
# Similarity: 0.034544769493731094, Book: An Author's Odyssey, Saga: The Land of Stories #5
# Similarity: 0.03454471117459255, Book: Winter World, Saga: The Long Winter #1
# Similarity: 0.034519773490888125, Book: Compete, Saga: The Atlantis Grail #2
# Similarity: 0.03449826218790948, Book: Fear, Saga: Gone #5
# Similarity: 0.03442973763134915, Book: Pleasures of the Night, Saga: Dream Guardians #1
# Similarity: 0.034408542510348965, Book: Managed, Saga: VIP #2
# Similarity: 0.03440635212156205, Book: Love at First Bite, Saga: Wild Wulfs of London #2.5 - The Forgotten One
# Similarity: 0.03438164513276447, Book: Wasteland, Saga: No
# Similarity: 0.03437793229866446, Book: Crush, Saga: Berrybrook Middle School #3
# Similarity: 0.034375899452711516, Book: The House Next Door, Saga: No
# Similarity: 0.03434355060265102, Book: A Madman Dreams of Turing Machines, Saga: No
# Similarity: 0.034329136852533214, Book: The Black River Chronicles: Level One, Saga: Black River Academy #1
# Similarity: 0.034320509186133295, Book: Eve, Saga: Eve #1
# Similarity: 0.03430655104562607, Book: Shadows in the Silence, Saga: Angelfire #3
# Similarity: 0.034269823588250974, Book: The Butterfly Garden, Saga: That Second Chance #6
# Similarity: 0.03426824220270011, Book: The Van Alen Legacy, Saga: Blue Bloods #4
# Similarity: 0.0342343532940839, Book: Mister B. Gone, Saga: No
# Similarity: 0.03423341748454908, Book: Piper Perish, Saga: Piper Perish #1
# Similarity: 0.034228700970814034, Book: Sizzle, Saga: Buchanan-Renard #8
# Similarity: 0.03422552186562959, Book: Cinema of Shadows, Saga: Harmony, Indiana #2
# Similarity: 0.03422476308090589, Book: The Farseekers, Saga: The Obernewtyn Chronicles #2
# Similarity: 0.034224425011563725, Book: Miranda's Big Mistake, Saga: No
# Similarity: 0.0342118663359031, Book: When I Found You, Saga: San Diego K-9 Unit #3
# Similarity: 0.03420832078409146, Book: Anne's House of Dreams, Saga: Anne of Green Gables #5
# Similarity: 0.03415445068382109, Book: Lord Loss, Saga: The Demonata #1
# Similarity: 0.0341348579355076, Book: Remember Me?, Saga: No
# Similarity: 0.034101553057331535, Book: The Hidden Land, Saga: The Secret Country #2
# Similarity: 0.03409348058206489, Book: The Moon Dwellers, Saga: The Dwellers #1
# Similarity: 0.03406698631856649, Book: If I Die, Saga: Soul Screamers #5
# Similarity: 0.03404365125966731, Book: Raising Stony Mayhall, Saga: No
# Similarity: 0.03404129347705792, Book: The Measure of the Magic, Saga: Legends of Shannara #2
# Similarity: 0.03401202328503244, Book: My Favorite Bride, Saga: Governess Brides #7
# Similarity: 0.033992532093295814, Book: The Complete ElfQuest, Volume One, Saga: The Complete ElfQuest #1
# Similarity: 0.03397353244187993, Book: Y: The Last Man, Vol. 1: Unmanned, Saga: Y: The Last Man #1
# Similarity: 0.03396888274258675, Book: Evil Star, Saga: The Power of Five #2
# Similarity: 0.03392990157119729, Book: The Blue Castle, Saga: No
# Similarity: 0.0339061354307691, Book: And Only to Deceive, Saga: Lady Emily #1
# Similarity: 0.033883402016892994, Book: Playing with Fire, Saga: Tales of an Extraordinary Girl #1
# Similarity: 0.033804679365128806, Book: Nemesis, Saga: Nemesis #1
# Similarity: 0.033794453828810946, Book: Forbidden, Saga: The Books of Mortals #1
# Similarity: 0.03375747406433099, Book: The Last Days of Lorien, Saga: Lorien Legacies: The Lost Files #5
# Similarity: 0.033741578349215276, Book: A Song for Summer, Saga: No
# Similarity: 0.03367058529718101, Book: For the Love of a Vampire, Saga: Blood Like Poison #1
# Similarity: 0.03363528930165981, Book: First Lady, Saga: Wynette, Texas #3
# Similarity: 0.03360677184962305, Book: Starless Night, Saga: Legacy of the Drow #2
# Similarity: 0.033604811895265, Book: A Reaper at the Gates, Saga: An Ember in the Ashes #3
# Similarity: 0.033592548392242495, Book: Let it Snow, Saga: No
# Similarity: 0.03356930570896485, Book: Poughkeepsie, Saga: The Poughkeepsie Brotherhood #1
# Similarity: 0.033564394866376024, Book: Jacob's Faith, Saga: Breeds #9
# Similarity: 0.03353504413817526, Book: The Mark of the Golden Dragon: Being an Account of the Further Adventures of Jacky Faber, Jewel of the East, Vexation of the West, and Pearl of the South China Sea, Saga: Bloody Jack #9
# Similarity: 0.03351943571228029, Book: Second Child, Saga: No
# Similarity: 0.03351717039619879, Book: The Diamond in the Window, Saga: Hall Family Chronicles #1
# Similarity: 0.03350416641186154, Book: Daring to Dream, Saga: Dream Trilogy #1
# Similarity: 0.03346022935169181, Book: The Source, Saga: Witching Savannah #2
# Similarity: 0.03343664701642984, Book: Deception, Saga: Defiance #2
# Similarity: 0.03341390973658541, Book: The Sinner, Saga: Black Dagger Brotherhood #18
# Similarity: 0.033392173519037345, Book: Odin's Ravens, Saga: The Blackwell Pages #2
# Similarity: 0.03337033426672421, Book: The Lucky Ones, Saga: Bright Young Things #3
# Similarity: 0.03336597117148067, Book: The Winter Guest, Saga: The Winter Guest #1
# Similarity: 0.03334360223115054, Book: The Element of Fire, Saga: Ile-Rien #1
# Similarity: 0.03331845376817251, Book: Among Others, Saga: No
# Similarity: 0.033313458917643694, Book: Midnight, Saga: The Vampire Diaries: The Return #3
# Similarity: 0.03329771196555671, Book: MirrorMask, Saga: No
# Similarity: 0.03328504042773072, Book: The Dark Age, Saga: Survivors of the Pulse #2
# Similarity: 0.03328197121489019, Book: Silver Phoenix, Saga: Kingdom of Xia (Phoenix) #1
# Similarity: 0.033267558528319766, Book: Taint, Saga: Sexual Education #1
# Similarity: 0.03326281172183981, Book: The Ten Best Days of My Life, Saga: No
# Similarity: 0.033239026601511575, Book: The Delirium Brief, Saga: Laundry Files #8
# Similarity: 0.03321793822155932, Book: The Talisman, Saga: The Talisman #1
# Similarity: 0.03320937867192278, Book: The Assassin and the Healer, Saga: Throne of Glass #0.2
# Similarity: 0.03319798262094459, Book: The Lives of Christopher Chant, Saga: Chrestomanci #2
# Similarity: 0.03319385638681786, Book: Lick, Saga: Stage Dive #1
# Similarity: 0.03319018454682616, Book: Señor Vivo and the Coca Lord, Saga: Latin American Trilogy
# Similarity: 0.03319007957303872, Book: Snuff, Saga: Discworld #39
# Similarity: 0.0331814470268194, Book: Year One, Saga: Chronicles of The One #1
# Similarity: 0.0331730325286476, Book: Odd Thomas, Saga: Odd Thomas #1
# Similarity: 0.03316440984757889, Book: Lover Mine, Saga: Black Dagger Brotherhood #8
# Similarity: 0.03315069170384389, Book: Traitor, Saga: Star Wars: The New Jedi Order #13
# Similarity: 0.03313348014613582, Book: By These Ten Bones, Saga: No
# Similarity: 0.033132019276923885, Book: A Stroke of Midnight, Saga: Merry Gentry #4
# Similarity: 0.03312752995376711, Book: The Orb of Truth, Saga: The Horn King #1
# Similarity: 0.033126145255771206, Book: Lords and Ladies, Saga: Discworld #14
# Similarity: 0.03310996475374087, Book: Backup, Saga: The Dresden Files #10.4
# Similarity: 0.03308549846190959, Book: Vampire Kisses, Saga: Vampire Kisses #1
# Similarity: 0.03305263468851114, Book: The Spine of the World, Saga: Paths of Darkness #2
# Similarity: 0.03304287103721748, Book: On a Pale Horse, Saga: Incarnations of Immortality #1
# Similarity: 0.03304077156938511, Book: Thirteen, Saga: The Winnie Years #4
# Similarity: 0.033025568377741996, Book: Prince of Fools, Saga: The Red Queen's War #1
# Similarity: 0.032985216061953364, Book: You Suck, Saga: A Love Story #2
# Similarity: 0.0329497198673903, Book: What My Girlfriend Doesn't Know, Saga: What My Mother Doesn't Know #2
# Similarity: 0.032946383759050075, Book: Megan Meade's Guide to the McGowan Boys, Saga: No
# Similarity: 0.03294590337134047, Book: The Magic Half, Saga: Miri and Molly #1
# Similarity: 0.03290783598676082, Book: A Thousand Boy Kisses, Saga: No
# Similarity: 0.03289767646964185, Book: Random Acts of Senseless Violence, Saga: Dryco
# Similarity: 0.03287670990252823, Book: Thin Space, Saga: No
# Similarity: 0.032855981338376514, Book: Deadly Sting, Saga: Elemental Assassin #8
# Similarity: 0.03283964160503557, Book: Thunderlight, Saga: The Dragonian #2
# Similarity: 0.032827890662328316, Book: Locke & Key, Volume 1: Welcome to Lovecraft, Saga: Locke & Key #1
# Similarity: 0.03282694620673655, Book: On the Shoulders of Titans, Saga: Arcane Ascension #2
# Similarity: 0.032824636518306916, Book: Breathing Under Water, Saga: No
# Similarity: 0.03281843549112756, Book: Valor, Saga: The Faithful and the Fallen #2
# Similarity: 0.032818323185346755, Book: 'Salem's Lot, Saga: No
# Similarity: 0.03276577481739957, Book: Battle Ground, Saga: The Dresden Files #17
# Similarity: 0.03275796433377149, Book: Halt's Peril, Saga: Ranger's Apprentice #9
# Similarity: 0.03275322466361415, Book: Inside Out, Saga: Insiders #1
# Similarity: 0.03274471998501293, Book: Divine By Mistake, Saga: Partholon #1
# Similarity: 0.03273401323949581, Book: Sunborn, Saga: Chaos Chronicles #4
# Similarity: 0.03272606834822493, Book: The Asylum, Saga: The Vampire Diaries: Stefan's Diaries #5
# Similarity: 0.0327200125790084, Book: The Love That Split the World, Saga: No
# Similarity: 0.032716879680359884, Book: Florence & Giles, Saga: Florence & Giles #1
# Similarity: 0.03270510896657318, Book: Wicked Kiss, Saga: Nightwatchers #2
# Similarity: 0.03266569662693794, Book: Dangerous Creatures, Saga: Dangerous Creatures #1
# Similarity: 0.032571555013061616, Book: Thursdays in Savannah (Slivers of Love), Saga: No
# Similarity: 0.03256096620022837, Book: 'Salem's Lot, Saga: No
# Similarity: 0.032557165390049804, Book: The Girl with the Make-Believe Husband, Saga: Rokesbys #2
# Similarity: 0.03255426184371664, Book: Veiled Eyes, Saga: Lake People #1
# Similarity: 0.0325382464653425, Book: Always a Thief, Saga: Quinn/Thief #2
# Similarity: 0.03253735072337088, Book: Magic's Promise, Saga: Valdemar: The Last Herald-Mage #2
# Similarity: 0.0325365004701847, Book: Winterling, Saga: Winterling #1
# Similarity: 0.03250324348910469, Book: Christy Miller Collection, Vol. 1, Saga: Christy Miller #1-3
# Similarity: 0.032497491671595984, Book: Dance with the Devil, Saga: Dark-Hunter #3
# Similarity: 0.03248218144242979, Book: Dreamlander, Saga: No
# Similarity: 0.032469248134079476, Book: Seize the Night, Saga: Moonlight Bay #2
# Similarity: 0.03246790253921375, Book: My French Whore, Saga: No
# Similarity: 0.03244432128888677, Book: Patternmaster, Saga: Patternmaster #4
# Similarity: 0.0323865314703117, Book: Rise, Saga: Nightshade Prequel #2
# Similarity: 0.032377560664802664, Book: Just One Thing, Saga: Cupid Falls #2
# Similarity: 0.0323704321491059, Book: Midnight, Saga: No
# Similarity: 0.03236044650357398, Book: The Daughters, Saga: Daughters #1
# Similarity: 0.03234992220849726, Book: Silverthorn, Saga: The Riftwar Saga #3
# Similarity: 0.03232741900818345, Book: BioShock: Rapture, Saga: No
# Similarity: 0.032312009178653026, Book: Zombies Don't Cry, Saga: Living Dead Love Story #1
# Similarity: 0.03229330455970259, Book: The Clover Chapel, Saga: Jamison Valley #2
# Similarity: 0.03227445317335643, Book: The Problem with Forever, Saga: No
# Similarity: 0.0322618336777549, Book: A Light to My Path, Saga: Refiner's Fire #3
# Similarity: 0.032246127889572956, Book: The Unwritten Rule, Saga: No
# Similarity: 0.03224335260625699, Book: Mini Shopaholic, Saga: Shopaholic #6
# Similarity: 0.03221734101786635, Book: Shadow Touch, Saga: Dirk & Steele #2
# Similarity: 0.03221578163370167, Book: Akira, Vol. 5, Saga: Akira: 6 Volumes #5
# Similarity: 0.032197500022129864, Book: The City of Worms, Saga: Everville #2
# Similarity: 0.032092132900934614, Book: Summerkin, Saga: Winterling #2
# Similarity: 0.032086788150833725, Book: Sanctuary, Saga: A New World #3
# Similarity: 0.032079963783026605, Book: Promised, Saga: One Night #1
# Similarity: 0.03205814039540006, Book: Sky in the Deep, Saga: Sky in the Deep #1
# Similarity: 0.03203810851182848, Book: Allan Quatermain, Saga: Allan Quatermain #2
# Similarity: 0.03202855403549272, Book: Itazura Na Kiss Volume 1, Saga: Itazura na Kiss - 12 volumes #1
# Similarity: 0.03201800867311035, Book: The House at the Edge of Night, Saga: No
# Similarity: 0.03199325872712309, Book: Forge of Darkness, Saga: The Kharkanas Trilogy #1
# Similarity: 0.03197737256608968, Book: The Magician King, Saga: The Magicians #2
# Similarity: 0.03196195738595448, Book: Vortex, Saga: Insignia #2
# Similarity: 0.03191369365304196, Book: Masque of the Red Death, Saga: Masque of the Red Death #1
# Similarity: 0.03188686504555564, Book: Little Lady, Big Apple, Saga: The Little Lady Agency #2
# Similarity: 0.03188385355540212, Book: The Evolutionary Void, Saga: Void #3
# Similarity: 0.03186277343168645, Book: City of Bones, Saga: The Mortal Instruments #1
# Similarity: 0.031851529118739084, Book: The Probable Future, Saga: No
# Similarity: 0.031805849618524715, Book: Dark Light of Mine, Saga: Overworld Chronicles #2
# Similarity: 0.03176857780955748, Book: Beauty and the Beast: The Only One Who Didn't Run Away, Saga: Twice Upon a Time #3
# Similarity: 0.03175216263915929, Book: Twilight Phantasies, Saga: Wings in the Night #1
# Similarity: 0.03174915809611006, Book: Deepsix, Saga: The Academy #2
# Similarity: 0.03174810609382541, Book: Forget You, Saga: No
# Similarity: 0.03174539753014199, Book: Brave Story, Saga: No
# Similarity: 0.03172280308475671, Book: May Bird, Warrior Princess, Saga: May Bird #3
# Similarity: 0.03172229073839277, Book: The Lonely Hearts Hotel, Saga: No
# Similarity: 0.031698434755598186, Book: Akira, Vol. 3, Saga: Akira: 6 Volumes #3
# Similarity: 0.03169842633412384, Book: Tempted, Saga: Alex Kennedy #1
# Similarity: 0.03168384785999909, Book: Leven Thumps and the Eyes of the Want, Saga: Leven Thumps #3
# Similarity: 0.03168147102095856, Book: Hiding in the Shadows, Saga: Bishop/Special Crimes Unit #2
# Similarity: 0.03167850256517472, Book: Where We Belong, Saga: Alabama Summer #4
# Similarity: 0.031677854982153045, Book: The Morganville Vampires, Volume 1, Saga: The Morganville Vampires #1-2
# Similarity: 0.03167764457181385, Book: Infinity Welcomes Careful Drivers, Saga: Red Dwarf #1
# Similarity: 0.03167384550388345, Book: Pet Shop of Horrors, Volume 9, Saga: Pet Shop of Horrors #9
# Similarity: 0.031672334691433296, Book: The Shadows, Saga: Vampire Huntress #11
# Similarity: 0.031670172693602616, Book: Through the Zombie Glass, Saga: White Rabbit Chronicles #2
# Similarity: 0.03166581689469304, Book: Sudden Response, Saga: EMS #1
# Similarity: 0.031615950472304984, Book: Unseen, Saga: The Vampire Diaries: The Salvation #1
# Similarity: 0.03160852081399931, Book: We Are Still Tornadoes, Saga: No
# Similarity: 0.03157911211933599, Book: The Warded Man, Saga: Demon Cycle #1
# Similarity: 0.031565656883631214, Book: Island of Graves, Saga: Unwanteds #6
# Similarity: 0.031562803890844496, Book: Moon Called, Saga: Mercy Thompson #1
# Similarity: 0.03152444534603424, Book: The Key to the Golden Firebird, Saga: No
# Similarity: 0.03151000681732393, Book: Sweet Girl, Saga: Courting Love (The Sweetest Thing) #2
# Similarity: 0.03150339742293944, Book: Reign of Shadows, Saga: Reign of Shadows #1
# Similarity: 0.03149167396970773, Book: Guards! Guards!: The Play, Saga: Discworld Stage Adaptations
# ...
# Similarity: 0.0, Book: The War of Don Emmanuel's Nether Parts, Saga: Latin American Trilogy
# Similarity: 0.0, Book: The Demon in the Wood, Saga: The Shadow and Bone Trilogy #0.5
# Similarity: 0.0, Book: Alice the Tennis Fairy, Saga: Rainbow Magic #62
# Similarity: 0.0, Book: Helen's Babies, Saga: No
# Similarity: 0.0, Book: The Complete Wheel of Time, Saga: The Wheel of Time #omnibus
# Similarity: 0.0, Book: The Time Between, Saga: No
# Similarity: 0.0, Book: Elysium, Saga: No
# Similarity: 0.0, Book: Help Wanted, Saga: Fantasy Heights #1
# Similarity: 0.0, Book: No Game, No Life Vol. 1, Saga: No Game, No Life manga #1
# Similarity: 0.0, Book: Prince of Foxes, Saga: No
# Similarity: 0.0, Book: Rua, Saga: Rua #1
# Similarity: 0.0, Book: The Adventures of Robin Hood, Saga: No
# Similarity: 0.0, Book: Midnight Embrace, Saga: Vampire Romances #6
# Similarity: 0.0, Book: A Princess in Berlin, Saga: No
# Similarity: 0.0, Book: The Proud Breed, Saga: No
# Similarity: 0.0, Book: Casanova, Saga: No
# Similarity: 0.0, Book: Dreadnaught, Saga: The Lost Fleet: Beyond the Frontier #1
# Similarity: 0.0, Book: Willful Child, Saga: Willful Child #1
# Similarity: 0.0, Book: Between the Spark and the Burn, Saga: Between #2
# Similarity: 0.0, Book: What-the-Dickens: The Story of a Rogue Tooth Fairy, Saga: No
# Similarity: 0.0, Book: Blood Magic, Saga: The Ballad Of Kirin Widowmaker #1
# Similarity: 0.0, Book: Love, Come to Me, Saga: No
# Similarity: 0.0, Book: Only By Your Touch, Saga: No
# Similarity: 0.0, Book: Homestuck Book Two, Saga: Homestuck #2
# Similarity: 0.0, Book: Let It Be Me, Saga: No
# Similarity: 0.0, Book: A Book Dragon, Saga: No
# Similarity: 0.0, Book: God's Demon, Saga: No
# Similarity: 0.0, Book: The Curse of the Gloamglozer, Saga: The Edge Chronicles: The Quint Saga #1
# Similarity: 0.0, Book: The Fetch, Saga: No
# Similarity: 0.0, Book: Witches on Parole, Saga: WitchLight Trilogy #1
# Similarity: 0.0, Book: Air, Saga: No
# Similarity: 0.0, Book: Ground Zero, Saga: The X-Files #3
# Similarity: 0.0, Book: The Planiverse: Computer Contact with a Two-Dimensional World, Saga: No
# Similarity: 0.0, Book: Cold Fire / Hideaway / The Key to Midnight, Saga: No
# Similarity: 0.0, Book: Slimer, Saga: No
# Similarity: 0.0, Book: Diving In, Saga: Art & Coll #1
# Similarity: 0.0, Book: The Reluctant Heiress, Saga: No
# Similarity: 0.0, Book: Haunted, Saga: No
# Similarity: 0.0, Book: The Unlikely Romance of Kate Bjorkman, Saga: No
# Similarity: 0.0, Book: The Princesse de Clèves, Saga: No
# Similarity: 0.0, Book: People of the Wolf, Saga: North America's Forgotten Past #1
# Similarity: 0.0, Book: Deathwish, Saga: 夜に彷徨うもの #5
# Similarity: 0.0, Book: Don't Die, Dragonfly, Saga: The Seer #1
# Similarity: 0.0, Book: Treason, Saga: No
# Similarity: 0.0, Book: Adorkable, Saga: No
# Similarity: 0.0, Book: Lie Down with Lions, Saga: No
# Similarity: 0.0, Book: El Dorado: Further Adventures of the Scarlet Pimpernel, Saga: The Scarlet Pimpernel (chronological order) #7
# Similarity: 0.0, Book: The Walking Dead, Vol. 12: Life Among Them, Saga: The Walking Dead (Collected Editions) #12
# Similarity: 0.0, Book: Beautiful, Saga: No
# Similarity: 0.0, Book: The Fisherman's Lady, Saga: No
# Similarity: 0.0, Book: Always, Saga: Montgomery/Taggert (Publication order) #27
# Similarity: 0.0, Book: Wolf in Shadow, Saga: Jon Shannow #1
# Similarity: 0.0, Book: Nausicaä of the Valley of the Wind, Vol. 5, Saga: Nausicaä of the Valley of the Wind #5
# Similarity: 0.0, Book: Captain Marvel, Volume 1: In Pursuit of Flight, Saga: Captain Marvel (2012) (Collected Editions) #1
# Similarity: 0.0, Book: Touch of Darkness, Saga: Darkness Chosen #2
# Similarity: 0.0, Book: Vanishing Girls, Saga: No
# Similarity: 0.0, Book: Shiva's Fire, Saga: No
# Similarity: 0.0, Book: The Firebird, Saga: Slains #2
# Similarity: 0.0, Book: Awry, Saga: The Archers of Avalon #2
# Similarity: 0.0, Book: Resistance, Saga: No
# Similarity: 0.0, Book: Vampire Rites Trilogy, Saga: Cirque du Freak #4-6
# Similarity: 0.0, Book: The Regulators, Saga: No
# Similarity: 0.0, Book: When It's Real, Saga: No
# Similarity: 0.0, Book: She Who Remembers, Saga: Kwani #1
# Similarity: 0.0, Book: Madouc, Saga: Lyonesse #3
# Similarity: 0.0, Book: Witchlight, Saga: Night World #9
# Similarity: 0.0, Book: Amazing Grace, Saga: No
# Similarity: 0.0, Book: Forever and Always, Saga: Montgomery/Taggert (Publication order) #25
# Similarity: 0.0, Book: I, Tituba, Black Witch of Salem, Saga: No
# Similarity: 0.0, Book: What I Was, Saga: No
# Similarity: 0.0, Book: Shoeless Joe, Saga: No
# Similarity: 0.0, Book: Immortal, Saga: Buffy the Vampire Slayer: Season 3 #9
# Similarity: 0.0, Book: The Adventures of Robin Hood: An English Legend, Saga: No
# Similarity: 0.0, Book: Ape and Essence, Saga: No
# Similarity: 0.0, Book: Unbreakable, Saga: Unraveling #2
# Similarity: 0.0, Book: Mermaid Park, Saga: No
# Similarity: 0.0, Book: The Songs of Distant Earth, Saga: No
# Similarity: 0.0, Book: The Key, Saga: Guardians of Time #3
# Similarity: 0.0, Book: Kalki, Saga: No
# Similarity: 0.0, Book: Mercy, Saga: Buchanan-Renard #2
# Similarity: 0.0, Book: Amy, Number Seven, Saga: Replica #1
# Similarity: 0.0, Book: Love's Unending Legacy, Saga: Love Comes Softly #5
# Similarity: 0.0, Book: The Brothers' War, Saga: Magic: The Gathering: Artifacts Cycle #1
# Similarity: 0.0, Book: Gallows Hill, Saga: No
# Similarity: 0.0, Book: Virtual Light, Saga: Bridge #1
# Similarity: 0.0, Book: In the Realm of the Wolf, Saga: The Drenai Saga #5
# Similarity: 0.0, Book: Sweep: The Story of a Girl and Her Monster, Saga: No
# Similarity: 0.0, Book: Angel-Seeker, Saga: Samaria #5
# Similarity: 0.0, Book: Eyes of Silver, Eyes of Gold, Saga: No
# Similarity: 0.0, Book: The Scottish Prisoner, Saga: Lord John Grey #3
# Similarity: 0.0, Book: In the Stillness, Saga: No
# Similarity: 0.0, Book: The Initiation, Saga: The Secret Circle #1
# Similarity: 0.0, Book: 10 Things to Do Before I Die, Saga: No
# Similarity: 0.0, Book: Unashamed: Rahab, Saga: Lineage of Grace #2
# Similarity: 0.0, Book: City of Blades, Saga: The Divine Cities #2
# Similarity: 0.0, Book: The Woman Who Loved Reindeer, Saga: No
# Similarity: 0.0, Book: The Stainless Steel Rat, Saga: Stainless Steel Rat (Publication Order) #1
# Similarity: 0.0, Book: Tributary, Saga: River of Time #3.2
# Similarity: 0.0, Book: The Kane Chronicles Survival Guide, Saga: The Kane Chronicles
# Similarity: 0.0, Book: The Swan Kingdom, Saga: No
# Similarity: 0.0, Book: More Than Enough, Saga: More Than #5
# Similarity: 0.0, Book: Victoria, Saga: No
# Similarity: 0.0, Book: Surrender, Saga: MacKinnon’s Rangers #1
# Similarity: 0.0, Book: Queen's Own, Saga: Valdemar: Heralds of Valdemar #1–3
# Similarity: 0.0, Book: When Calls the Heart, Saga: Canadian West #1
# Similarity: 0.0, Book: The Changeling Sea, Saga: No
# Similarity: 0.0, Book: Plum Spooky, Saga: Stephanie Plum #14.5
# Similarity: 0.0, Book: My Cousin, My Gastroenterologist, Saga: No
# Similarity: 0.0, Book: Fallen Heir, Saga: The Royals #4
# Similarity: 0.0, Book: Black Powder War, Saga: Temeraire #3
# Similarity: 0.0, Book: The Ghost of Crutchfield Hall, Saga: No
# Similarity: 0.0, Book: Meet Me at the Cupcake Café, Saga: At the Cupcake Café #1
# Similarity: 0.0, Book: Soul Screamers Volume One, Saga: Soul Screamers #0.5, 1, 2
# Similarity: 0.0, Book: The Lady from the Sea, Saga: No
# Similarity: 0.0, Book: 'Till Death Do Us Part, Saga: Zombie Fallout #6
# Similarity: 0.0, Book: Enchanted Glass, Saga: No
# Similarity: 0.0, Book: More Than We Can Tell, Saga: Letters to the Lost #2
# Similarity: 0.0, Book: Ghosts & Echoes, Saga: Shadows Inquiries #2
# Similarity: 0.0, Book: Rival Demons, Saga: The Shadow Demons Saga #5
# Similarity: 0.0, Book: Life Before Legend, Saga: Legend #0.5
# Similarity: 0.0, Book: The Wood's Edge, Saga: The Pathfinders #1
# Similarity: 0.0, Book: East of the Sun, Saga: No
# Similarity: 0.0, Book: The End of the World, Saga: Skulduggery Pleasant #6.5
# Similarity: 0.0, Book: Lorna Doone, Saga: No
# Similarity: 0.0, Book: Lost, Saga: Magic Thief #2
# Similarity: 0.0, Book: The Heart Mender: A Story of Second Chances, Saga: No
# Similarity: 0.0, Book: Reincarnation, Saga: No
# Similarity: 0.0, Book: Life Sucks, Saga: No
# Similarity: 0.0, Book: Bring Me the Head of Prince Charming, Saga: Millennial Contest #1
# Similarity: 0.0, Book: The Shadows Between Us, Saga: No
# Similarity: 0.0, Book: It's All Greek to Me, Saga: Time Warp Trio #8
# Similarity: 0.0, Book: Stranger and Stranger, Saga: Emily the Strange #2
# Similarity: 0.0, Book: The Devil's Right Hand, Saga: Dante Valentine #3
# Similarity: 0.0, Book: The Power That Preserves, Saga: The Chronicles of Thomas Covenant the Unbeliever #3
# Similarity: 0.0, Book: Prisoner of the Inquisition, Saga: No
# Similarity: 0.0, Book: Harpist in the Wind, Saga: Riddle-Master #3
# Similarity: 0.0, Book: Pretty Little Liars Box Set, Saga: Pretty Little Liars #1-4
# Similarity: 0.0, Book: The Killing Kind, Saga: Charlie Parker #3
# Similarity: 0.0, Book: Heart-Shaped Bruise, Saga: No
# Similarity: 0.0, Book: Practical Demonkeeping, Saga: Pine Cove #1
# Similarity: 0.0, Book: Legend, Saga: Legend, Colorado #1
# Similarity: 0.0, Book: Ironhand's Daughter, Saga: The Hawk Queen #1
# Similarity: 0.0, Book: Sapphire Battersea, Saga: Hetty Feather #2
# Similarity: 0.0, Book: Borders of Infinity, Saga: Vorkosigan Saga (Publication Order) #5.1-5.3
# Similarity: 0.0, Book: Exile's Valor, Saga: Alberich's Tale #2
# Similarity: 0.0, Book: Brethren, Saga: Brethren Trilogy #1
# Similarity: 0.0, Book: Thomas’s First Memory of the Flare, Saga: The Maze Runner #2.5
# Similarity: 0.0, Book: A Fork of Paths, Saga: A Shade of Vampire #22
# Similarity: 0.0, Book: Always a Witch, Saga: Witch #2
# Similarity: 0.0, Book: Embraced by Darkness, Saga: Riley Jenson Guardian #5
# Similarity: 0.0, Book: Under a Vampire Moon, Saga: Argeneau #16
# Similarity: 0.0, Book: Key of Valor, Saga: Key Trilogy #3
# Similarity: 0.0, Book: Hidden Currents, Saga: Drake Sisters #7
# Similarity: 0.0, Book: The Dying Earth, Saga: The Dying Earth #1
# Similarity: 0.0, Book: Sweetwater Gap, Saga: No
# Similarity: 0.0, Book: Massie, Saga: Clique Summer Collection #1
# Similarity: 0.0, Book: Renegade's Magic, Saga: The Soldier Son #3
# Similarity: 0.0, Book: Dunkirk Crescendo, Saga: Zion Covenant #9
# Similarity: 0.0, Book: Maid to Match, Saga: No
# Similarity: 0.0, Book: Avempartha, Saga: The Riyria Revelations #2
# Similarity: 0.0, Book: A Love Surrendered, Saga: Winds of Change #3
# Similarity: 0.0, Book: Night's Child, Saga: Wicca #15
# Similarity: 0.0, Book: Chime, Saga: No
# Similarity: 0.0, Book: Invisibility, Saga: No
# Similarity: 0.0, Book: The Rise of the Hotel Dumort, Saga: The Bane Chronicles #5
# Similarity: 0.0, Book: Isle of Swords, Saga: Isle of Swords #1
# Similarity: 0.0, Book: Strange Candy, Saga: Anita Blake, Vampire Hunter #0.5
# Similarity: 0.0, Book: Amy Snow, Saga: No
# Similarity: 0.0, Book: Domain, Saga: Rats #3
# Similarity: 0.0, Book: Lost Covenant, Saga: Widdershins Adventures #3
# Similarity: 0.0, Book: The Ugly Little Boy, Saga: No
# Similarity: 0.0, Book: One Past Midnight: The Langoliers, Saga: No
# Similarity: 0.0, Book: Mort: The Play, Saga: Discworld Stage Adaptations
# Similarity: 0.0, Book: Underworld: Blood Enemy, Saga: Underworld #2
# Similarity: 0.0, Book: Sundiver, Saga: The Uplift Saga #1
# Similarity: 0.0, Book: Raising Abel, Saga: No
# Similarity: 0.0, Book: The Islands of the Blessed, Saga: Sea of Trolls #3
# Similarity: 0.0, Book: The Ironwood Tree, Saga: The Spiderwick Chronicles #4
# Similarity: 0.0, Book: Back on Blossom Street, Saga: Blossom Street #4
# Similarity: 0.0, Book: The Violet Keystone, Saga: The Seventh Tower #6
# Similarity: 0.0, Book: Doctor Who: The Glamour Chase, Saga: Doctor Who: New Series Adventures #42
# Similarity: 0.0, Book: Mackenzies' Honor: Mackenzie's Pleasure / A Game of Chance, Saga: Mackenzie Family #3-4
# Similarity: 0.0, Book: Alphas, Saga: Alphas #1
# Similarity: 0.0, Book: Harmony's Way, Saga: Breeds #7
# Similarity: 0.0, Book: The Rescue, Saga: The English Garden #2
# Similarity: 0.0, Book: Sleep No More, Saga: No
# Similarity: 0.0, Book: A Constant Heart, Saga: Against All Expectations #1
# Similarity: 0.0, Book: In the Tall Grass, Saga: No
# Similarity: 0.0, Book: The Musician's Daughter, Saga: Theresa Schurman #1
# Similarity: 0.0, Book: CryoBurn, Saga: Vorkosigan Saga (Publication Order) #14
# Similarity: 0.0, Book: Goodnight Opus, Saga: No
# Similarity: 0.0, Book: Anita Blake, Vampire Hunter Collection 1-4 (Anita Blake, Vampire Hunter, #1-4), Saga: No
# Similarity: 0.0, Book: The White Mountains, Saga: The Tripods #1
# Similarity: 0.0, Book: The Road Home, Saga: No
# Similarity: 0.0, Book: Ghouls Just Haunt to Have Fun, Saga: Ghost Hunter Mystery #3
# Similarity: 0.0, Book: What's a Ghoul to Do?, Saga: Ghost Hunter Mystery #1
# Similarity: 0.0, Book: Infinity in the Palm of Her Hand: A Novel of Adam and Eve, Saga: No
# Similarity: 0.0, Book: The Wise Woman, Saga: No
# Similarity: 0.0, Book: Are You in the House Alone?, Saga: No
# Similarity: 0.0, Book: Alphabet of Thorn, Saga: No
# Similarity: 0.0, Book: A Soldier of Shadows, Saga: A Shade of Vampire #19
# Similarity: 0.0, Book: The Parasites, Saga: No
# Similarity: 0.0, Book: Peaches for Father Francis, Saga: Chocolat #3
# Similarity: 0.0, Book: Nightwalker, Saga: Dark Days #1
# Similarity: 0.0, Book: The Promise, Saga: No
# Similarity: 0.0, Book: Singularity Sky, Saga: Eschaton #1
# Similarity: 0.0, Book: The Last Enchantment, Saga: Arthurian Saga #3
# Similarity: 0.0, Book: The Sin Eater's Daughter, Saga: The Sin Eater’s Daughter #1
# Similarity: 0.0, Book: Lady of Avalon, Saga: Avalon #3
# Similarity: 0.0, Book: The People of the Mist, Saga: No
# Similarity: 0.0, Book: Over My Dead Body, Saga: 43 Old Cemetery Road #2
# Similarity: 0.0, Book: Jake Undone, Saga: Jake #1
# Similarity: 0.0, Book: The Legend of Sleepy Hollow and Other Stories, Saga: No
# Similarity: 0.0, Book: The List, Saga: The List #1
# Similarity: 0.0, Book: Busman's Honeymoon, Saga: Lord Peter Wimsey #11
# Similarity: 0.0, Book: Firefight, Saga: The Reckoners #2
# Similarity: 0.0, Book: Loki, Saga: No
# Similarity: 0.0, Book: The Rescue, Saga: Medusa Project #3
# Similarity: 0.0, Book: Dying to Meet You, Saga: 43 Old Cemetery Road #1
# Similarity: 0.0, Book: Absolutely Normal Chaos, Saga: No
# Similarity: 0.0, Book: The Reality Dysfunction Part 2: Expansion, Saga: Night's Dawn #1, Part 2 of 2
# Similarity: 0.0, Book: Stinger, Saga: No
# Similarity: 0.0, Book: The Harvester, Saga: No
# Similarity: 0.0, Book: Release Me, Saga: Stark Saga #1
# Similarity: 0.0, Book: Working for the Devil, Saga: Dante Valentine #1
# Similarity: 0.0, Book: All You Need is Love, Saga: Green Mountain #1
# Similarity: 0.0, Book: The Wind Blows Backward, Saga: No
# Similarity: 0.0, Book: Tamed, Saga: Tangled #3
# Similarity: 0.0, Book: Breathe: A Ghost Story, Saga: No
# Similarity: 0.0, Book: xxxHolic, Vol. 10, Saga: xxxHOLiC #10
# Similarity: 0.0, Book: Cetaganda, Saga: Vorkosigan Saga (Publication Order) #9
# Similarity: 0.0, Book: Wintertide, Saga: The Riyria Revelations #5
# Similarity: 0.0, Book: Callahan's Crosstime Saloon, Saga: Callahan's #1
# Similarity: 0.0, Book: Whispering Rock, Saga: Virgin River #3
# Similarity: 0.0, Book: Tonight on the Titanic, Saga: Magic Tree House #17
# Similarity: 0.0, Book: Lucinda's Secret, Saga: The Spiderwick Chronicles #3
# Similarity: 0.0, Book: Lonely Werewolf Girl, Saga: Kalix MacRinnalch #1
# Similarity: 0.0, Book: Darwinia, Saga: No
# Similarity: 0.0, Book: Shadow Spinner, Saga: No
# Similarity: 0.0, Book: Human.4, Saga: Point 4 #1
# Similarity: 0.0, Book: A Barrel of Laughs, a Vale of Tears, Saga: No
# Similarity: 0.0, Book: Longbourn, Saga: No
# Similarity: 0.0, Book: To Have and to Hold: A Tale of Providence and Perseverance in Colonial Jamestown, Saga: No
# Similarity: 0.0, Book: Thornyhold, Saga: No
# Similarity: 0.0, Book: Born in Shame, Saga: Born In Trilogy #3
# Similarity: 0.0, Book: Poison, Saga: The Poisoner Mysteries #1
# Similarity: 0.0, Book: The Secret Wife, Saga: No
# Similarity: 0.0, Book: Spellbound, Saga: Wicca #6
# Similarity: 0.0, Book: Cardboard, Saga: No
# Similarity: 0.0, Book: Wayside School Gets A Little Stranger, Saga: Wayside School #3
# Similarity: 0.0, Book: The Hunger Games, Saga: The Hunger Games #1

# %% [markdown]
# - - -
